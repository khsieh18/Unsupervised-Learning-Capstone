# %% [markdown]
# For this project you'll dig into a large amount of text and apply most of what you've covered in this unit and in the course so far.
#
# First, pick a set of texts. This can be either a series of novels, chapters, or articles. Anything you'd like. It just has to have multiple entries of varying characteristics. At least 100 should be good. There should also be at least 10 different authors, but try to keep the texts related (either all on the same topic of from the same branch of literature - something to make classification a bit more difficult than obviously different subjects).
#
# This capstone can be an extension of your NLP challenge if you wish to use the same corpus. If you found problems with that data set that limited your analysis, however, it may be worth using what you learned to choose a new corpus. Reserve 25% of your corpus as a test set.
#
# The first technique is to create a series of clusters. Try several techniques and pick the one you think best represents your data. Make sure there is a narrative and reasoning around why you have chosen the given clusters. Are authors consistently grouped into the same cluster?
#
# Next, perform some unsupervised feature generation and selection using the techniques covered in this unit and elsewhere in the course. Using those features then build models to attempt to classify your texts by author. Try different permutations of unsupervised and supervised techniques to see which combinations have the best performance.
#
# Lastly return to your holdout group. Does your clustering on those members perform as you'd expect? Have your clusters remained stable or changed dramatically? What about your model? Is it's performance consistent?
#
# If there is a divergence in the relative stability of your model and your clusters, delve into why.
#
# Your end result should be a write up of how clustering and modeling compare for classifying your texts. What are the advantages of each? Why would you want to use one over the other? Approximately 3-5 pages is a good length for your write up, and remember to include visuals to help tell your story!

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import spacy
nlp = spacy.load('en')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# %% [markdown]
# ## Load files

# %%
#filename=['brady.txt','butler.txt','cutting.txt','dawson.txt','dyke.txt',
#          'hughes.txt','mitchell.txt','richmond.txt','rinehart.txt','stretton.txt']
filename=['brady.txt']

# %%
#def text_creater(filename):
#    file=open(filename,'r')
#    text=file.read()
#    file.close
#    return text

# %%
file=open(filename[0],'r')
text=file.read()
file.close
# Out:
# <function TextIOWrapper.close()>

# %%
text_doc=nlp(text)

# %%
text_sents=[[sent,"brady"] for sent in text_doc.sents]

# %%
text_sents
# Out:
# [[ï»¿The Project Gutenberg eBook, And Thus He Came, by Cyrus Townsend Brady,,
#   'brady'],
#  [Illustrated by Walter B. Everett
#
#   , 'brady'],
#  [This eBook is for the use of anyone anywhere at no cost and with
#   almost no restrictions whatsoever.  , 'brady'],
#  [You may copy it, give it away or
#   re-use it under the terms of the Project Gutenberg License included
#   with this eBook or online at www.gutenberg.net
#
#
#
#
#   , 'brady'],
#  [Title:, 'brady'],
#  [And Thus He Came
#   , 'brady'],
#  [Author: Cyrus Townsend Brady
#
#   Release Date, 'brady'],
#  [: January 5, 2005  , 'brady'],
#  [[eBook #14606]
#   , 'brady'],
#  [Language:, 'brady'],
#  [English
#
#   Character set encoding: ISO-646-US (US-ASCII)
#
#   , 'brady'],
#  [*, 'brady'],
#  [**START OF THE PROJECT GUTENBERG EBOOK AND, 'brady'],
#  [THUS HE CAME*, 'brady'],
#  [**
#
#
#   E-text prepared by Robert Cicconetti, Melissa Er-Raqabi, and the Project
#   Gutenberg Online Distributed Proofreading Team (http://www.pgdp.net)
#
#
#   , 'brady'],
#  [Note: Project Gutenberg also has an HTML version of this
#         file which includes the original illustrations.
#         , 'brady'],
#  [See 14606-h.htm or 14606-h.zip, 'brady'],
#  [:
#         (http://www.gutenberg.net/dirs/1/4/6/0/14606/14606-h/14606-h.htm)
#         or
#         (http://www.gutenberg.net/dirs/1/4/6/0/14606/14606-h.zip)
#
#
#
#
#
#   AND THUS HE CAME
#   , 'brady'],
#  [A Christmas Fantasy
#
#   by
#
#   CYRUS TOWNSEND BRADY
#   , 'brady'],
#  [Pictures by Walter B. Everett
#
#   G.P. Putnam's Sons
#   New York and London
#   The Knickerbocker Press
#
#   1916
#
#
#
#
#
#
#   , 'brady'],
#  [[Illustration: "No, No," said the woman, "I can't go with you now."]
#
#
#   , 'brady'],
#  [To the Beloved Memory
#   of
#   Little Betty
#
#
#
#
#   Contents
#
#          , 'brady'],
#  [I.--, 'brady'],
#  [THE BABY
#         II.--, 'brady'],
#  [THE CHILD
#        III.--, 'brady'],
#  [THE FRIEND
#         IV.--, 'brady'],
#  [THE WORKMAN
#          V.--, 'brady'],
#  [THE COMFORTER
#         VI.--, 'brady'],
#  [THE BURDEN BEARER
#        VII.--, 'brady'],
#  [THE THORN CROWNED
#       VIII.--, 'brady'],
#  [THE BROKEN-HEARTED
#         , 'brady'],
#  [IX.--, 'brady'],
#  [THE FORGIVER OF SINS
#          X.--, 'brady'],
#  [THE GIVER OF LIFE
#         XI.--, 'brady'],
#  [THE STILLER OF THE STORM
#
#
#
#
#   Illustrations
#
#      , 'brady'],
#  ["NO, NO," SAID THE WOMAN, ", 'brady'],
#  [I CAN'T GO WITH YOU NOW", 'brady'],
#  [(Frontispiece)
#
#      , 'brady'],
#  [AFTER A TIME SHE FELL DOWN ON HER KNEES., 'brady'],
#  [SHE PRESSED THEM, 'brady'],
#  [AGAINST
#      , 'brady'],
#  [HER FACE
#
#      , 'brady'],
#  [SHE LAID HER HAND UPON THE KNOB OF THE CHURCH DOOR
#
#      , 'brady'],
#  ["IT IS HE,", 'brady'],
#  [WHISPERED THE PRIEST; "HIS SORROW WAS GREATER THAN MINE"
#
#      ABSOLVO TE
#
#      THE CRY FOR BREAD
#
#
#
#
#   I
#   , 'brady'],
#  [The Baby
#   , 'brady'],
#  [", 'brady'],
#  [A LITTLE CHILD SHALL LEAD THEM"
#
#
#
#
#   I
#   , 'brady'],
#  [The Baby
#
#
#   The heavy perfume of rare blossoms, the wild strains of mad music, the
#   patter of flying feet, the murmur of speech, the ring of laughter,
#   filled the great hall., 'brady'],
#  [Now and again a pair of dancers, peculiarly
#   graceful and particularly daring, held the center of the floor for a
#   moment while the room rang with applause.
#   , 'brady'],
#  [Into alcoves, screened and flower-decked, couples wandered., 'brady'],
#  [In the
#   dancing-space hands were clasped, bosoms rose and fell, hearts throbbed,
#   pulses beat, and moving bodies kept time to rhythmic sound.
#   , 'brady'],
#  [Suddenly the music stopped, the conversation ceased, the laughter died
#   away., 'brady'],
#  [Almost, as it were, poised in the air, the dancers stood amazed., 'brady'],
#  [One looked to another in surprise., 'brady'],
#  [Something stole throughout the room
#   which was neither music, nor lights, nor fragrance, but which was
#   life--a presence!
#   , 'brady'],
#  ["Do you see that child?, 'brady'],
#  [" asked the wildest of the dancers of her escort., 'brady'],
#  ["There," she pointed. ", 'brady'],
#  [He looks like a very little boy."
#   , 'brady'],
#  ["I see nothing," said the man, who still held her in the clasp of his
#   arm.
#   , 'brady'],
#  ["He is strangely dressed, although I see him indistinctly, vaguely,"
#   whispered the woman. ", 'brady'],
#  [He wears a long white robe and there is a kind of
#   light about his face., 'brady'],
#  [See, he is looking at us."
#   , 'brady'],
#  ["I see nothing," repeated the man in low tones., 'brady'],
#  ["The heat, the light,
#   the music, have disturbed you; let me get you--"
#   , 'brady'],
#  ["I want nothing," interposed the woman, waving the man aside and drawing
#   away from his arm., 'brady'],
#  ["Don't you see him, there?"
#   , 'brady'],
#  [She made a step toward the center of the room., 'brady'],
#  [She stopped, put her
#   hand to her head.
#   , 'brady'],
#  ["Why, he is gone," she exclaimed.
#   , 'brady'],
#  ["Good," said the man, while at that instant the room suddenly rang with
#   cries: "Go on with the music, the dance is not half over.", 'brady'],
#  [He extended
#   his arm to the woman again., 'brady'],
#  ["Our dance is not finished."
#   , 'brady'],
#  ["Yes, it is," she said as the flying feet once more twinkled across the
#   polished floor, as everybody took a long breath and a new start
#   apparently unconscious of the pause.
#   , 'brady'],
#  ["It is over for me., 'brady'],
#  [What I saw!"
#   , 'brady'],
#  ["What did you see?"
#   , 'brady'],
#  ["I don't know, but I'm going back home to my child., 'brady'],
#  [Good-night."
#
#          , 'brady'],
#  [*       , 'brady'],
#  [*       *       *       *
#
#   Yes, the music had stopped suddenly., 'brady'],
#  [The man in the farthest alcove
#   turned to his companion., 'brady'],
#  [They were hidden by a group of palms.
#   , 'brady'],
#  ["I wonder why?" queried the woman., 'brady'],
#  [She was deathly pale., 'brady'],
#  [Her eyes were
#   dark with fear, yet alight with passionate determination.
#   , 'brady'],
#  ["When it begins," said the man tenderly, "we will slip away., 'brady'],
#  [My car is
#   outside., 'brady'],
#  [Everything is ready."
#   , 'brady'],
#  ["That is my husband over there," said the woman.
#   , 'brady'],
#  ["Yes," said the man, "he won't trouble you any more."
#   , 'brady'],
#  ["That woman with him is leaving him," she said., 'brady'],
#  ["I wonder why.", 'brady'],
#  [She
#   turned suddenly with a great start., 'brady'],
#  ["There is somebody here," she
#   whispered, staring into the back of the alcove.
#   , 'brady'],
#  ["Nonsense," said the man, throwing a glance around the recess., 'brady'],
#  ["There's
#   nobody here, 'brady'],
#  [but you and I., 'brady'],
#  [We are alone together, as we shall be
#   hereafter, when we have taken the step."
#   , 'brady'],
#  ["But that child," whispered the woman, "with his strange vesture and
#   his wonderful face., 'brady'],
#  [His eyes look at me so."
#   , 'brady'],
#  ["There is no child there, my dear," urged the man; "you are overwrought,
#   excited, nervous., 'brady'],
#  [The music starts., 'brady'],
#  [Let us go."
#   , 'brady'],
#  [He stretched out his hand to the woman, but as he came nearer she shrank
#   back with her own hand on her heart.
#   , 'brady'],
#  ["Oh," she said faintly, "he's gone."
#   , 'brady'],
#  ["Of course he's gone," he answered soothingly. ", 'brady'],
#  [Now is our time to get
#   away., 'brady'],
#  [Let me--"
#
#   "No, no," said the woman., 'brady'],
#  ["I can't go with you now., 'brady'],
#  [It wouldn't be
#   right."
#   , 'brady'],
#  ["But you knew that before," pleaded the man. ", 'brady'],
#  [Besides--"
#   , 'brady'],
#  ["Yes, but I can't do it., 'brady'],
#  [He was there!, 'brady'],
#  [His eyes spoke--I--don't touch
#   me," she said; "I'm going back to my husband., 'brady'],
#  [Don't follow."
#
#
#
#   , 'brady'],
#  [II
#
#   The Child
#
#
#
#
#   "SUFFER THE LITTLE CHILDREN TO COME UNTO ME"
#
#
#
#
#   II
#   , 'brady'],
#  [The Child
#
#   , 'brady'],
#  [The employees had all gone home, carrying with them Christmas checks and
#   hearty greetings from the great man whose beck and nod they followed.,
#   'brady'],
#  [He
#   sat in his private office absolutely alone., 'brady'],
#  [He had some serious matters
#   to consider and did not want any interruptions., 'brady'],
#  [His balance-sheet for
#   the year had been made up according to the custom of the firm before
#   Christmas instead of on New Year's Day., 'brady'],
#  [He examined it again., 'brady'],
#  [It showed
#   tremendous profit., 'brady'],
#  [The mills were turning out quantities of material,
#   the demand for which was greater and the cost of production less than
#   ever before.
#   , 'brady'],
#  ["I tell you," said the man to himself, "it was a master-stroke to
#   displace the men with children in the mills., 'brady'],
#  [They have reduced the cost
#   by four fifths., 'brady'],
#  [War has made the prices go up., 'brady'],
#  [This is not wealth, it is
#   riches beyond calculation."
#   , 'brady'],
#  [He picked up a letter, read it over., 'brady'],
#  [It was a proposal from the
#   superintendent to clear more land, to build more buildings, to install
#   more machines, to employ more children and increase the profits greatly.
#   , 'brady'],
#  ["I'll do it," said the man., 'brady'],
#  ["We can crush opposition absolutely., 'brady'],
#  [I'll
#   control the markets of the world., 'brady'],
#  [I'll build a fortune upon this
#   foundation so great that no one can comprehend it."
#   , 'brady'],
#  [He stopped, leaned back in his chair, lifted his eyes up toward the
#   ceiling of the room and saw beyond it the kingdoms of this world and the
#   means unlimited to make him lord and master., 'brady'],
#  [He gave no thought to the
#   foundations, only to the structure erected by his fancy., 'brady'],
#  [How long he
#   indulged in dreams he scarcely realized, but presently he put his hands
#   on the arms of the chair and started to rise, saying,
#
#   "I'll telegraph the superintendent to go ahead."
#   , 'brady'],
#  [He had scarcely formulated the words when right in front of him, seated
#   on his desk, he saw a young lad regarding him intently., 'brady'],
#  [He stopped,
#   petrified, in the position he had assumed.
#   , 'brady'],
#  ["How did you get in?, 'brady'],
#  [What are you doing here?, 'brady'],
#  [" he asked., 'brady'],
#  [There was no
#   answer. ", 'brady'],
#  [Come," said the man, shrinking back., 'brady'],
#  ["I can't imagine how you
#   got in here., 'brady'],
#  [If my people had not all gone I should hold them to strict
#   account., 'brady'],
#  [As it is, you--"
#   , 'brady'],
#  [The room was suddenly filled with people., 'brady'],
#  [They came crowding through the
#   walls from every side and pressed close to him., 'brady'],
#  [Such people he had never
#   seen: wan, worn, stunted, pinched, starved, joyless., 'brady'],
#  [They were all
#   children, meagerly clothed, badly nourished, ill developed., 'brady'],
#  [They were
#   quite silent., 'brady'],
#  [They did not cry., 'brady'],
#  [They did not protest., 'brady'],
#  [They did not
#   argue., 'brady'],
#  [They did not plead., 'brady'],
#  [They did not laugh., 'brady'],
#  [They just looked at him., 'brady'],
#  [They made no sound of any sort., 'brady'],
#  [He had children of his own and he had
#   known many children., 'brady'],
#  [He had never known so many gathered together
#   without a smile or a laugh.
#   , 'brady'],
#  [His eye wandered around the room., 'brady'],
#  [They were very close to him and, 'brady'],
#  [yet
#   they did not touch him., 'brady'],
#  [He turned to the desk where the lad had sat, but
#   he was no longer there, 'brady'],
#  [and yet he well remembered his face., 'brady'],
#  [He knew
#   exactly how he looked., 'brady'],
#  [He turned to the nearest child and in some
#   strange way, although the poor, wretched face had not changed, his look
#   suggested the lad who had been his first visitor., 'brady'],
#  [He turned to another
#   and another., 'brady'],
#  [They all looked back at him in the same way with the same
#   eyes.
#   , 'brady'],
#  [He threw his head up again and saw the castle of success of which he had
#   dreamed., 'brady'],
#  [He looked down again., 'brady'],
#  [This was the foundation., 'brady'],
#  [Slowly his hand
#   went to the desk., 'brady'],
#  [The little crowding figures drew back to give him
#   freedom of movement as he stretched his hand out for a telegraph-blank.,
#   'brady'],
#  [He drew it to him., 'brady'],
#  [He seized a pen and wrote rapidly:
#
#   "Build no more mills, take the children out of those already in
#   operation, put men in their places., 'brady'],
#  [We will be content with less profit
#   in the future."
#   , 'brady'],
#  [He read over the telegram., 'brady'],
#  [The telephone was close at hand., 'brady'],
#  [He called up
#   the telegraph-office, dictated it and directed it to be sent
#   immediately., 'brady'],
#  [He had been so engrossed in this task that he had noticed
#   nothing else., 'brady'],
#  [Now he looked up., 'brady'],
#  [The room was still filled with children,
#   but they were all laughing., 'brady'],
#  [It was a soundless laugh, and yet he heard
#   it., 'brady'],
#  [And then the room was empty save for the child he had seen first and
#   vaguely., 'brady'],
#  [He had just time to catch a smile from his lips and then he,
#   too, was gone as silently and as strangely as he had appeared.
#   , 'brady'],
#  [Was it a dream?, 'brady'],
#  [No, there was the telegram in his hand!, 'brady'],
#  [Had he sent it?, 'brady'],
#  [Again he called up the office on the telephone.
#   , 'brady'],
#  ["Did you get a message from me just a minute ago?, 'brady'],
#  ["
#   , 'brady'],
#  ["Yes, do you want to recall it?"
#   , 'brady'],
#  [The man thought a second.
#   , 'brady'],
#  ["No," he said quietly--was it to himself or to his vanished
#   visitors?--"let it go., 'brady'],
#  [Merry Christmas."
#
#
#
#
#   III
#   , 'brady'],
#  [The Friend
#
#
#
#
#   "INASMUCH AS YE HAVE DONE IT UNTO ONE OF THE LEAST OF THESE, MY
#   BRETHREN"
#
#
#
#
#   III
#   , 'brady'],
#  [The Friend
#
#
#   "Is the story of the Christ Child true, Mommy?", 'brady'],
#  [quivered one little,
#   thin voice.
#   , 'brady'],
#  ["Yes, they told us it was over at the mission Sunday-school," said the
#   littlest child.
#   , 'brady'],
#  ["I don't believe it," answered the mother., 'brady'],
#  ["God ain't never done much
#   for me."
#   , 'brady'],
#  ["It's Christmas eve, ain't it?", 'brady'],
#  [asked the boy, climbing up on the thin
#   knees of the threadbare woman and nestling his thin face against a
#   thinner breast which the rags scarcely covered decently.
#   , 'brady'],
#  ["Yes, it's Christmas eve."
#   , 'brady'],
#  ["And that's the day He came, ain't it?" urged the oldest girl.
#   , 'brady'],
#  ["They say so."
#   , 'brady'],
#  ["Don't you believe it, Mommy?"
#   , 'brady'],
#  ["I used to believe it when I was a girl., 'brady'],
#  [I believed it before your
#   father died, but now--"
#
#   "Don't you believe it now?" repeated the first child.
#   , 'brady'],
#  ["How can I believe it?, 'brady'],
#  [You're old enough to understand., 'brady'],
#  [That's the last
#   scuttle of coal we got., 'brady'],
#  [We ate the last bit of bread for supper
#   to-night."
#   , 'brady'],
#  ["They say," put in the little boy, "that if you hang up your stockings,
#   Santa Claus'll fill 'em, 'cause of the Christ Child."
#   , 'brady'],
#  ["Don't you believe it, Sonny," said the mother desperately.
#   , 'brady'],
#  ["I'm going to hang up mine and see," said the littlest girl.
#   , 'brady'],
#  ["He's got too many other children to look after," said the woman, "to
#   care for the likes of us,, 'brady'],
#  [I'm afraid, and--"
#   , 'brady'],
#  ["But my Sunday-school teacher said He came to poor people special., 'brady'],
#  [He
#   was awful poor Himself., 'brady'],
#  [Why, He was born in a stable., 'brady'],
#  [That's awful poor,
#   ain't it?" asked the boy.
#   , 'brady'],
#  ["When I was a girl," answered the mother, "I lived on a farm and we had
#   a stable there that was a palace to this hole we live in now., 'brady'],
#  [No, you'd
#   better not hang up your stockings, none of you."
#   , 'brady'],
#  ["And you don't believe in Him, Mommy?"
#   , 'brady'],
#  ["No., 'brady'],
#  [What would be the use if you hung 'em up and didn't find anything
#   in 'em in the morning?"
#   , 'brady'],
#  ["It'd be awful, but I believe in Him," said the littlest girl., 'brady'],
#  ["I don't
#   think God has forgot us, really., 'brady'],
#  [I'm going to try."
#   , 'brady'],
#  ["I tell you 'tain't no use."
#   , 'brady'],
#  ["Oh, yes, it is."
#   , 'brady'],
#  ["I'm sure it ain't., 'brady'],
#  [But have it your own way," said the woman., 'brady'],
#  ["If
#   someone would fill your stockings with milk and bread and--"
#
#   "I want a turkey," said the oldest girl.
#   , 'brady'],
#  ["And cranberry sauce," added the boy.
#   , 'brady'],
#  ["I want a doll-baby in mine," said the littlest girl.
#   , 'brady'],
#  [The mother hid her face and groaned aloud.
#   , 'brady'],
#  ["You ain't sick, are you, Mommy?"
#   , 'brady'],
#  ["I guess so., 'brady'],
#  [Come, you'd better say your prayers and go to bed., 'brady'],
#  [We don't
#   have to keep the fire going so hard when you're all covered up."
#   , 'brady'],
#  [It did not take long for the three little youngsters to divest
#   themselves of the rags of clothing they wore., 'brady'],
#  [They slept in what passed
#   for their underclothes, so there was no donning of white gowns for the
#   night.
#   , 'brady'],
#  ["Here are our stockings, Mommy," said the oldest, handing three ragged,
#   almost footless, black stockings to the woman.
#   , 'brady'],
#  ["It's no use, I tell you., 'brady'],
#  [I can't do it."
#   , 'brady'],
#  ["It won't do any harm, Mommy," urged the girl.
#   , 'brady'],
#  ["Do you believe in it, too?" asked the mother, and the girl shook her
#   head., 'brady'],
#  ["You won't be disappointed in the morning if there's nothing in
#   'em?"
#   , 'brady'],
#  ["No, I suppose it will be because Santa Claus was too busy."
#   , 'brady'],
#  [With nervous fingers the woman hung the three stockings near the window.,
#   'brady'],
#  [She was hungry, she was cold,, 'brady'],
#  [she was broken, she was a mother., 'brady'],
#  [She
#   could scarcely keep from crying.
#   , 'brady'],
#  ["Maybe you'll be glad you did it," said the littlest girl drowsily.
#   , 'brady'],
#  ["Ain't you comin' to bed, too, Mommy?" asked the oldest, beneath the
#   covers over the mattress on the floor.
#   , 'brady'],
#  [", 'brady'],
#  [In a little while."
#   , 'brady'],
#  ["And you won't forget to say your prayers?"
#   , 'brady'],
#  ["I ain't said 'em for months, ever since your father was killed, and we
#   got so poor."
#   , 'brady'],
#  ["But you'll say 'em to-night 'cause it's Christmas eve?"
#   , 'brady'],
#  ["Yes, to-night," said the mother; "now you go to sleep., 'brady'],
#  ["
#
#   "Are you waitin' for him to come, Mommy?" asked the littlest girl, who
#   was very sleepy.
#   , 'brady'],
#  ["Yes," said the mother.
#   , 'brady'],
#  [Presently, as she sat in the dark, having turned out the light, the deep
#   breathing of the children told her they were asleep., 'brady'],
#  [She rose quietly,
#   stepped to the window, and stood looking at the three shapeless,
#   tattered stockings., 'brady'],
#  [She was high up in the tenement and the moonlight
#   came softly over the house roofs of the city into the bare, cold,
#   cheerless room., 'brady'],
#  [She stared at the stockings and tears streamed down her
#   wasted cheeks., 'brady'],
#  [She had hung them low at the suggestion of the littlest
#   girl so the children could easily get at them in the morning.
#   , 'brady'],
#  [[Illustration:, 'brady'],
#  [She pressed them against her face.]
#   , 'brady'],
#  [After a time she fell down on her knees., 'brady'],
#  [She pressed them against her
#   face., 'brady'],
#  [She did not say anything., 'brady'],
#  [She could scarcely think anything., 'brady'],
#  [She
#   just knelt there until something gently drew her head around., 'brady'],
#  [She
#   dropped the stockings., 'brady'],
#  [She put her right hand on the window-ledge to
#   steady herself and looked backward.
#   , 'brady'],
#  [No sound save the breathing of the children and her own stifled sobs had
#   broken the silence; the door was shut, but a man was there, a man of
#   strange vesture seen dimly in the moon's radiance, yet there was a kind
#   of light about his face., 'brady'],
#  [She could see his features., 'brady'],
#  [They were those of
#   a man in middle years., 'brady'],
#  [They were lined with care., 'brady'],
#  [He had seen life on
#   its seamy side., 'brady'],
#  [The woman felt that he had known poverty and loneliness., 'brady'],
#  [She stared up at him.
#   , 'brady'],
#  ["I didn't believe," she whispered; "it cannot be., 'brady'],
#  [I thought we were
#   forgotten."
#   , 'brady'],
#  [The man slowly raised his hand., 'brady'],
#  [The moonlight struck fair upon it., 'brady'],
#  [She
#   saw that it was calloused, the hand of a man who toiled., 'brady'],
#  [It was extended
#   over her head., 'brady'],
#  [There was no bodily touch, but her head bent low down
#   until she rested it upon her hands upon the floor., 'brady'],
#  [When she looked up,
#   the room was empty., 'brady'],
#  [There was no sound save the breathing of the
#   children and the throb of her own heart which beat wildly in the fearful
#   hollow of her ear.
#   , 'brady'],
#  [She heard a sound of strange footsteps outside the door., 'brady'],
#  [There was a
#   crackle as of paper, the soft sound of things laid upon the floor, a
#   gentle rapping on the panels, a light laugh, a rustle of draperies,
#   footsteps moving away., 'brady'],
#  [As in a dream she got to her feet, she knew not
#   how., 'brady'],
#  [She opened the door.
#   , 'brady'],
#  [The hall was dimly illuminated., 'brady'],
#  [Her feet struck a little heap of
#   joy-bringing parcels., 'brady'],
#  [She leaned back against the door-jamb, her hand
#   to her heart, trembling., 'brady'],
#  [What could it mean?
#   , 'brady'],
#  [A tiny voice broke the silence., 'brady'],
#  [It was the littlest girl turning over in
#   her sleep, murmuring incoherently and then clearly:
#
#   "If you only believe, that's enough; if you only believe."
#
#
#
#
#   IV
#   , 'brady'],
#  [The Workman
#
#   "IS NOT THIS THE CARPENTER?"
#
#
#
#
#   IV
#   , 'brady'],
#  [The Workman
#
#   , 'brady'],
#  [In the mean squalid room back of the saloon half a score of men were
#   assembled., 'brady'],
#  [They were all young in years, in other things not youthful., 'brady'],
#  [Some of them lounged against the wall., 'brady'],
#  [Some sat at tables., 'brady'],
#  [All were
#   drinking., 'brady'],
#  [The air was foul with smoke and reeked with the odor of vile
#   liquor.
#   , 'brady'],
#  ["We've got two jobs on hand to-night," said the leader of the gang.,
#   'brady'],
#  ["There's a crib to be cracked an' a guy to be croaked., 'brady'],
#  [Red, you an'
#   Gypsie an' the Gunney will crack the crib., 'brady'],
#  [It's dead easy., 'brady'],
#  [Only an old
#   man an' his wife., 'brady'],
#  [The servants are out except one an' he's fixed., 'brady'],
#  [I'll
#   give you the layout presently., 'brady'],
#  [The other job's harder., 'brady'],
#  [Kid, I'll put you
#   in charge, an' as it's got to be done early to-night, 'brady'],
#  [I'll give you the
#   orders now., 'brady'],
#  [He'll be at The Montmorency at ten o'clock., 'brady'],
#  [Someone will
#   call him out to the street."
#   , 'brady'],
#  ["Who?"
#   , 'brady'],
#  ["Never mind who., 'brady'],
#  [You'll be there in the car."
#   , 'brady'],
#  ["Whose car?"
#   , 'brady'],
#  ["Never mind whose., 'brady'],
#  [Why're you askin' so many questions?, 'brady'],
#  [It'll take you
#   an' the four to The Montmorency at ten o'clock., 'brady'],
#  [When he comes out every
#   one of you let go, the whole bunch, understand., 'brady'],
#  [If they don't find five
#   bullets in him there'll be trouble to-morrow., 'brady'],
#  ["
#   , 'brady'],
#  ["What do we get out of it?"
#   , 'brady'],
#  ["A hundred apiece fer you an' a hundred an' fifty fer me fer engineerin'
#   the job., 'brady'],
#  [Christmas money!, 'brady'],
#  [You get me?"
#   , 'brady'],
#  ["Of course., 'brady'],
#  [How'll we know who we've got to shoot?"
#   , 'brady'],
#  ["I'll be there myself on the sidewalk., 'brady'],
#  [I'll point him out to you."
#   , 'brady'],
#  ["The police?"
#   , 'brady'],
#  ["They're fixed."
#   , 'brady'],
#  ["Easy enough," said the Kid, the youngest of the gang.
#   , 'brady'],
#  ["Well, you guys," said the leader pointing out four of the men, "will go
#   with the Kid., 'brady'],
#  [The car'll be at the door in half an hour."
#   , 'brady'],
#  ["Now, gimme my orders," said Red.
#   , 'brady'],
#  [The gang leader scribbled something on a bit of paper.
#   , 'brady'],
#  ["You go to that number with these two guys between midnight an' two in
#   the mornin'., 'brady'],
#  [You'll find a back winder open., 'brady'],
#  [Here's the combination of
#   the safe., 'brady'],
#  [The silver'll be in that."
#   , 'brady'],
#  ["Jewels?"
#   , 'brady'],
#  ["In a wall cabinet upstairs., 'brady'],
#  [It'll be unlocked."
#   , 'brady'],
#  ["An' if they make any noise?"
#   , 'brady'],
#  ["Croak 'em, of course., 'brady'],
#  [But don't make no noise doin' it., 'brady'],
#  [Better use a
#   blackjack., 'brady'],
#  [We're not sure about the cop on that beat."
#   , 'brady'],
#  ["I understand."
#   , 'brady'],
#  ["Well, git your gats and make ready., 'brady'],
#  [Before we go, the drinks'll be on
#   me., 'brady'],
#  [Fill up, men," he added, first pouring himself a liberal glassful,
#   "an' here's to bringin' it off easy."
#   , 'brady'],
#  [With deep relish the toast was drunk by all save Red and the Kid., 'brady'],
#  [Red
#   set his glass down on the table., 'brady'],
#  [The Kid dropped his to the floor.
#   , 'brady'],
#  ["There's somebody else in the room," whispered Red.
#   , 'brady'],
#  ["Yes, yonder by the door," said the Kid., 'brady'],
#  ["You c'n jest see him."
#   , 'brady'],
#  ["Don't be a fool," said the gang leader., 'brady'],
#  ["There's nobody here but us."
#   , 'brady'],
#  ["He's wearin' strange clothes," said Red.
#   , 'brady'],
#  ["He looks like a carpenter by his kit o' tools," said the Kid.
#
#   "Here, pull yourselves together, men," said the gang leader;, 'brady'],
#  ["you're
#   dippy, there's nobody here., 'brady'],
#  [Where's your nerve?"
#   , 'brady'],
#  [But Red made no move to obey., 'brady'],
#  [He thrust his glass from him and rose and
#   leaned over the table staring., 'brady'],
#  [The other men shrank back glancing at the
#   two figures, for the Kid had also dashed the proffered glass aside.
#   , 'brady'],
#  ["I see him," he said, "he's lookin' at me, he's lookin' through me."
#   , 'brady'],
#  [In his excitement he took a step forward and the table went over with a
#   crash., 'brady'],
#  [The two men passed their hands over their eyes in bewilderment.
#   , 'brady'],
#  ["Why, there ain't nobody here," said the Kid.
#   , 'brady'],
#  ["But I seen him I tell you," persisted Red.
#   , 'brady'],
#  ["And so did I."
#
#   "Well, he's gone, whoever he was, accordin' to your own showin'," said
#   the gang leader contemptuously. ", 'brady'],
#  [Now brace up., 'brady'],
#  [Take your liquor., 'brady'],
#  [Get a
#   move on youse."
#   , 'brady'],
#  ["Not me," exclaimed Red suddenly.
#   , 'brady'],
#  ["Nor me," said the Kid, 'brady'],
#  [.
#
#   ", 'brady'],
#  [What d'ye mean?"
#   , 'brady'],
#  ["I won't do it."
#   , 'brady'],
#  ["Neither will I."
#
#   Both men moved to the door., 'brady'],
#  [The gang leader sprang to intercept them,, 'brady'],
#  [his arms upraised, his hands clenched.
#   , 'brady'],
#  ["Lemme pass," said Red.
#   , 'brady'],
#  ["Are you goin' to give us away?"
#   , 'brady'],
#  ["No," answered Red. ", 'brady'],
#  [But you don't rob no house, an' you don't kill no
#   man to-night."
#   , 'brady'],
#  ["You all know what that means," cried the leader. ", 'brady'],
#  [Here you men grab
#   'em."
#   , 'brady'],
#  [But the rest of the gang hung back.
#   , 'brady'],
#  ["Mebbe they did see somethin'," said one.
#   , 'brady'],
#  ["You cowardly dogs," cried the leader.
#   , 'brady'],
#  ["We won't mention no names to nobody," said the Kid, "but you can't
#   pull them jobs off., 'brady'],
#  [We'll jest warn 'em."
#   , 'brady'],
#  ["You swore you'd be true to the gang, that you'd obey orders an' follow
#   directions."
#   , 'brady'],
#  ["We won't give ye away, 'brady'],
#  [but I'm goin' to quit the gang an' go to work,"
#   said Red.
#   , 'brady'],
#  ["Me too," said the Kid.
#
#   "Work!, 'brady'],
#  [Hell!", 'brady'],
#  [exclaimed the gang leader, but they shoved him out of the
#   way and went out of the door.
#
#
#
#   , 'brady'],
#  [V
#
#   Comforter
#
#
#
#   , 'brady'],
#  ["NEITHER DO, 'brady'],
#  [I CONDEMN THEE"
#
#
#
#
#   V
#   , 'brady'],
#  [The Comforter
#
#   , 'brady'],
#  [She was a daughter of shame., 'brady'],
#  [Even inexperience could see that as she
#   wandered up and down the streets of the town, desperate, impelled to go
#   on by a force too strong for her to resist., 'brady'],
#  [She trod the pavement, yet
#   loathed the necessity and hated herself for her compliance., 'brady'],
#  [She had only
#   to look forward to the jail or the hospital; yet there was always the
#   river., 'brady'],
#  [Had it come to that?, 'brady'],
#  [Was there nothing else?
#   , 'brady'],
#  [She lifted her eyes from the stone walk as hard as the heart of the
#   world, and found herself opposite a brightly lighted building., 'brady'],
#  [She
#   leaned against the door., 'brady'],
#  [From within came the sound of music, the
#   strains of a hymn, words of prayer., 'brady'],
#  [The light streamed about her face
#   from the stained window., 'brady'],
#  [This was a Church of God., 'brady'],
#  [Stained window,
#   stained woman, confronting each other in the night!
#   , 'brady'],
#  [There was no God for her., 'brady'],
#  [There might have been once, but she had
#   committed the unpardonable sin against society and society was God.,
#   'brady'],
#  [There was no place for her anywhere, save the jail or the hospital or
#   the river., 'brady'],
#  [That last was the best., 'brady'],
#  [The street was deserted., 'brady'],
#  [She had
#   thought it not a good place in which to ply her trade!, 'brady'],
#  [She made a step
#   forward and stopped.
#   , 'brady'],
#  [In her pathway stood a figure seen dimly in the darkness., 'brady'],
#  [It stood in
#   the shadow beyond the broad light from the painted window., 'brady'],
#  [There was
#   something strangely familiar about it., 'brady'],
#  [She glanced up at that window., 'brady'],
#  [Had the figure there stepped down and embodied itself vaguely on the
#   walk before her?
#   , 'brady'],
#  [[Illustration:, 'brady'],
#  [She laid her hand upon the knob of the church door.]
#   , 'brady'],
#  [What was this strange figure?, 'brady'],
#  [Who was he?, 'brady'],
#  [As she stared, the outline
#   drew nearer., 'brady'],
#  [A man vested in long white draperies confronted her., 'brady'],
#  [He was
#   bareheaded and appeared insensible to the cold in which she shivered.,
#   'brady'],
#  [She put out her hand and something folded it back upon her breast., 'brady'],
#  [She
#   opened her lips and something sealed them.
#   , 'brady'],
#  [As she watched, the figure slowly moved., 'brady'],
#  [It bent forward and went slowly
#   down on its knees on the sidewalk., 'brady'],
#  [The white hand began to trace
#   strange, mysterious, unknown, incomprehensible characters upon the
#   pavement., 'brady'],
#  [She watched with bated breath, some memory of another sinful
#   woman of whom she had heard in childhood coming back to her prostrate
#   mind., 'brady'],
#  [Yes, and there behind the figure stood others, hateful and hating,
#   very violent, passionate men., 'brady'],
#  [She stared from the handwriting in the
#   dust to these others and they faded away., 'brady'],
#  [She was alone with the
#   kneeling figure and, as she looked, it too vanished in the chill air.
#   , 'brady'],
#  [She bent over the pavement., 'brady'],
#  [There was nothing there, yet she had
#   received a message., 'brady'],
#  [After a last glance she turned away, new courage,
#   new life, new hope in her heart.
#   , 'brady'],
#  [She mounted the steps, she laid her hand upon the knob of the church
#   door, she turned it and went bravely within.
#
#
#
#   , 'brady'],
#  [VI
#   , 'brady'],
#  [The Burden Bearer
#
#   "HE, BEARING HIS CROSS, WENT FORTH"
#
#
#
#
#   VI
#   , 'brady'],
#  [The Burden Bearer
#
#   , 'brady'],
#  [The sound of the running feet of the man smashing through the burned
#   stubble ceased abruptly., 'brady'],
#  [He stopped at the threshold of the door., 'brady'],
#  [No
#   friendly bark of dog welcomed him., 'brady'],
#  [From the barn there came no gentle
#   lowing of cattle, no homely clucking of chickens., 'brady'],
#  [Like the house the
#   byre too had been ruined, gutted with flame.
#   , 'brady'],
#  [The soldier whose march had brought him back to his own village that
#   night stood in the entrance of what had been his home and stared at the
#   smoking walls, the charred roof gaping to the sky, the empty casements.,
#   'brady'],
#  [The enemy had been there., 'brady'],
#  [He whispered his young wife's name, he called
#   softly to the baby, as if they might be sleeping somewhere within the
#   devastated house., 'brady'],
#  [He listened for a reply but none came., 'brady'],
#  [Perhaps he
#   would have been thankful even for a groan or a cry of agony, anything
#   that meant life., 'brady'],
#  [But all was silence within, without.
#   , 'brady'],
#  [Yonder on the winding road at the foot of the hill, 'brady'],
#  [he could hear the
#   trampling of men, the groaning of wheels, the clank of iron cavalrymen,
#   the jingling of bits and swords, sharp words of command., 'brady'],
#  [The army was
#   advancing., 'brady'],
#  [He could delay no longer., 'brady'],
#  [He must get back to his place in
#   the ranks., 'brady'],
#  [Summoning his courage he crossed the threshold and stepped
#   into the vacant emptiness of the house., 'brady'],
#  [Everything was gone but the four
#   stone walls., 'brady'],
#  [There were unrecognizable heaps of ashes here and there., 'brady'],
#  [He
#   bent over them fearfully in the twilight wondering whether the
#   shapeless, formless masses, 'brady'],
#  [were--
#
#   Something caught his eye., 'brady'],
#  [The one thing intact apparently., 'brady'],
#  [He stooped
#   over it., 'brady'],
#  [It was the baby's shoe--white, it had been originally., 'brady'],
#  [He
#   remembered it., 'brady'],
#  [Now it was stained with blood., 'brady'],
#  [That was all that was
#   left--a little baby's shoe, blood spotted., 'brady'],
#  [He pressed it to his heart
#   and groaned aloud., 'brady'],
#  [A spasm of mortal anguish shook his frame., 'brady'],
#  [He lifted
#   his clenched hand toward the sky overshadowing the roofless walls.
#   , 'brady'],
#  [Now he suddenly became aware that he was not alone., 'brady'],
#  [There was someone
#   else in the room., 'brady'],
#  [He saw vaguely, indistinctly, a figure strangely clad,
#   staggering on with bended back as if under some crushing load., 'brady'],
#  [He stared
#   in the twilight striving to concentrate his faculties., 'brady'],
#  [The figure passed
#   by., 'brady'],
#  [On its back was a shadowy something--beams of wood roughly crossed,
#   he decided., 'brady'],
#  [It raised its head and looked at him., 'brady'],
#  [The face was somehow
#   lighter than the rest.
#   , 'brady'],
#  [The man's arm fell., 'brady'],
#  [The room was empty after all., 'brady'],
#  [He stared at the
#   little shoe., 'brady'],
#  [Was it somewhere well with the child, with its mother?, 'brady'],
#  [Unbuttoning his tunic he thrust the little shoe within, over his heart.,
#   'brady'],
#  [He straightened up., 'brady'],
#  [Away off on the road a bugle call rang out above the
#   tumult., 'brady'],
#  [He turned away, seized his rifle, shouldered it, stepped rapidly
#   toward his regiment and his duty.
#
#
#
#
#   VII
#   , 'brady'],
#  [The Thorn Crowned
#
#   "THE SOLDIERS PLATTED A CROWN OF THORNS AND PUT IT ON HIS HEAD"
#
#
#
#
#   VII
#   , 'brady'],
#  [The Thorn Crowned
#
#   , 'brady'],
#  [It was ghastly cold in the ruined church., 'brady'],
#  [It had been warm enough there
#   during the day, but the fire that had gutted it had died like the young
#   acolyte, like the aged sacristan, the venerable mother, the sweet young
#   novice, the women who had sought shelter there in vain., 'brady'],
#  [Neither the
#   dignity of age nor the sweetness of maidenhood nor the innocence of
#   youth nor the sanctity of profession had availed.
#   , 'brady'],
#  [The old priest was glad they were dead., 'brady'],
#  [Life after what they had
#   suffered had been unthinkable., 'brady'],
#  [He thanked God for that oblivion., 'brady'],
#  [He
#   wished that he, too, might die in that violated shrine where he had
#   peacefully ministered for so long a time., 'brady'],
#  [They had taken the flock, the
#   shepherd must follow., 'brady'],
#  [He should have led.
#   , 'brady'],
#  [He had fought, oh, he had played the man for the honor of the poor lambs
#   committed to him., 'brady'],
#  [Had he done right?, 'brady'],
#  [Should he not have stood dumb
#   before the shearers?, 'brady'],
#  [They had shot him and stabbed him and beaten him
#   into insensibility., 'brady'],
#  [The last thing he had heard was the shriek of one
#   woman, the piteous appeal of another., 'brady'],
#  [They thought he was dead, but he
#   was living., 'brady'],
#  [Why had he not died?
#   , 'brady'],
#  [How could God be so cruel?, 'brady'],
#  [This was war., 'brady'],
#  [This ruined sanctuary, these
#   broken men and women who had sought only to serve Him!, 'brady'],
#  [Was there a God
#   indeed?, 'brady'],
#  [Faith, hope, what were they?, 'brady'],
#  [Assurance, trust?, 'brady'],
#  [Words, words!, 'brady'],
#  [Ah,
#   how he suffered.
#   , 'brady'],
#  [[Illustration: "It is He," whispered the priest. ", 'brady'],
#  [His sorrow was
#   greater than mine."]
#   , 'brady'],
#  [It was bitter cold and yet he burned with fever., 'brady'],
#  [The tremors of pain so
#   exquisite that they might almost be counted pleasure shot through his
#   ruined, torn, broken figure, yet he recked little of these., 'brady'],
#  [It was the
#   shame, the shame., 'brady'],
#  [He had been zealous for the Lord of Hosts., 'brady'],
#  [There was
#   no God., 'brady'],
#  [Men were not made in any image save that of hell., 'brady'],
#  [He could not
#   move hand or foot, but he could see., 'brady'],
#  [He could speak., 'brady'],
#  [He could curse God
#   and die.
#   , 'brady'],
#  [As his lips framed that anathema he saw vaguely the figure of a
#   stranger; a slender, wasted body, dark stains upon it in the moonlight.,
#   'brady'],
#  [It wore some kind of curious headgear., 'brady'],
#  [The man stared., 'brady'],
#  [The light was
#   reflected from the sharp points of long thorns., 'brady'],
#  [A cloth was fastened
#   about the loins., 'brady'],
#  [The figure stood very straight in the desecrated Holy
#   of Holies., 'brady'],
#  [A light seemed to come from its face., 'brady'],
#  [Its eyes looked at the
#   man with great pity., 'brady'],
#  [Slowly the figure raised its arms., 'brady'],
#  [Slowly the arms
#   extended themselves; there were blood-stains in the palms of the hands.
#   , 'brady'],
#  ["It is He," whispered the priest. ", 'brady'],
#  [His sorrow was greater than mine., 'brady'],
#  [Lord, I believe., 'brady'],
#  ["
#   , 'brady'],
#  [He knew nothing more save that a great peace had suddenly stolen around
#   him.
#
#
#
#   , 'brady'],
#  [VIII
#   , 'brady'],
#  [The Broken Hearted
#
#
#
#
#   "ONE OF THE SOLDIERS WITH, 'brady'],
#  [A SPEAR PIERCED HIS SIDE"
#
#
#
#
#   VIII
#   , 'brady'],
#  [The Broken Hearted
#
#
#   ", 'brady'],
#  [I'll get that man if I die for it," said the soldier., 'brady'],
#  ["He's found the
#   one position in the lines from which he can fire into our trenches."
#   , 'brady'],
#  ["It's easier said than done," remarked his comrade, "and the minute you
#   cross that spot you come within his range., 'brady'],
#  [He'll put a bullet through
#   you before you can level a rifle or press a trigger."
#   , 'brady'],
#  ["I'll not go that way," said the man.
#   , 'brady'],
#  ["What is your plan?"
#   , 'brady'],
#  ["You know that salient yonder on the right?, 'brady'],
#  [I'm going out of the trench
#   there."
#   , 'brady'],
#  ["When?"
#   , 'brady'],
#  ["Now., 'brady'],
#  [I'll wrap myself in white., 'brady'],
#  [That little run of coppice will cover
#   me until I get within a few feet of him, then I'll have to chance it.,
#   'brady'],
#  ["
#
#   "Wish I could help you, old man., 'brady'],
#  [I'd like to get that man., 'brady'],
#  [He's shot six
#   of the best fellows in the company and--"
#
#   "You can help me by making a diversion to attract his attention., 'brady'],
#  [Keep
#   him looking at that alley."
#   , 'brady'],
#  [A few moments later the soldier shrouded in white crept out of the
#   trench and noiselessly rolled down the slope to the bushes., 'brady'],
#  [The snow was
#   deep on the ground., 'brady'],
#  [There was no touch of color about the soldier., 'brady'],
#  [He
#   even thrust his rifle under the linen in which he had wrapped himself.,
#   'brady'],
#  [Outside the shelter of the trenches the wind blew with terrific force.,
#   'brady'],
#  [It was terribly cold., 'brady'],
#  [He had discarded his overcoat for freedom of
#   motion., 'brady'],
#  [Only his indomitable resolution kept him alive., 'brady'],
#  [He locked his
#   jaws together to keep his teeth from chattering., 'brady'],
#  [The ice-covered snow
#   under his bare hands almost blistered the flesh as he crept along.
#   , 'brady'],
#  [He intended to use the bayonet., 'brady'],
#  [If he shot the man he was stalking alarm
#   would be given and he would be riddled with bullets before he got back.,
#   'brady'],
#  [He was willing to give a life for a life if it were necessary, but he
#   was reluctant to do so if it could be avoided., 'brady'],
#  [Cold steel would be
#   better., 'brady'],
#  [Cold steel!, 'brady'],
#  [He smiled grimly., 'brady'],
#  [It would need some hot blood to
#   take the chill off the bayonet at the end of his rifle.
#   , 'brady'],
#  [Slowly, almost holding his breath lest he be noticed, he edged his way
#   along., 'brady'],
#  [He had plenty of time for thought., 'brady'],
#  [This was not so easy a job as
#   he had fancied, not the physical part, but the mental strain., 'brady'],
#  [He could
#   shoot a man who was shooting at him, he could batter a man over the head
#   who was trying to do the same to him, but this stalking a man in cold
#   blood was different somehow., 'brady'],
#  [Cold blood!, 'brady'],
#  [He laughed soundlessly at his
#   recurrent fancy., 'brady'],
#  [He went a little more slowly., 'brady'],
#  [Finally he stopped to
#   consider.
#   , 'brady'],
#  [From the nook ahead of him in which the enemy had ensconced himself came
#   a sudden rapid rattle of rifle-shots., 'brady'],
#  [His friend back in the trench was
#   doing his part., 'brady'],
#  [The man was awake--on the alert., 'brady'],
#  [It would be something
#   of a fair fight, he thought with some little satisfaction., 'brady'],
#  [He surveyed
#   the intervening space beyond the coppice., 'brady'],
#  [The men in the trenches on
#   both sides would be awake, too., 'brady'],
#  [It would take him a few seconds to cross
#   that space and get at the man he was stalking., 'brady'],
#  [Could they shoot him
#   before that?, 'brady'],
#  [There was some shelter where the enemy was., 'brady'],
#  [If the stalker
#   could get to that spot he would be protected for a moment from fire from
#   the enemy's trench.
#   , 'brady'],
#  [It would take him a second or two to cross that space., 'brady'],
#  [In a second or
#   two what might happen?, 'brady'],
#  [Well, he would have to risk that., 'brady'],
#  [At the very
#   end of the coppice he gathered himself together and rose slowly to a
#   crouching position., 'brady'],
#  [Another rain of shots came from the nook; the man's
#   rifle would be empty, he must give him no chance to reload., 'brady'],
#  [Now it would
#   be a fair fight with the bayonet.
#   , 'brady'],
#  [He threw aside the white draperies that impeded his legs and in half a
#   dozen bounds the two men were face to face.
#   , 'brady'],
#  [No shot had been fired., 'brady'],
#  [Yes, the magazine of the man's rifle was empty., 'brady'],
#  [He heard the crunch of his enemy's feet on the snow., 'brady'],
#  [He rose to his
#   feet, his bayoneted rifle extended., 'brady'],
#  [The two barrels struck with terrific
#   force., 'brady'],
#  [The men swayed, drew back for another thrust, and they were
#   suddenly aware of a mist-like figure between them, a figure draped in
#   white, lightly, diaphanously.
#   , 'brady'],
#  [They stood arrested, guns drawn back, and stared., 'brady'],
#  [The figure slowly
#   extended its arm, carrying drapery with it., 'brady'],
#  [A man's breast was bared., 'brady'],
#  [There, over the heart, was a great gaping wound, fresh, as if a broad,
#   heavy blade had pierced it.
#   , 'brady'],
#  [There was a clatter on the ice as a gun dropped and another clatter as a
#   similar weapon struck the stone opposite., 'brady'],
#  [The two men bent forward,
#   their hands outstretched., 'brady'],
#  [They took a step as if to touch the figure and
#   there was nothing there!, 'brady'],
#  [The hands met., 'brady'],
#  [They clasped warmly in the cold
#   against each other.
#   , 'brady'],
#  ["My God, what was that?" said the stalker.
#   , 'brady'],
#  ["I don't know," answered the other.
#   , 'brady'],
#  ["A pierced side!"
#   , 'brady'],
#  ["Was, 'brady'],
#  [it--"
#
#   "No., 'brady'],
#  [It couldn't be."
#   , 'brady'],
#  ["Well, we worship the same God and--"
#
#   Ah, they were seen., 'brady'],
#  [There were quick words of command from the
#   trenches, a staccato of rifle-shots, and two bodies lay side by side,
#   hands still clasped, while the snow reddened and reddened beneath them.
#   , 'brady'],
#  [And it was Christmas eve.
#
#
#
#   , 'brady'],
#  [IX
#   , 'brady'],
#  [The Forgiver of Sins
#
#
#
#
#   "I SAY UNTO, 'brady'],
#  [THEE, 'brady'],
#  [UNTIL SEVENTY TIMES SEVEN"
#
#
#
#
#   IX
#   , 'brady'],
#  [The Forgiver of Sins
#
#
#   "A Priest, for Christ's sake, a priest," moaned the man.
#   , 'brady'],
#  [A white-faced sister of charity upon whom had developed the appalling
#   task of caring for the long rows of wounded at the dressing station
#   before they were entrained and sent south to the hospital, hovered over
#   the stretcher.
#   , 'brady'],
#  ["My poor man," she whispered, "there is no priest here., 'brady'],
#  ["
#   , 'brady'],
#  ["I can't die without confession--absolution," was the answer., 'brady'],
#  ["A priest,
#   get me a priest."
#   , 'brady'],
#  [Next to and almost touching the cot on which the speaker writhed in his
#   death agony lay another man apparently in a profound stupor., 'brady'],
#  [He wore
#   the uniform of a private soldier and his eyes were bandaged., 'brady'],
#  [His face
#   had been torn to pieces by shrapnel, fragments of which had blinded him.,
#   'brady'],
#  [At that instant he came out of that stupor., 'brady'],
#  [Perhaps the familiar words
#   recalled him to himself., 'brady'],
#  [He moved his hand slightly., 'brady'],
#  [The sister saw his
#   lips tremble., 'brady'],
#  [She bent low.
#   , 'brady'],
#  ["Who seeks confession, absolution?, 'brady'],
#  [" he whispered., 'brady'],
#  ["I am a priest."
#   , 'brady'],
#  ["You are wounded, dying, father."
#   , 'brady'],
#  ["How can I die better than shriving a fellow sinner?"
#   , 'brady'],
#  [That was true., 'brady'],
#  [The heroic woman turned to the man who still kept up his
#   monotonous appeal.
#   , 'brady'],
#  ["The man next to you," she said, "dying like you, is a priest."
#   , 'brady'],
#  ["Father," cried the first man with sudden strength., 'brady'],
#  ["I must confess
#   before I die."
#   , 'brady'],
#  ["Lift me up," said the priest.
#   , 'brady'],
#  [The woman slipped her arm about his shoulders and raised him.
#   , 'brady'],
#  ["The sister?" began the other.
#   , 'brady'],
#  ["I shall be blind and deaf," said the woman.
#   , 'brady'],
#  ["Speak on," whispered the priest.
#   , 'brady'],
#  ["I have been a great sinner--there isn't time to confess all."
#   , 'brady'],
#  ["What is heaviest upon your soul, my son?"
#   , 'brady'],
#  ["A woman's fate."
#   , 'brady'],
#  ["Ah."
#   , 'brady'],
#  ["There were two who loved her--a dozen years ago--she preferred me--,
#   'brady'],
#  [I
#   took her away."
#   , 'brady'],
#  ["Did you marry her?"
#   , 'brady'],
#  ["No., 'brady'],
#  [And then we quarreled--I deserted her., 'brady'],
#  [When I came to seek her she
#   was gone--young, innocent, penniless, alone in Paris--I have sought her
#   and never found her."
#   , 'brady'],
#  ["What is your name?", 'brady'],
#  [asked the priest suddenly with a fierce note in
#   his quivering voice.
#   , 'brady'],
#  ["Father, can I be forgiven?" answered the man giving his name.
#   , 'brady'],
#  [The dying soldier stared anxiously up at his bandaged comrade, at the
#   nun who had hid her face behind the shoulder of the priest., 'brady'],
#  [He noticed
# ...
#   "BE OF GOOD CHEER; IT IS I; BE NOT AFRAID"
#
#
#
#
#   XI
#   , 'brady'],
#  [The Stiller of the Storm
#
#
#   ", 'brady'],
#  [It's Christmas eve at home," murmured the young lad after he had said
#   his prayers and tumbled into his narrow berth on the great ship., 'brady'],
#  ["I
#   suppose they're trimming the Christmas tree now and hanging up the
#   stockings., 'brady'],
#  [I wish I were there."
#   , 'brady'],
#  [He was very young to serve his country, but not too young according to
#   the standards of mankind to be a midshipman on the great steel monster
#   keeping the leaden deep., 'brady'],
#  [It was the first time he had ever been away
#   from home on Christmas day, too., 'brady'],
#  [The youngsters had all laughed and
#   joked about it in the steerage mess., 'brady'],
#  [They had promised themselves some
#   kind of a celebration in the morning, but in his own cot with no one to
#   see, a few tears which he fondly deemed unmanly would come., 'brady'],
#  [He had the
#   midnight watch and he knew that he must get some sleep, but it was a
#   long time before he closed his eyes and drifted off to dream of home and
#   his mother.
#   , 'brady'],
#  [Athwart that dream came a sudden, frightful, heart-stilling roar of
#   destruction; a hideous crash followed, a terrible rending, breaking,
#   smashing, concatenation of noises, succeeded by frightful detonations,
#   as through the gaping hole torn in the great battleship by the deadly
#   torpedo, the water rushed upon the heated boilers, the explosion of
#   which in turn ignited the magazines., 'brady'],
#  [By that deadly underwater thrust of
#   the enemy the battleship was reduced in a few moments to a disjointed,
#   disorganized, sinking mass of shapeless, formless, splintered steel.
#   , 'brady'],
#  [As the explosions ceased, from every point rose shrieks and groans and
#   cries of men in the death-agony hurled into eternity and torn like the
#   steel., 'brady'],
#  [And then the boy heard the surviving officers coolly, resolutely
#   calling the men to their stations.
#   , 'brady'],
#  [He had been thrown from his berth by the violence of the explosion.,
#   'brady'],
#  [His
#   face was cut and bleeding where he had struck a near-by stanchion., 'brady'],
#  [His
#   left arm hung useless., 'brady'],
#  [He had lain dazed on the deck for a few moments
#   until he heard the orders of his lieutenant., 'brady'],
#  [He was one of the signal
#   midshipmen stationed on the signal bridge., 'brady'],
#  [Whatever happened that was
#   the place to which to go; he still had a duty to perform.
#   , 'brady'],
#  [Picking himself up as best he could, he hurried to report to the
#   lieutenant., 'brady'],
#  [With such means as were available signals were made., 'brady'],
#  [Calls
#   for help?, 'brady'],
#  [Oh, never!, 'brady'],
#  [Warnings that the enemy's submarines were in the
#   near vicinity and that other ships should keep away.
#   , 'brady'],
#  [The captain was on the half wrecked bridge above., 'brady'],
#  [The boy noticed how
#   quiet he was, yet his voice rang over the tumult.
#   , 'brady'],
#  ["Steady, men, steady., 'brady'],
#  [Keep your stations., 'brady'],
#  [Stand by., 'brady'],
#  [Be ready."
#   , 'brady'],
#  [The old quartermaster whose business it was to tell the hours saluted
#   the captain.
#   , 'brady'],
#  ["Eight bells, sir," he said, "midnight., 'brady'],
#  [Christmas day," he added.
#   , 'brady'],
#  ["Strike them," said the captain.
#   , 'brady'],
#  [And, as clear as ever, the four couplets rang out over the chaos and the
#   disaster.
#   , 'brady'],
#  ["Christmas day," the boy murmured.
#   , 'brady'],
#  ["She's going, men," said the captain, as the cadences died away., 'brady'],
#  [", 'brady'],
#  [Save
#   yourselves., 'brady'],
#  [Abandon the ship., 'brady'],
#  ["
#   , 'brady'],
#  ["Christmas morning," said the boy., 'brady'],
#  ["I wonder what they're doing at
#   home., 'brady'],
#  ["
#
#   "Overboard with you, youngster," said the signal lieutenant; "I wish I
#   had a life-preserver for you, but--"
#
#   "Merry Christmas, sir," said the lad suddenly.
#   , 'brady'],
#  ["Good God!" said the man. ", 'brady'],
#  [Merry Christmas!, 'brady'],
#  [They will think of us at
#   home."
#   , 'brady'],
#  [What was left of the ship gave a mighty reel.
#   , 'brady'],
#  ["Quick or she'll suck you down," the officer roared, as he fairly flung
#   the boy into the water,--and how he hurt that broken arm! ", 'brady'],
#  [You can swim., 'brady'],
#  [Strike out., 'brady'],
#  [Good-by."
#   , 'brady'],
#  [The boy had caught a glimpse of the captain standing on the bridge as
#   the wreck went down and then the wild waters closed over his head., 'brady'],
#  [It
#   was frightfully cold., 'brady'],
#  [A hard gale was blowing., 'brady'],
#  [The waves ran terribly
#   high., 'brady'],
#  [His left arm was helpless., 'brady'],
#  [His head ached fiercely., 'brady'],
#  [What was the
#   use?, 'brady'],
#  [Still the boy struck out bravely with his free hand., 'brady'],
#  [The instinct
#   of life!, 'brady'],
#  [It was too dark to see., 'brady'],
#  [The sky was covered with drifting
#   clouds., 'brady'],
#  [Only here and there a little rift of moonlight came through.
#   , 'brady'],
#  ["Christmas morning," he sobbed out as the waves rolled him over. ", 'brady'],
#  [Oh, my
#   God!"
#   , 'brady'],
#  [He felt himself going down., 'brady'],
#  [All at once the waters seemed to grow still., 'brady'],
#  [It was suddenly calm., 'brady'],
#  [He was no longer cold., 'brady'],
#  [He threw his head up for
#   one last look at the sky and life, 'brady'],
#  [and then he hung, as it were, 'brady'],
#  [,
#   suspended in some strange way., 'brady'],
#  [He saw a figure walking across the smooth
#   of the seas as it had been solid ground., 'brady'],
#  [The figure drew nearer, the
#   wind seemed to have died away, but the draperies that shrouded it swung
#   gently as they would while a man walked along., 'brady'],
#  [The face he saw dimly,
#   vaguely, but there was light in it somehow., 'brady'],
#  [It came slowly nearer.
#   , 'brady'],
#  ["Christmas morning," whispered the boy.
#   , 'brady'],
#  [The hand of the figure reached down., 'brady'],
#  [It caught the boy's right arm., 'brady'],
#  [He
#   was lifted up.
#   , 'brady'],
#  ["Home and Christmas morning," whispered the boy, closing his eyes.
#   , 'brady'],
#  [The moonlight broke through a cloud and fell upon him., 'brady'],
#  [A wave rolled
#   over him and the sea was empty as before.
#
#
#          , 'brady'],
#  [*       *       *       *       *
#
#   He that hath eyes to see, let him see!
#
#
#   , 'brady'],
#  [*, 'brady'],
#  [**END OF THE PROJECT GUTENBERG EBOOK AND, 'brady'],
#  [THUS HE CAME*, 'brady'],
#  [**
#
#   , 'brady'],
#  [*****, 'brady'],
#  [*, 'brady'],
#  [* This file should be named 14606.txt or 14606.zip, 'brady'],
#  [*, 'brady'],
#  [*, 'brady'],
#  [*****
#
#
#   This and all associated files of various formats will be found in:
#   http://www.gutenberg.org/dirs/1/4/6/0/14606
#
#
#
#   Updated editions will replace the previous one--the old editions
#   will be renamed.
#   , 'brady'],
#  [Creating the works from public domain print editions means that no
#   one owns a United States copyright in these works, so the Foundation
#   (and you!), 'brady'],
#  [can copy and distribute it in the United States without
#   permission and without paying copyright royalties.  , 'brady'],
#  [Special rules,
#   set forth in the General Terms of Use part of this license, apply to
#   copying and distributing Project Gutenberg-tm electronic works to
#   protect the PROJECT GUTENBERG-tm concept and trademark.  , 'brady'],
#  [Project, 'brady'],
#  [Gutenberg is a registered trademark, and may not be used if you
#   charge for the eBooks, unless you receive specific permission.  , 'brady'],
#  [If you
#   do not charge anything for copies of this eBook, complying with the
#   rules is very easy.  , 'brady'],
#  [You may use this eBook for nearly any purpose
#   such as creation of derivative works, reports, performances and
#   research.  , 'brady'],
#  [They may be modified and printed and given away--you may do
#   practically ANYTHING with public domain eBooks.  , 'brady'],
#  [Redistribution is
#   subject to the trademark license, especially commercial
#   redistribution.
#
#
#   , 'brady'],
#  [*, 'brady'],
#  [** START:, 'brady'],
#  [FULL LICENSE, 'brady'],
#  [*, 'brady'],
#  [**
#
#   THE FULL PROJECT GUTENBERG LICENSE, 'brady'],
#  [PLEASE READ THIS, 'brady'],
#  [BEFORE YOU DISTRIBUTE OR USE, 'brady'],
#  [THIS WORK
#
#   To protect the Project Gutenberg-tm mission of promoting the free
#   distribution of electronic works, by using or distributing this work
#   (or any other work associated in any way with the phrase "Project
#   Gutenberg"), 'brady'],
#  [, you agree to comply with all the terms of the Full Project
#   Gutenberg-tm License (available with this file or online at
#   http://gutenberg.net/license).
#
#   , 'brady'],
#  [Section 1.  , 'brady'],
#  [General Terms of Use and Redistributing Project Gutenberg-tm
#   electronic works
#   , 'brady'],
#  [1.A.  , 'brady'],
#  [By reading or using any part of this Project Gutenberg-tm
#   electronic work, you indicate that you have read, understand, agree to
#   and accept all the terms of this license and intellectual property
#   (trademark/copyright) agreement.  , 'brady'],
#  [If you do not agree to abide by all
#   the terms of this agreement, you must cease using and return or destroy
#   all copies of Project Gutenberg-tm electronic works in your possession.,
#   'brady'],
#  [If you paid a fee for obtaining a copy of or access to a Project
#   Gutenberg-tm electronic work and you do not agree to be bound by the
#   terms of this agreement, you may obtain a refund from the person or
#   entity to whom you paid the fee as set forth in paragraph 1.E.8.
#   , 'brady'],
#  [1.B.  "Project Gutenberg" is a registered trademark.  , 'brady'],
#  [It may only be
#   used on or associated in any way with an electronic work by people who
#   agree to be bound by the terms of this agreement.  , 'brady'],
#  [There are a few
#   things that you can do with most Project Gutenberg-tm electronic works
#   even without complying with the full terms of this agreement.  , 'brady'],
#  [See, 'brady'],
#  [paragraph 1.C below.  , 'brady'],
#  [There are a lot of things you can do with Project
#   Gutenberg-tm electronic works if you follow the terms of this agreement
#   and help preserve free future access to Project Gutenberg-tm electronic
#   works.  , 'brady'],
#  [See paragraph 1.E below.
#   , 'brady'],
#  [1.C.  , 'brady'],
#  [The Project Gutenberg Literary Archive Foundation ("the Foundation"
#   or PGLAF), owns a compilation copyright in the collection of Project
#   Gutenberg-tm electronic works.  , 'brady'],
#  [Nearly all the individual works in the
#   collection are in the public domain in the United States.  , 'brady'],
#  [If an
#   individual work is in the public domain in the United States and you are
#   located in the United States, we do not claim a right to prevent you from
#   copying, distributing, performing, displaying or creating derivative
#   works based on the work as long as all references to Project Gutenberg
#   are removed.  , 'brady'],
#  [Of course, we hope that you will support the Project
#   Gutenberg-tm mission of promoting free access to electronic works by
#   freely sharing Project Gutenberg-tm works in compliance with the terms of
#   this agreement for keeping the Project Gutenberg-tm name associated with
#   the work.  , 'brady'],
#  [You can easily comply with the terms of this agreement by
#   keeping this work in the same format with its attached full Project
#   Gutenberg-tm License when you share it without charge with others.
#   , 'brady'],
#  [1.D.  , 'brady'],
#  [The copyright laws of the place where you are located also govern
#   what you can do with this work.  , 'brady'],
#  [Copyright laws in most countries are in
#   a constant state of change.  , 'brady'],
#  [If you are outside the United States, check
#   the laws of your country in addition to the terms of this agreement
#   before downloading, copying, displaying, performing, distributing or
#   creating derivative works based on this work or any other Project
#   Gutenberg-tm work.  , 'brady'],
#  [The Foundation makes no representations concerning
#   the copyright status of any work in any country outside the United
#   States.
#   , 'brady'],
#  [1.E.  , 'brady'],
#  [Unless you have removed all references to Project Gutenberg:
#
#   1.E.1.  , 'brady'],
#  [The following sentence, with active links to, or other immediate
#   access to, the full Project Gutenberg-tm License must appear prominently
#   whenever any copy of a Project Gutenberg-tm work (any work on which the
#   phrase "Project Gutenberg" appears, or with which the phrase "Project
#   Gutenberg" is associated) is accessed, displayed, performed, viewed,
#   copied or distributed:
#   , 'brady'],
#  [This eBook is for the use of anyone anywhere at no cost and with
#   almost no restrictions whatsoever.  , 'brady'],
#  [You may copy it, give it away or
#   re-use it under the terms of the Project Gutenberg License included
#   with this eBook or online at www.gutenberg.net
#
#   1.E.2.  , 'brady'],
#  [If an individual Project Gutenberg-tm electronic work is derived
#   from the public domain (does not contain a notice indicating that it is
#   posted with permission of the copyright holder), the work can be copied
#   and distributed to anyone in the United States without paying any fees
#   or charges.  , 'brady'],
#  [If you are redistributing or providing access to a work
#   with the phrase "Project Gutenberg" associated with or appearing on the
#   work, you must comply either with the requirements of paragraphs 1.E.1
#   through 1.E.7 or obtain permission for the use of the work and the
#   Project Gutenberg-tm trademark as set forth in paragraphs 1.E.8 or
#   1.E.9.
#   , 'brady'],
#  [1.E.3.  , 'brady'],
#  [If an individual Project Gutenberg-tm electronic work is posted
#   with the permission of the copyright holder, your use and distribution
#   must comply with both paragraphs 1.E.1 through 1.E.7 and any additional
#   terms imposed by the copyright holder.  , 'brady'],
#  [Additional terms will be linked
#   to the Project Gutenberg-tm License for all works posted with the
#   permission of the copyright holder found at the beginning of this work.
#   , 'brady'],
#  [1.E.4.  , 'brady'],
#  [Do not unlink or detach or remove the full Project Gutenberg-tm
#   License terms from this work, or any files containing a part of this
#   work or any other work associated with Project Gutenberg-tm.
#
#   1.E.5.  , 'brady'],
#  [Do not copy, display, perform, distribute or redistribute this
#   electronic work, or any part of this electronic work, without
#   prominently displaying the sentence set forth in paragraph 1.E.1 with
#   active links or immediate access to the full terms of the Project
#   Gutenberg-tm License.
#   , 'brady'],
#  [1.E.6.  , 'brady'],
#  [You may convert to and distribute this work in any binary,
#   compressed, marked up, nonproprietary or proprietary form, including any
#   word processing or hypertext form.  , 'brady'],
#  [However, if you provide access to or
#   distribute copies of a Project Gutenberg-tm work in a format other than
#   "Plain Vanilla ASCII" or other format used in the official version
#   posted on the official Project Gutenberg-tm web site (www.gutenberg.net),
#   you must, at no additional cost, fee or expense to the user, provide a
#   copy, a means of exporting a copy, or a means of obtaining a copy upon
#   request, of the work in its original "Plain Vanilla ASCII" or other
#   form.  , 'brady'],
#  [Any alternate format must include the full Project Gutenberg-tm
#   License as specified in paragraph 1.E.1.
#   , 'brady'],
#  [1.E.7.  , 'brady'],
#  [Do not charge a fee for access to, viewing, displaying,
#   performing, copying or distributing any Project Gutenberg-tm works
#   unless you comply with paragraph 1.E.8 or 1.E.9.
#   , 'brady'],
#  [1.E.8.  , 'brady'],
#  [You may charge a reasonable fee for copies of or providing
#   access to or distributing Project Gutenberg-tm electronic works provided
#   that
#
#   - You pay a royalty fee of 20% of the gross profits you derive from
#        the use of Project Gutenberg-tm works calculated using the method
#        , 'brady'],
#  ...]

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6fcf9dfbd479> in <module>
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
def text_cleaner(text):
    text=text.replace('gutenberg','')
    text=re.sub(r'ï»¿','',text)
    text=re.sub(r'\n','',text)
    text=re.sub('\[[^()]*\]','',text)
    text=re.sub('\([^()]*\)','',text)
    text=re.sub('[^\w\.\,]',' ',text)
    
    text=' '.join(text.split())
    text=text.split()
    
    return text

# %%
# Utility function to create a list of the 10 most common words.
def bag_of_words(text):
    
    # Filter out punctuation and stop words.
    allwords = [token.lemma_
                for token in text
                if not token.is_punct
                and not token.is_stop]
    
    # Return the most common words.
    return [item[0] for item in Counter(allwords).most_common(10)]

# %%
# Creates a data frame with features for each word in our common word set.
# Each value is the count of the times the word appears in each sentence.
def bow_features(sentences, common_words):
    
    # Scaffold the data frame and initialize counts to zero.
    df = pd.DataFrame(columns=common_words)
    df['text_sentence'] = sentences[0]
    df['text_source'] = sentences[1]
    df.loc[:, common_words] = 0
    
    # Process each row, counting the occurrence of words in each sentence.
    for i, sentence in enumerate(df['text_sentence']):
        
        # Convert the sentence to lemmas, then filter out punctuation,
        # stop words, and uncommon words.
        words = [token.lemma_
                 for token in sentence
                 if (
                     not token.is_punct
                     and not token.is_stop
                     and token.lemma_ in common_words
                 )]
        
        # Populate the row with word counts.
        for word in words:
            df.loc[i, word] += 1
        
        # This counter is just to make sure the kernel didn't hang.
        if i % 500 == 0:
            print("Processing row {}".format(i))
            
    return df

# %%
df = pd.DataFrame()

for i in range(len(filename)):
    text = text_creater(filename[i])
    text_clean = text_cleaner(text)
    
    text_doc=nlp(text_clean)
    text_words=bag_of_words(text_doc)

# %%
df.shape

# %%
from sklearn.preprocessing import normalize
x=df.drop(['author'],axis=1)
x=normalize(x)
y=df['author']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, 
                                                    y,
                                                    test_size=0.25,
                                                    random_state=0)

# %%
k=10
model = KMeans(n_clusters=k, init='k-means++', max_iter=100, n_init=1)
model.fit(x_train)

# %%
y_pred=model.predict(x_test)

# %%
from sklearn import metrics
    
metrics.adjusted_rand_score(y_test, y_pred)

# %%
y_pred=model.predict(x_train)
metrics.adjusted_rand_score(y_train, y_pred)

# %%
from sklearn.metrics import pairwise_distances

model.fit(x)
labels=model.labels_

score=metrics.silhouette_score(x, labels, metric='euclidean')
print(score)

# %%
from sklearn.linear_model import LogisticRegressionCV

lr = LogisticRegressionCV(cv=4)
lr.fit(x,y)
lr.score(x,y)

# %%
from sklearn import ensemble
rfc = ensemble.RandomForestClassifier()
train = rfc.fit(x_train, y_train)

print('Training set score:', rfc.score(x_train, y_train))
print('\nTest set score:', rfc.score(x_test, y_test))
