# %% [markdown]
# For this project you'll dig into a large amount of text and apply most of what you've covered in this unit and in the course so far.
#
# First, pick a set of texts. This can be either a series of novels, chapters, or articles. Anything you'd like. It just has to have multiple entries of varying characteristics. At least 100 should be good. There should also be at least 10 different authors, but try to keep the texts related (either all on the same topic of from the same branch of literature - something to make classification a bit more difficult than obviously different subjects).
#
# This capstone can be an extension of your NLP challenge if you wish to use the same corpus. If you found problems with that data set that limited your analysis, however, it may be worth using what you learned to choose a new corpus. Reserve 25% of your corpus as a test set.
#
# The first technique is to create a series of clusters. Try several techniques and pick the one you think best represents your data. Make sure there is a narrative and reasoning around why you have chosen the given clusters. Are authors consistently grouped into the same cluster?
#
# Next, perform some unsupervised feature generation and selection using the techniques covered in this unit and elsewhere in the course. Using those features then build models to attempt to classify your texts by author. Try different permutations of unsupervised and supervised techniques to see which combinations have the best performance.
#
# Lastly return to your holdout group. Does your clustering on those members perform as you'd expect? Have your clusters remained stable or changed dramatically? What about your model? Is it's performance consistent?
#
# If there is a divergence in the relative stability of your model and your clusters, delve into why.
#
# Your end result should be a write up of how clustering and modeling compare for classifying your texts. What are the advantages of each? Why would you want to use one over the other? Approximately 3-5 pages is a good length for your write up, and remember to include visuals to help tell your story!

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
filename='And Thus He Came.txt'
file=open(filename,'r')
text=file.read()
file.close
# Out:
# <function TextIOWrapper.close()>

# %%
text
# Out:
# 'ï»¿The Project Gutenberg eBook, And Thus He Came, by Cyrus Townsend Brady,\nIllustrated by Walter B. Everett\n\n\nThis eBook is for the use of anyone anywhere at no cost and with\nalmost no restrictions whatsoever.  You may copy it, give it away or\nre-use it under the terms of the Project Gutenberg License included\nwith this eBook or online at www.gutenberg.net\n\n\n\n\n\nTitle: And Thus He Came\n\nAuthor: Cyrus Townsend Brady\n\nRelease Date: January 5, 2005  [eBook #14606]\n\nLanguage: English\n\nCharacter set encoding: ISO-646-US (US-ASCII)\n\n\n***START OF THE PROJECT GUTENBERG EBOOK AND THUS HE CAME***\n\n\nE-text prepared by Robert Cicconetti, Melissa Er-Raqabi, and the Project\nGutenberg Online Distributed Proofreading Team (http://www.pgdp.net)\n\n\n\nNote: Project Gutenberg also has an HTML version of this\n      file which includes the original illustrations.\n      See 14606-h.htm or 14606-h.zip:\n      (http://www.gutenberg.net/dirs/1/4/6/0/14606/14606-h/14606-h.htm)\n      or\n      (http://www.gutenberg.net/dirs/1/4/6/0/14606/14606-h.zip)\n\n\n\n\n\nAND THUS HE CAME\n\nA Christmas Fantasy\n\nby\n\nCYRUS TOWNSEND BRADY\n\nPictures by Walter B. Everett\n\nG.P. Putnam\'s Sons\nNew York and London\nThe Knickerbocker Press\n\n1916\n\n\n\n\n\n\n\n[Illustration: "No, No," said the woman, "I can\'t go with you now."]\n\n\n\nTo the Beloved Memory\nof\nLittle Betty\n\n\n\n\nContents\n\n       I.--THE BABY\n      II.--THE CHILD\n     III.--THE FRIEND\n      IV.--THE WORKMAN\n       V.--THE COMFORTER\n      VI.--THE BURDEN BEARER\n     VII.--THE THORN CROWNED\n    VIII.--THE BROKEN-HEARTED\n      
arm. He is strangely dressed, although I see him indistinctly, vaguely, whispered the woman.  He wears a long white robe and there is a kind oflight about his face. See, he is looking at us.  I see nothing,  repeated the man in low tones.  The heat, the light,the music, have disturbed you  let me get you    I want nothing,  interposed the woman, waving the man aside and drawingaway from his arm.  Don t you see him, there  She made a step toward the center of the room. She stopped, put herhand to her head. Why, he is gone,  she exclaimed. Good,  said the man, while at that instant the room suddenly rang withcries   Go on with the music, the dance is not half over.  He extendedhis arm to the woman again.  Our dance is not finished.  Yes, it is,  she said as the flying feet once more twinkled across thepolished floor, as everybody took a long breath and a new startapparently unconscious of the pause. It is over for me. What I saw   What did you see   I don t know, but I m going back home to my child. Good night.                                         Yes, the music had stopped suddenly. The man in the farthest alcoveturned to his companion. They were hidden by a group of palms. I wonder why   queried the woman. She was deathly pale. Her eyes weredark with fear, yet alight with passionate determination. When it begins,  said  ...

# %%
text.split()
# Out:
# ['The',
#  'Project',
#  'Gutenberg',
#  'eBook,',
#  'And',
#  'Thus',
#  'He',
#  'Came,',
#  'by',
#  'Cyrus',
#  'Townsend',
#  'Brady,Illustrated',
#  'by',
#  'Walter',
#  'B.',
#  'EverettThis',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'withalmost',
#  'no',
#  'restrictions',
#  'whatsoever.',
#  'You',
#  'may',
#  'copy',
#  'it,',
#  'give',
#  'it',
#  'away',
#  'orre',
#  'use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'includedwith',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.netTitle',
#  'And',
#  'Thus',
#  'He',
#  'CameAuthor',
#  'Cyrus',
#  'Townsend',
#  'BradyRelease',
#  'Date',
#  'January',
#  '5,',
#  '2005',
#  'Language',
#  'EnglishCharacter',
#  'set',
#  'encoding',
#  'ISO',
#  '646',
#  'US',
#  'START',
#  'OF',
#  'THE',
#  'PROJECT',
#  'GUTENBERG',
#  'EBOOK',
#  'AND',
#  'THUS',
#  'HE',
#  'CAME',
#  'E',
#  'text',
#  'prepared',
#  'by',
#  'Robert',
#  'Cicconetti,',
#  'Melissa',
#  'Er',
#  'Raqabi,',
#  'and',
#  'the',
#  'ProjectGutenberg',
#  'Online',
#  'Distributed',
#  'Proofreading',
#  'Team',
#  'Note',
#  'Project',
#  'Gutenberg',
#  'also',
#  'has',
#  'an',
#  'HTML',
#  'version',
#  'of',
#  'this',
#  'file',
#  'which',
#  'includes',
#  'the',
#  'original',
#  'illustrations.',
#  'See',
#  '14606',
#  'h.htm',
#  'or',
#  '14606',
#  'h.zip',
#  'or',
#  'AND',
#  'THUS',
#  'HE',
#  'CAMEA',
#  'Christmas',
#  'FantasybyCYRUS',
#  'TOWNSEND',
#  'BRADYPictures',
#  'by',
#  'Walter',
#  'B.',
#  'EverettG.P.',
#  'Putnam',
#  's',
#  'SonsNew',
#  'York',
#  'and',
#  'LondonThe',
#  'Knickerbocker',
#  'Press1916To',
#  'the',
#  'Beloved',
#  'MemoryofLittle',
#  'BettyContents',
#  'I.',
#  'THE',
#  'BABY',
#  'II.',
#  'THE',
#  'CHILD',
#  'III.',
#  'THE',
#  'FRIEND',
#  'IV.',
#  'THE',
#  'WORKMAN',
#  'V.',
#  'THE',
#  'COMFORTER',
#  'VI.',
#  'THE',
#  'BURDEN',
#  'BEARER',
#  'VII.',
#  'THE',
#  'THORN',
#  'CROWNED',
#  'VIII.',
#  'THE',
#  'BROKEN',
#  'HEARTED',
#  'IX.',
#  'THE',
#  'FORGIVER',
#  'OF',
#  'SINS',
#  'X.',
#  'THE',
#  'GIVER',
#  'OF',
#  'LIFE',
#  'XI.',
#  'THE',
#  'STILLER',
#  'OF',
#  'THE',
#  'STORMIllustrations',
#  'NO,',
#  'NO,',
#  'SAID',
#  'THE',
#  'WOMAN,',
#  'I',
#  'CAN',
#  'T',
#  'GO',
#  'WITH',
#  'YOU',
#  'NOW',
#  'AFTER',
#  'A',
#  'TIME',
#  'SHE',
#  'FELL',
#  'DOWN',
#  'ON',
#  'HER',
#  'KNEES.',
#  'SHE',
#  'PRESSED',
#  'THEM',
#  'AGAINST',
#  'HER',
#  'FACE',
#  'SHE',
#  'LAID',
#  'HER',
#  'HAND',
#  'UPON',
#  'THE',
#  'KNOB',
#  'OF',
#  'THE',
#  'CHURCH',
#  'DOOR',
#  'IT',
#  'IS',
#  'HE,',
#  'WHISPERED',
#  'THE',
#  'PRIEST',
#  'HIS',
#  'SORROW',
#  'WAS',
#  'GREATER',
#  'THAN',
#  'MINE',
#  'ABSOLVO',
#  'TE',
#  'THE',
#  'CRY',
#  'FOR',
#  'BREADIThe',
#  'Baby',
#  'A',
#  'LITTLE',
#  'CHILD',
#  'SHALL',
#  'LEAD',
#  'THEM',
#  'IThe',
#  'BabyThe',
#  'heavy',
#  'perfume',
#  'of',
#  'rare',
#  'blossoms,',
#  'the',
#  'wild',
#  'strains',
#  'of',
#  'mad',
#  'music,',
#  'thepatter',
#  'of',
#  'flying',
#  'feet,',
#  'the',
#  'murmur',
#  'of',
#  'speech,',
#  'the',
#  'ring',
#  'of',
#  'laughter,filled',
#  'the',
#  'great',
#  'hall.',
#  'Now',
#  'and',
#  'again',
#  'a',
#  'pair',
#  'of',
#  'dancers,',
#  'peculiarlygraceful',
#  'and',
#  'particularly',
#  'daring,',
#  'held',
#  'the',
#  'center',
#  'of',
#  'the',
#  'floor',
#  'for',
#  'amoment',
#  'while',
#  'the',
#  'room',
#  'rang',
#  'with',
#  'applause.Into',
#  'alcoves,',
#  'screened',
#  'and',
#  'flower',
#  'decked,',
#  'couples',
#  'wandered.',
#  'In',
#  'thedancing',
#  'space',
#  'hands',
#  'were',
#  'clasped,',
#  'bosoms',
#  'rose',
#  'and',
#  'fell,',
#  'hearts',
#  'throbbed,pulses',
#  'beat,',
#  'and',
#  'moving',
#  'bodies',
#  'kept',
#  'time',
#  'to',
#  'rhythmic',
#  'sound.Suddenly',
#  'the',
#  'music',
#  'stopped,',
#  'the',
#  'conversation',
#  'ceased,',
#  'the',
#  'laughter',
#  'diedaway.',
#  'Almost,',
#  'as',
#  'it',
#  'were,',
#  'poised',
#  'in',
#  'the',
#  'air,',
#  'the',
#  'dancers',
#  'stood',
#  'amazed.One',
#  'looked',
#  'to',
#  'another',
#  'in',
#  'surprise.',
#  'Something',
#  'stole',
#  'throughout',
#  'the',
#  'roomwhich',
#  'was',
#  'neither',
#  'music,',
#  'nor',
#  'lights,',
#  'nor',
#  'fragrance,',
#  'but',
#  'which',
#  'waslife',
#  'a',
#  'presence',
#  'Do',
#  'you',
#  'see',
#  'that',
#  'child',
#  'asked',
#  'the',
#  'wildest',
#  'of',
#  'the',
#  'dancers',
#  'of',
#  'her',
#  'escort.',
#  'There,',
#  'she',
#  'pointed.',
#  'He',
#  'looks',
#  'like',
#  'a',
#  'very',
#  'little',
#  'boy.',
#  'I',
#  'see',
#  'nothing,',
#  'said',
#  'the',
#  'man,',
#  'who',
#  'still',
#  'held',
#  'her',
#  'in',
#  'the',
#  'clasp',
#  'of',
#  'hisarm.',
#  'He',
#  'is',
#  'strangely',
#  'dressed,',
#  'although',
#  'I',
#  'see',
#  'him',
#  'indistinctly,',
#  'vaguely,',
#  'whispered',
#  'the',
#  'woman.',
#  'He',
#  'wears',
#  'a',
#  'long',
#  'white',
#  'robe',
#  'and',
#  'there',
#  'is',
#  'a',
#  'kind',
#  'oflight',
#  'about',
#  'his',
#  'face.',
#  'See,',
#  'he',
#  'is',
#  'looking',
#  'at',
#  'us.',
#  'I',
#  'see',
#  'nothing,',
#  'repeated',
#  'the',
#  'man',
#  'in',
#  'low',
#  'tones.',
#  'The',
#  'heat,',
#  'the',
#  'light,the',
#  'music,',
#  'have',
#  'disturbed',
#  'you',
#  'let',
#  'me',
#  'get',
#  'you',
#  'I',
#  'want',
#  'nothing,',
#  'interposed',
#  'the',
#  'woman,',
#  'waving',
#  'the',
#  'man',
#  'aside',
#  'and',
#  'drawingaway',
#  'from',
#  'his',
#  'arm.',
#  'Don',
#  't',
#  'you',
#  'see',
#  'him,',
#  'there',
#  'She',
#  'made',
#  'a',
#  'step',
#  'toward',
#  'the',
#  'center',
#  'of',
#  'the',
#  'room.',
#  'She',
#  'stopped,',
#  'put',
#  'herhand',
#  'to',
#  'her',
#  'head.',
#  'Why,',
#  'he',
#  'is',
#  'gone,',
#  'she',
#  'exclaimed.',
#  'Good,',
#  'said',
#  'the',
#  'man,',
#  'while',
#  'at',
#  'that',
#  'instant',
#  'the',
#  'room',
#  'suddenly',
#  'rang',
#  'withcries',
#  'Go',
#  'on',
#  'with',
#  'the',
#  'music,',
#  'the',
#  'dance',
#  'is',
#  'not',
#  'half',
#  'over.',
#  'He',
#  'extendedhis',
#  'arm',
#  'to',
#  'the',
#  'woman',
#  'again.',
#  'Our',
#  'dance',
#  'is',
#  'not',
#  'finished.',
#  'Yes,',
#  'it',
#  'is,',
#  'she',
#  'said',
#  'as',
#  'the',
#  'flying',
#  'feet',
#  'once',
#  'more',
#  'twinkled',
#  'across',
#  'thepolished',
#  'floor,',
#  'as',
#  'everybody',
#  'took',
#  'a',
#  'long',
#  'breath',
#  'and',
#  'a',
#  'new',
#  'startapparently',
#  'unconscious',
#  'of',
#  'the',
#  'pause.',
#  'It',
#  'is',
#  'over',
#  'for',
#  'me.',
#  'What',
#  'I',
#  'saw',
#  'What',
#  'did',
#  'you',
#  'see',
#  'I',
#  'don',
#  't',
#  'know,',
#  'but',
#  'I',
#  'm',
#  'going',
#  'back',
#  'home',
#  'to',
#  'my',
#  'child.',
#  'Good',
#  'night.',
#  'Yes,',
#  'the',
#  'music',
#  'had',
#  'stopped',
#  'suddenly.',
#  'The',
#  'man',
#  'in',
#  'the',
#  'farthest',
#  'alcoveturned',
#  'to',
#  'his',
#  'companion.',
#  'They',
#  'were',
#  'hidden',
#  'by',
#  'a',
#  'group',
#  'of',
#  'palms.',
#  'I',
#  'wonder',
#  'why',
#  'queried',
#  'the',
#  'woman.',
#  'She',
#  'was',
#  'deathly',
#  'pale.',
#  'Her',
#  'eyes',
#  'weredark',
#  'with',
#  'fear,',
#  'yet',
#  'alight',
#  'with',
#  'passionate',
#  'determination.',
#  'When',
#  'it',
#  'begins,',
#  'said',
#  'the',
#  'man',
#  'tenderly,',
#  'we',
#  'will',
#  'slip',
#  'away.',
#  'My',
#  'car',
#  'isoutside.',
#  'Everything',
#  'is',
#  'ready.',
#  'That',
#  'is',
#  'my',
#  'husband',
#  'over',
#  'there,',
#  'said',
#  'the',
#  'woman.',
#  'Yes,',
#  'said',
#  'the',
#  'man,',
#  'he',
#  'won',
#  't',
#  'trouble',
#  'you',
#  'any',
#  'more.',
#  'That',
#  'woman',
#  'with',
#  'him',
#  'is',
#  'leaving',
#  'him,',
#  'she',
#  'said.',
#  'I',
#  'wonder',
#  'why.',
#  'Sheturned',
#  'suddenly',
#  'with',
#  'a',
#  'great',
#  'start.',
#  'There',
#  'is',
#  'somebody',
#  'here,',
#  'shewhispered,',
#  'staring',
#  'into',
#  'the',
#  'back',
#  'of',
#  'the',
#  'alcove.',
#  'Nonsense,',
#  'said',
#  'the',
#  'man,',
#  'throwing',
#  'a',
#  'glance',
#  'around',
#  'the',
#  'recess.',
#  'There',
#  'snobody',
#  'here',
#  'but',
#  'you',
#  'and',
#  'I.',
#  'We',
#  'are',
#  'alone',
#  'together,',
#  'as',
#  'we',
#  'shall',
#  'behereafter,',
#  'when',
#  'we',
#  'have',
#  'taken',
#  'the',
#  'step.',
#  'But',
#  'that',
#  'child,',
#  'whispered',
#  'the',
#  'woman,',
#  'with',
#  'his',
#  'strange',
#  'vesture',
#  'andhis',
#  'wonderful',
#  'face.',
#  'His',
#  'eyes',
#  'look',
#  'at',
#  'me',
#  'so.',
#  'There',
#  'is',
#  'no',
#  'child',
#  'there,',
#  'my',
#  'dear,',
#  'urged',
#  'the',
#  'man',
#  'you',
#  'are',
#  'overwrought,excited,',
#  'nervous.',
#  'The',
#  'music',
#  'starts.',
#  'Let',
#  'us',
#  'go.',
#  'He',
#  'stretched',
#  'out',
#  'his',
#  'hand',
#  'to',
#  'the',
#  'woman,',
#  'but',
#  'as',
#  'he',
#  'came',
#  'nearer',
#  'she',
#  'shrankback',
#  'with',
#  'her',
#  'own',
#  'hand',
#  'on',
#  'her',
#  'heart.',
#  'Oh,',
#  'she',
#  'said',
#  'faintly,',
#  'he',
#  's',
#  'gone.',
#  'Of',
#  'course',
#  'he',
#  's',
#  'gone,',
#  'he',
#  'answered',
#  'soothingly.',
#  'Now',
#  'is',
#  'our',
#  'time',
#  'to',
#  'getaway.',
#  'Let',
#  'me',
#  'No,',
#  'no,',
#  'said',
#  'the',
#  'woman.',
#  'I',
#  'can',
#  't',
#  'go',
#  'with',
#  'you',
#  'now.',
#  'It',
#  'wouldn',
#  't',
#  'beright.',
#  'But',
#  'you',
#  'knew',
#  'that',
#  'before,',
#  'pleaded',
#  'the',
#  'man.',
#  'Besides',
#  'Yes,',
#  'but',
#  'I',
#  'can',
#  't',
#  'do',
#  'it.',
#  'He',
#  'was',
#  'there',
#  'His',
#  'eyes',
#  'spoke',
#  'I',
#  'don',
#  't',
#  'touchme,',
#  'she',
#  'said',
#  'I',
#  'm',
#  'going',
#  'back',
#  'to',
#  'my',
#  'husband.',
#  'Don',
#  't',
#  'follow.',
#  'IIThe',
#  'Child',
#  'SUFFER',
#  'THE',
#  'LITTLE',
#  'CHILDREN',
#  'TO',
#  'COME',
#  'UNTO',
#  'ME',
#  'IIThe',
#  'ChildThe',
#  'employees',
#  'had',
#  'all',
#  'gone',
#  'home,',
#  'carrying',
#  'with',
#  'them',
#  'Christmas',
#  'checks',
#  'andhearty',
#  'greetings',
#  'from',
#  'the',
#  'great',
#  'man',
#  'whose',
#  'beck',
#  'and',
#  'nod',
#  'they',
#  'followed.',
#  'Hesat',
#  'in',
#  'his',
#  'private',
#  'office',
#  'absolutely',
#  'alone.',
#  'He',
#  'had',
#  'some',
#  'serious',
#  'mattersto',
#  'consider',
#  'and',
#  'did',
#  'not',
#  'want',
#  'any',
#  'interruptions.',
#  'His',
#  'balance',
#  'sheet',
#  'forthe',
#  'year',
#  'had',
#  'been',
#  'made',
#  'up',
#  'according',
#  'to',
#  'the',
#  'custom',
#  'of',
#  'the',
#  'firm',
#  'beforeChristmas',
#  'instead',
#  'of',
#  'on',
#  'New',
#  'Year',
#  's',
#  'Day.',
#  'He',
#  'examined',
#  'it',
#  'again.',
#  'It',
#  'showedtremendous',
#  'profit.',
#  'The',
#  'mills',
#  'were',
#  'turning',
#  'out',
#  'quantities',
#  'of',
#  'material,the',
#  'demand',
#  'for',
#  'which',
#  'was',
#  'greater',
#  'and',
#  'the',
#  'cost',
#  'of',
#  'production',
#  'less',
#  'thanever',
#  'before.',
#  'I',
#  'tell',
#  'you,',
#  'said',
#  'the',
#  'man',
#  'to',
#  'himself,',
#  ...]

# %%
text=' '.join(text.split())
text
# Out:
# 'The Project Gutenberg eBook, And Thus He Came, by Cyrus Townsend Brady,Illustrated by Walter B. EverettThis eBook is for the use of anyone anywhere at no cost and withalmost no restrictions whatsoever. You may copy it, give it away orre use it under the terms of the Project Gutenberg License includedwith this eBook or online at www.gutenberg.netTitle And Thus He CameAuthor Cyrus Townsend BradyRelease Date January 5, 2005 Language EnglishCharacter set encoding ISO 646 US START OF THE PROJECT GUTENBERG EBOOK AND THUS HE CAME E text prepared by Robert Cicconetti, Melissa Er Raqabi, and the ProjectGutenberg Online Distributed Proofreading Team Note Project Gutenberg also has an HTML version of this file which includes the original illustrations. See 14606 h.htm or
#  [And Thus He CameAuthor Cyrus Townsend BradyRelease Date January 5, 2005 Language EnglishCharacter set encoding ISO,
#   'brady'],
#  [646 US START OF THE PROJECT GUTENBERG EBOOK AND, 'brady'],
#  [THUS HE CAME E text prepared by Robert Cicconetti, Melissa Er Raqabi, and the ProjectGutenberg Online Distributed Proofreading Team Note Project Gutenberg also has an HTML version of this file which includes the original illustrations.,
#   'brady'],
#  [See 14606 h.htm or 14606 h.zip or AND THUS HE CAMEA Christmas FantasybyCYRUS TOWNSEND BRADYPictures by Walter B. EverettG.P. Putnam s SonsNew York and LondonThe Knickerbocker Press1916To the Beloved MemoryofLittle BettyContents I. THE BABY II.,
#   'brady'],
#  [THE CHILD III., 'brady'],
#  [THE FRIEND IV., 'brady'],
#  [THE WORKMAN V. THE COMFORTER VI., 'brady'],
#  [THE BURDEN BEARER VII., 'brady'],
#  [THE THORN CROWNED VIII., 'brady'],
#  [THE BROKEN HEARTED IX., 'brady'],
#  [THE FORGIVER OF SINS, 'brady'],
#  [X., 'brady'],
#  [THE GIVER OF LIFE XI., 'brady'],
#  [THE STILLER OF THE STORMIllustrations, 'brady'],
#  [NO, NO, SAID THE WOMAN,, 'brady'],
#  [I CAN T GO WITH YOU NOW AFTER A TIME SHE FELL DOWN ON HER KNEES., 'brady'],
#  [SHE PRESSED THEM, 'brady'],
#  [AGAINST HER FACE SHE LAID HER HAND UPON THE KNOB OF THE CHURCH DOOR,
#   'brady'],
#  [IT IS HE,, 'brady'],
#  [WHISPERED THE PRIEST HIS SORROW, 'brady'],
#  [WAS GREATER THAN MINE ABSOLVO TE THE CRY FOR BREADIThe Baby A LITTLE CHILD SHALL LEAD THEM,
#   'brady'],
#  [IThe BabyThe heavy perfume of rare blossoms, the wild strains of mad music, thepatter of flying feet, the murmur of speech, the ring of laughter,filled the great hall.,
#   'brady'],
#  [Now and again a pair of dancers, peculiarlygraceful and particularly daring, held the center of the floor for amoment while the room rang with applause.,
#   'brady'],
#  [Into alcoves, screened and flower decked, couples wandered., 'brady'],
#  [In thedancing space hands were clasped, bosoms rose and fell, hearts throbbed,pulses beat, and moving bodies kept time to rhythmic sound.,
#   'brady'],
#  [Suddenly the music stopped, the conversation ceased, the laughter diedaway.,
#   'brady'],
#  [Almost, as it were, poised in the air, the dancers stood amazed., 'brady'],
#  [One looked to another in surprise., 'brady'],
#  [Something stole throughout the roomwhich was neither music, nor lights, nor fragrance, but which waslife a presence Do you see that child asked the wildest of the dancers of her escort.,
#   'brady'],
#  [There, she pointed., 'brady'],
#  [He looks like a very little boy., 'brady'],
#  [I see nothing, said the man, who still held her in the clasp of hisarm.,
#   'brady'],
#  [He is strangely dressed, although I see him indistinctly, vaguely, whispered the woman.,
#   'brady'],
#  [He wears a long white robe and there is a kind oflight about his face.,
#   'brady'],
#  [See, he is looking at us., 'brady'],
#  [I see nothing, repeated the man in low tones., 'brady'],
#  [The heat, the light,the music, have disturbed, 'brady'],
#  [you let me get you, 'brady'],
#  [I want nothing, interposed the woman, waving the man aside and drawingaway from his arm.,
#   'brady'],
#  [Don t, 'brady'],
#  [you see him, there She made a step toward the center of the room., 'brady'],
#  [She stopped, put herhand to her head., 'brady'],
#  [Why, he is gone, she exclaimed., 'brady'],
#  [Good, said the man, while at that instant the room suddenly rang withcries Go on with the music, the dance is not half over.,
#   'brady'],
#  [He extendedhis arm to the woman again., 'brady'],
#  [Our dance is not finished., 'brady'],
#  [Yes, it is, she said as the flying feet once more twinkled across thepolished floor, as everybody took a long breath and a new startapparently unconscious of the pause.,
#   'brady'],
#  [It is over for me., 'brady'],
#  [What I saw What did you see I don, 'brady'],
#  [t know, but I m going back home to my child., 'brady'],
#  [Good night., 'brady'],
#  [Yes, the music had stopped suddenly., 'brady'],
#  [The man in the farthest alcoveturned to his companion., 'brady'],
#  [They were hidden by a group of palms., 'brady'],
#  [I wonder why queried the woman., 'brady'],
#  [She was deathly pale., 'brady'],
#  [Her eyes weredark with fear, yet alight with passionate determination.,
#   'brady'],
#  [When it begins, said the man tenderly, we will slip away., 'brady'],
#  [My car isoutside., 'brady'],
#  [Everything is ready., 'brady'],
#  [That is my husband over there, said the woman., 'brady'],
#  [Yes, said the man, he won t trouble you any more., 'brady'],
#  [That woman with him is leaving him, she said., 'brady'],
#  [I wonder why., 'brady'],
#  [Sheturned suddenly with a great start., 'brady'],
#  [There is somebody here, shewhispered, staring into the back of the alcove.,
#   'brady'],
#  [Nonsense, said the man, throwing a glance around the recess., 'brady'],
#  [There snobody here, 'brady'],
#  [but you and I., 'brady'],
#  [We are alone together, as we shall behereafter, when we have taken the step.,
#   'brady'],
#  [But that child, whispered the woman, with his strange vesture andhis wonderful face.,
#   'brady'],
#  [His eyes look at me so., 'brady'],
#  [There is no child there, my dear, urged the man you are overwrought,excited, nervous.,
#   'brady'],
#  [The music starts., 'brady'],
#  [Let us go., 'brady'],
#  [He stretched out his hand to the woman, but as he came nearer she shrankback with her own hand on her heart.,
#   'brady'],
#  [Oh, she said faintly,, 'brady'],
#  [he s gone., 'brady'],
#  [Of course he s gone, he answered soothingly., 'brady'],
#  [Now is our time to getaway., 'brady'],
#  [Let me, 'brady'],
#  [No, no, said the woman., 'brady'],
#  [I can t go with you now., 'brady'],
#  [It wouldn t beright., 'brady'],
#  [But you knew that before, pleaded the man., 'brady'],
#  [Besides Yes,, 'brady'],
#  [but I can t do it., 'brady'],
#  [He was there, 'brady'],
#  [His eyes spoke I don, 'brady'],
#  [t touchme, 'brady'],
#  [, she said I m going back to my husband., 'brady'],
#  [Don t follow., 'brady'],
#  [IIThe Child SUFFER THE LITTLE CHILDREN, 'brady'],
#  [TO COME UNTO ME, 'brady'],
#  [IIThe, 'brady'],
#  [ChildThe employees had all gone home, carrying with them Christmas checks andhearty greetings from the great man whose beck and nod they followed.,
#   'brady'],
#  [Hesat in his private office absolutely alone., 'brady'],
#  [He had some serious mattersto consider and did not want any interruptions.,
#   'brady'],
#  [His balance sheet forthe year had been made up according to the custom of the firm beforeChristmas instead of on New Year s Day.,
#   'brady'],
#  [He examined it again., 'brady'],
#  [It showedtremendous profit., 'brady'],
#  [The mills were turning out quantities of material,the demand for which was greater and the cost of production less thanever before.,
#   'brady'],
#  [I tell you, said the man to himself, it was a master stroke todisplace the men with children in the mills.,
#   'brady'],
#  [They have reduced the costby four fifths., 'brady'],
#  [War has made the prices go up., 'brady'],
#  [This is not wealth, it isriches beyond calculation., 'brady'],
#  [He picked up a letter, read it over., 'brady'],
#  [It was a proposal from thesuperintendent to clear more land, to build more buildings, to installmore machines, to employ more children and increase the profits greatly.,
#   'brady'],
#  [I ll do it, said the man., 'brady'],
#  [We can crush opposition absolutely., 'brady'],
#  [I llcontrol the markets of the world., 'brady'],
#  [I ll build a fortune upon thisfoundation so great that no one can comprehend it.,
#   'brady'],
#  [He stopped, leaned back in his chair, lifted his eyes up toward theceiling of the room and saw beyond it the kingdoms of this world and themeans unlimited to make him lord and master.,
#   'brady'],
#  [He gave no thought to thefoundations, only to the structure erected by his fancy.,
#   'brady'],
#  [How long heindulged in dreams he scarcely realized, but presently he put his handson the arms of the chair and started to rise, saying, I ll telegraph the superintendent to go ahead.,
#   'brady'],
#  [He had scarcely formulated the words when right in front of him, seatedon his desk, he saw a young lad regarding him intently.,
#   'brady'],
#  [He stopped,petrified, in the position he had assumed., 'brady'],
#  [How did you get in, 'brady'],
#  [What are you doing here he asked., 'brady'],
#  [There was noanswer., 'brady'],
#  [Come, said the man, shrinking back., 'brady'],
#  [I can t imagine how yougot in here., 'brady'],
#  [If my people had not all gone I should hold them to strictaccount., 'brady'],
#  [As it is, you The room was suddenly filled with people., 'brady'],
#  [They came crowding through thewalls from every side and pressed close to him.,
#   'brady'],
#  [Such people he had neverseen wan, worn, stunted, pinched, starved, joyless.,
#   'brady'],
#  [They were allchildren, meagerly clothed, badly nourished, ill developed.,
#   'brady'],
#  [They werequite silent., 'brady'],
#  [They did not cry., 'brady'],
#  [They did not protest., 'brady'],
#  [They did notargue., 'brady'],
#  [They did not plead., 'brady'],
#  [They did not laugh., 'brady'],
#  [They just looked at him., 'brady'],
#  [They made no sound of any sort., 'brady'],
#  [He had children of his own and he hadknown many children., 'brady'],
#  [He had never known so many gathered togetherwithout a smile or a laugh.,
#   'brady'],
#  [His eye wandered around the room., 'brady'],
#  [They were very close to him and yetthey did not touch him., 'brady'],
#  [He turned to the desk where the lad had sat, buthe was no longer there,
#   'brady'],
#  [and yet he well remembered his face., 'brady'],
#  [He knewexactly how he looked., 'brady'],
#  [He turned to the nearest child and in somestrange way, although the poor, wretched face had not changed, his looksuggested the lad who had been his first visitor.,
#   'brady'],
#  [He turned to anotherand another., 'brady'],
#  [They all looked back at him in the same way with the sameeyes., 'brady'],
#  [He threw his head up again and saw the castle of success of which he haddreamed.,
#   'brady'],
#  [He looked down again., 'brady'],
#  [This was the foundation., 'brady'],
#  [Slowly his handwent to the desk., 'brady'],
#  [The little crowding figures drew back to give himfreedom of movement as he stretched his hand out for a telegraph blank.,
#   'brady'],
#  [He drew it to him., 'brady'],
#  [He seized a pen and wrote rapidly Build no more mills, take the children out of those already inoperation, put men in their places.,
#   'brady'],
#  [We will be content with less profitin the future., 'brady'],
#  [He read over the telegram., 'brady'],
#  [The telephone was close at hand., 'brady'],
#  [He called upthe telegraph office, dictated it and directed it to be sentimmediately.,
#   'brady'],
#  [He had been so engrossed in this task that he had noticednothing else.,
#   'brady'],
#  [Now he looked up., 'brady'],
#  [The room was still filled with children,but they were all laughing.,
#   'brady'],
#  [It was a soundless laugh, and yet he heardit., 'brady'],
#  [And then the room was empty save for the child he had seen first andvaguely.,
#   'brady'],
#  [He had just time to catch a smile from his lips and then he,too, was gone as silently and as strangely as he had appeared.,
#   'brady'],
#  [Was it a dream, 'brady'],
#  [No, there was the telegram in his hand, 'brady'],
#  [Had he sent it Again, 'brady'],
#  [he called up the office on the telephone., 'brady'],
#  [Did you get a message from me just a minute ago, 'brady'],
#  [Yes, do you want to recall it, 'brady'],
#  [The man thought a second., 'brady'],
#  [No, he said quietly was it to himself or to his vanishedvisitors, 'brady'],
#  [let it go., 'brady'],
#  [Merry Christmas., 'brady'],
#  [IIIThe Friend INASMUCH, 'brady'],
#  [AS YE HAVE DONE, 'brady'],
#  [IT UNTO ONE OF THE LEAST OF THESE,, 'brady'],
#  [MYBRETHREN IIIThe Friend Is the story of the Christ Child true, Mommy quivered one little,thin voice.,
#   'brady'],
#  [Yes, they told us it was over at the mission Sunday school, said thelittlest child.,
#   'brady'],
#  [I don t believe it, answered the mother., 'brady'],
#  [God ain t never done muchfor me., 'brady'],
#  [It s Christmas eve, ain t it asked the boy, climbing up on the thinknees of the threadbare woman and nestling his thin face against athinner breast which the rags scarcely covered decently.,
#   'brady'],
#  [Yes, it s Christmas eve., 'brady'],
#  [And that s the day He came,, 'brady'],
#  [ain t it urged the oldest girl., 'brady'],
#  [They say so., 'brady'],
#  [Don t, 'brady'],
#  [you believe it, 'brady'],
#  [, Mommy I used to believe it when I was a girl., 'brady'],
#  [I believed it before yourfather died, but now Don t you believe it now repeated the first child.,
#   'brady'],
#  [How can I believe it, 'brady'],
#  [You re old enough to understand., 'brady'],
#  [That s the lastscuttle of coal we got., 'brady'],
#  [We ate the last bit of bread for supperto night., 'brady'],
#  [They say, put in the little boy, that if you hang up your stockings,Santa Claus ll fill em, cause of the Christ Child.,
#   'brady'],
#  [Don t you believe it, Sonny, said the mother desperately., 'brady'],
#  [I m going to hang up mine and see, said the littlest girl., 'brady'],
#  [He s got too many other children to look after, said the woman, tocare for the likes of us, I m afraid, and But my Sunday school teacher said He came to poor people special.,
#   'brady'],
#  [Hewas awful poor Himself., 'brady'],
#  [Why, He was born in a stable., 'brady'],
#  [That s awful poor,ain t it asked the boy., 'brady'],
#  [When I was a girl, answered the mother, I lived on a farm and we hada stable there,
#   'brady'],
#  [that was a palace to this hole we live in now., 'brady'],
#  [No, you dbetter not hang up your stockings, none of you., 'brady'],
#  [And you don t believe in Him,, 'brady'],
#  [Mommy No., 'brady'],
#  [What would be the use if you hung em up and didn t find anythingin em in the morning,
#   'brady'],
#  [It d be awful, but I believe in Him, said the littlest girl., 'brady'],
#  [I don tthink God has forgot us, really., 'brady'],
#  [I m going to try., 'brady'],
#  [I tell you tain, 'brady'],
#  [t no use., 'brady'],
#  [Oh, yes, it is., 'brady'],
#  [I m sure it ain, 'brady'],
#  [t., 'brady'],
#  [But have it your own way, said the woman., 'brady'],
#  [Ifsomeone would fill your stockings with milk and bread, 'brady'],
#  [and I want a turkey, said the oldest girl., 'brady'],
#  [And cranberry sauce, added the boy., 'brady'],
#  [I want a doll baby in mine, said the littlest girl., 'brady'],
#  [The mother hid her face and groaned aloud., 'brady'],
#  [You ain t sick, are you, Mommy I guess so., 'brady'],
#  [Come, you d better say your prayers and go to bed., 'brady'],
#  [We don thave to keep the fire going so hard when you re all covered up.,
#   'brady'],
#  [It did not take long for the three little youngsters to divestthemselves of the rags of clothing they wore.,
#   'brady'],
#  [They slept in what passedfor their underclothes, so there was no donning of white gowns for thenight.,
#   'brady'],
#  [Here are our stockings, Mommy, said the oldest, handing three ragged,almost footless, black stockings to the woman.,
#   'brady'],
#  [It s no use, I tell you., 'brady'],
#  [I can t do it., 'brady'],
#  [It won t do any harm, Mommy, urged the girl., 'brady'],
#  [Do you believe in it, too asked the mother, and the girl shook herhead.,
#   'brady'],
#  [You won t be disappointed in the morning if there s nothing in em, 'brady'],
#  [No, I suppose it will be because Santa Claus was too busy., 'brady'],
#  [With nervous fingers the woman hung the three stockings near the window.,
#   'brady'],
#  [She was hungry, she was cold,, 'brady'],
#  [she was broken, she was a mother., 'brady'],
#  [Shecould scarcely keep from crying., 'brady'],
#  [Maybe you ll be glad you did it, said the littlest girl drowsily., 'brady'],
#  [Ain t you comin to bed, too, Mommy asked the oldest, beneath thecovers over the mattress on the floor.,
#   'brady'],
#  [In a little while., 'brady'],
#  [And you won t forget to say your prayers, 'brady'],
#  [I ain t said em for months, ever since your father was killed, and wegot so poor.,
#   'brady'],
#  [But you ll say em to night cause it s Christmas eve, 'brady'],
#  [Yes, to night, said the mother now you go to sleep., 'brady'],
#  [Are you waitin for him to come, Mommy asked the littlest girl, whowas very sleepy.,
#   'brady'],
#  [Yes, said the mother., 'brady'],
#  [Presently, as she sat in the dark, having turned out the light, the deepbreathing of the children told her they were asleep.,
#   'brady'],
#  [She rose quietly,stepped to the window, and stood looking at the three shapeless,tattered stockings.,
#   'brady'],
#  [She was high up in the tenement and the moonlightcame softly over the house roofs of the city into the bare, cold,cheerless room.,
#   'brady'],
#  [She stared at the stockings and tears streamed down herwasted cheeks.,
#   'brady'],
#  [She had hung them low at the suggestion of the littlestgirl so the children could easily get at them in the morning.,
#   'brady'],
#  [Bread, he whispered., 'brady'],
#  [The body He shattered the water breaker with his fist., 'brady'],
#  [There was a suggestion ofmoisture on the inside of the staves of the cask.,
#   'brady'],
#  [He drew his fingeracross them and touched it to the woman s lips., 'brady'],
#  [Water, he said hoarsely., 'brady'],
#  [The blood The terror, the yearning, disappeared from the woman s eyes.,
#   'brady'],
#  [She lookedat the man sanely, gratefully., 'brady'],
#  [God bless she faltered and then her lips stiffened., 'brady'],
#  [Some tag of quaint old Scripture that had impressed him when he firstheard it because of its very strangeness, but of which he had neverthought in all the years of his rough life since boyhood, came into theman s mind now.,
#   'brady'],
#  [He lifted his head as if to see again that figure., 'brady'],
#  [A priest forever, he gasped, after the order of Melchis He did not finish the word.,
#   'brady'],
#  [The woman was dead., 'brady'],
#  [He knew now for what hehad been kept alive., 'brady'],
#  [His task had been performed., 'brady'],
#  [He bowed his head inhis hands and entered into life eternal with the others.,
#   'brady'],
#  [Presently a little cloud flecked the sky., 'brady'],
#  [Out of the south the wind blewsoftly., 'brady'],
#  [The smooth sea rippled blue and white in the gentle breeze., 'brady'],
#  [Thelittle boat, cradling its dead, rocked gently as it drifted on., 'brady'],
#  [XIThe Stiller of the Storm BE OF GOOD, 'brady'],
#  [CHEER, 'brady'],
#  [IT IS, 'brady'],
#  [I BE NOT, 'brady'],
#  [AFRAID XIThe Stiller of the Storm, 'brady'],
#  [It s Christmas eve at home, murmured the young lad after he had saidhis prayers and tumbled into his narrow berth on the great ship.,
#   'brady'],
#  [Isuppose they re trimming the Christmas tree now and hanging up thestockings.,
#   'brady'],
#  [I wish I were there., 'brady'],
#  [He was very young to serve his country, but not too young according tothe standards of mankind to be a midshipman on the great steel monsterkeeping the leaden deep.,
#   'brady'],
#  [It was the first time he had ever been awayfrom home on Christmas day, too.,
#   'brady'],
#  [The youngsters had all laughed andjoked about it in the steerage mess.,
#   'brady'],
#  [They had promised themselves somekind of a celebration in the morning, but in his own cot with no one tosee, a few tears which he fondly deemed unmanly would come.,
#   'brady'],
#  [He had themidnight watch and he knew that he must get some sleep, but it was along time before he closed his eyes and drifted off to dream of home andhis mother.,
#   'brady'],
#  [Athwart that dream came a sudden, frightful, heart stilling roar ofdestruction a hideous crash followed, a terrible rending, breaking,smashing, concatenation of noises, succeeded by frightful detonations,as through the gaping hole torn in the great battleship by the deadlytorpedo, the water rushed upon the heated boilers, the explosion ofwhich in turn ignited the magazines.,
#   'brady'],
#  [By that deadly underwater thrust ofthe enemy the battleship was reduced in a few moments to a disjointed,disorganized, sinking mass of shapeless, formless, splintered steel.,
#   'brady'],
#  [As the explosions ceased, from every point rose shrieks and groans andcries of men in the death agony hurled into eternity and torn like thesteel.,
#   'brady'],
#  [And then the boy heard the surviving officers coolly, resolutelycalling the men to their stations.,
#   'brady'],
#  [He had been thrown from his berth by the violence of the explosion.,
#   'brady'],
#  [Hisface was cut and bleeding where he had struck a near by stanchion.,
#   'brady'],
#  [Hisleft arm hung useless., 'brady'],
#  [He had lain dazed on the deck for a few momentsuntil he heard the orders of his lieutenant.,
#   'brady'],
#  [He was one of the signalmidshipmen stationed on the signal bridge., 'brady'],
#  [Whatever happened that wasthe place to which to go he still had a duty to perform.,
#   'brady'],
#  [Picking himself up as best he could, he hurried to report to thelieutenant.,
#   'brady'],
#  [With such means as were available signals were made., 'brady'],
#  [Callsfor help, 'brady'],
#  [Oh, never Warnings that the enemy s submarines were in thenear vicinity and that other ships should keep away.,
#   'brady'],
#  [The captain was on the half wrecked bridge above., 'brady'],
#  [The boy noticed howquiet he was, yet his voice rang over the tumult.,
#   'brady'],
#  [Steady, men, steady., 'brady'],
#  [Keep your stations., 'brady'],
#  [Stand by., 'brady'],
#  [Be ready., 'brady'],
#  [The old quartermaster whose business it was to tell the hours salutedthe captain.,
#   'brady'],
#  [Eight bells, sir, he said, midnight., 'brady'],
#  [Christmas day, he added., 'brady'],
#  [Strike them, said the captain., 'brady'],
#  [And, as clear as ever, the four couplets rang out over the chaos and thedisaster.,
#   'brady'],
#  [Christmas day, the boy murmured., 'brady'],
#  [She s going, men, said the captain, as the cadences died away., 'brady'],
#  [Saveyourselves., 'brady'],
#  [Abandon the ship., 'brady'],
#  [Christmas morning, said the boy., 'brady'],
#  [I wonder what they re doing athome., 'brady'],
#  [Overboard with you, youngster, said the signal lieutenant I wish Ihad a life preserver for you, but Merry Christmas, sir, said the lad suddenly.,
#   'brady'],
#  [Good God said the man., 'brady'],
#  [Merry Christmas They will think of us athome., 'brady'],
#  [What was left of the ship gave a mighty reel., 'brady'],
#  [Quick or she ll suck you down, the officer roared, as he fairly flungthe boy into the water, and how he hurt that broken arm You can swim.,
#   'brady'],
#  [Strike out., 'brady'],
#  [Good by., 'brady'],
#  [The boy had caught a glimpse of the captain standing on the bridge asthe wreck went down and then the wild waters closed over his head.,
#   'brady'],
#  [Itwas frightfully cold., 'brady'],
#  [A hard gale was blowing., 'brady'],
#  [The waves ran terriblyhigh., 'brady'],
#  [His left arm was helpless., 'brady'],
#  [His head ached fiercely., 'brady'],
#  [What was theuse, 'brady'],
#  [Still the boy struck out bravely with his free hand., 'brady'],
#  [The instinctof life It was too dark to see., 'brady'],
#  [The sky was covered with driftingclouds., 'brady'],
#  [Only here and there a little rift of moonlight came through., 'brady'],
#  [Christmas morning, he sobbed out as the waves rolled him over., 'brady'],
#  [Oh, myGod, 'brady'],
#  [He felt himself going down., 'brady'],
#  [All at once the waters seemed to grow still., 'brady'],
#  [It was suddenly calm., 'brady'],
#  [He was no longer cold., 'brady'],
#  [He threw his head up forone last look at the sky and life and then he hung, as it were,suspended in some strange way.,
#   'brady'],
#  [He saw a figure walking across the smoothof the seas as it had been solid ground.,
#   'brady'],
#  [The figure drew nearer, thewind seemed to have died away, but the draperies that shrouded it swunggently as they would while a man walked along.,
#   'brady'],
#  [The face he saw dimly,vaguely, but there was light in it somehow., 'brady'],
#  [It came slowly nearer., 'brady'],
#  [Christmas morning, whispered the boy., 'brady'],
#  [The hand of the figure reached down., 'brady'],
#  [It caught the boy s right arm., 'brady'],
#  [Hewas lifted up., 'brady'],
#  [Home and Christmas morning, whispered the boy, closing his eyes., 'brady'],
#  [The moonlight broke through a cloud and fell upon him., 'brady'],
#  [A wave rolledover him and the sea was empty as before., 'brady'],
#  [He that hath eyes to see, let him see END OF THE PROJECT GUTENBERG EBOOK AND THUS,
#   'brady'],
#  [HE CAME This file should be named 14606.txt or 14606.zip, 'brady'],
#  [This and all associated files of various formats will be found in http www.gutenberg.org dirs,
#   'brady'],
#  [1 4 6 0 14606Updated editions will replace the previous one the old editionswill be renamed.,
#   'brady'],
#  [Creating the works from public domain print editions means that noone owns a United States copyright in these works, so the Foundation can copy and distribute it in the United States withoutpermission and without paying copyright royalties.,
#   'brady'],
#  [Special rules,set forth in the General Terms of Use part of this license, apply tocopying and distributing Project Gutenberg tm electronic works toprotect the PROJECT GUTENBERG tm concept and trademark.,
#   'brady'],
#  [ProjectGutenberg is a registered trademark, and may not be used if youcharge for the eBooks, unless you receive specific permission.,
#   'brady'],
#  [If youdo not charge anything for copies of this eBook, complying with therules is very easy.,
#   'brady'],
#  [You may use this eBook for nearly any purposesuch as creation of derivative works, reports, performances andresearch.,
#   'brady'],
#  [They may be modified and printed and given away you may dopractically ANYTHING with public domain eBooks.,
#   'brady'],
#  [Redistribution issubject to the trademark license, especially commercialredistribution.,
#   'brady'],
#  [START FULL LICENSE, 'brady'],
#  [THE FULL PROJECT GUTENBERG LICENSEPLEASE READ THIS, 'brady'],
#  [BEFORE YOU DISTRIBUTE OR USE THIS WORKTo protect the Project Gutenberg tm mission of promoting the freedistribution of electronic works, by using or distributing this work, you agree to comply with all the terms of the Full ProjectGutenberg tm License .Section,
#   'brady'],
#  [1., 'brady'],
#  [General Terms of Use and Redistributing Project Gutenberg tmelectronic,
#   'brady'],
#  [works1.A., 'brady'],
#  [By reading or using any part of this Project Gutenberg tmelectronic work, you indicate that you have read, understand, agree toand accept all the terms of this license and intellectual property agreement.,
#   'brady'],
#  [If you do not agree to abide by allthe terms of this agreement, you must cease using and return or destroyall copies of Project Gutenberg tm electronic works in your possession.,
#   'brady'],
#  [If you paid a fee for obtaining a copy of or access to a ProjectGutenberg tm electronic work and you do not agree to be bound by theterms of this agreement, you may obtain a refund from the person orentity to whom you paid the fee as set forth in paragraph 1.E.8.1.B. Project Gutenberg is a registered trademark.,
#   'brady'],
#  [It may only beused on or associated in any way with an electronic work by people whoagree to be bound by the terms of this agreement.,
#   'brady'],
#  [There are a fewthings that you can do with most Project Gutenberg tm electronic workseven without complying with the full terms of this agreement.,
#   'brady'],
#  [Seeparagraph 1.C below., 'brady'],
#  [There are a lot of things you can do with ProjectGutenberg tm electronic works if you follow the terms of this agreementand help preserve free future access to Project Gutenberg tm electronicworks.,
#   'brady'],
#  [See paragraph 1.E below.1.C., 'brady'],
#  [The Project Gutenberg Literary Archive Foundation , owns a compilation copyright in the collection of ProjectGutenberg tm electronic works.,
#   'brady'],
#  [Nearly all the individual works in thecollection are in the public domain in the United States.,
#   'brady'],
#  [If anindividual work is in the public domain in the United States and you arelocated in the United States, we do not claim a right to prevent you fromcopying, distributing, performing, displaying or creating derivativeworks based on the work as long as all references to Project Gutenbergare removed.,
#   'brady'],
#  [Of course, we hope that you will support the ProjectGutenberg tm mission of promoting free access to electronic works byfreely sharing Project Gutenberg tm works in compliance with the terms ofthis agreement for keeping the Project Gutenberg tm name associated withthe work.,
#   'brady'],
#  [You can easily comply with the terms of this agreement bykeeping this work in the same format with its attached full ProjectGutenberg tm License when you share it without charge with others.1.D.,
#   'brady'],
#  [The copyright laws of the place where you are located also governwhat you can do with this work.,
#   'brady'],
#  [Copyright laws in most countries are ina constant state of change., 'brady'],
#  [If you are outside the United States, checkthe laws of your country in addition to the terms of this agreementbefore downloading, copying, displaying, performing, distributing orcreating derivative works based on this work or any other ProjectGutenberg tm work.,
#   'brady'],
#  [The Foundation makes no representations concerningthe copyright status of any work in any country outside the UnitedStates.1.E. Unless you have removed all references to Project Gutenberg 1.E.1.,
#   'brady'],
#  [The following sentence, with active links to, or other immediateaccess to, the full Project Gutenberg tm License must appear prominentlywhenever any copy of a Project Gutenberg tm work is accessed, displayed, performed, viewed,copied or distributed This eBook is for the use of anyone anywhere at no cost and withalmost no restrictions whatsoever.,
#   'brady'],
#  [You may copy it, give it away orre use it under the terms of the Project Gutenberg License includedwith this eBook or online at www.gutenberg.net1.E.2.,
#   'brady'],
#  [If an individual Project Gutenberg tm electronic work is derivedfrom the public domain , the work can be copiedand distributed to anyone in the United States without paying any feesor charges.,
#   'brady'],
#  [If you are redistributing or providing access to a workwith the phrase Project Gutenberg associated with or appearing on thework, you must comply either with the requirements of paragraphs 1.E.1through 1.E.7 or obtain permission for the use of the work and theProject Gutenberg tm trademark as set forth in paragraphs 1.E.8 or1.E.9.1.E.3.,
#   'brady'],
#  [If an individual Project Gutenberg tm electronic work is postedwith the permission of the copyright holder, your use and distributionmust comply with both paragraphs 1.E.1 through 1.E.7 and any additionalterms imposed by the copyright holder.,
#   'brady'],
#  [Additional terms will be linkedto the Project Gutenberg tm License for all works posted with thepermission of the copyright holder found at the beginning of this work.1.E.4.,
#   'brady'],
#  [Do not unlink or detach or remove the full Project Gutenberg tmLicense terms from this work, or any files containing a part of thiswork or any other work associated with Project Gutenberg tm.1.E.5.,
#   'brady'],
#  [Do not copy, display, perform, distribute or redistribute thiselectronic work, or any part of this electronic work, withoutprominently displaying the sentence set forth in paragraph 1.E.1 withactive links or immediate access to the full terms of the ProjectGutenberg tm License.1.E.6.,
#   'brady'],
#  [You may convert to and distribute this work in any binary,compressed, marked up, nonproprietary or proprietary form, including anyword processing or hypertext form.,
#   'brady'],
#  [However, if you provide access to ordistribute copies of a Project Gutenberg tm work in a format other than Plain Vanilla ASCII or other format used in the official versionposted on the official Project Gutenberg tm web site ,you must, at no additional cost, fee or expense to the user, provide acopy, a means of exporting a copy, or a means of obtaining a copy uponrequest, of the work in its original Plain Vanilla ASCII or otherform.,
#   'brady'],
#  [Any alternate format must include the full Project Gutenberg tmLicense as specified in paragraph 1.E.1.1.E.7.,
#   'brady'],
#  [Do not charge a fee for access to, viewing, displaying,performing, copying or distributing any Project Gutenberg tm worksunless you comply with paragraph 1.E.8 or 1.E.9.1.E.8.,
#   'brady'],
#  [You may charge a reasonable fee for copies of or providingaccess to or distributing Project Gutenberg tm electronic works providedthat You pay a royalty fee of 20 of the gross profits you derive from the use of Project Gutenberg tm works calculated using the method you already use to calculate your applicable taxes.,
#   'brady'],
#  [The fee is owed to the owner of the Project Gutenberg tm trademark, but he has agreed to donate royalties under this paragraph to the Project Gutenberg Literary Archive Foundation.,
#   'brady'],
#  [Royalty payments must be paid within 60 days following each date on which you prepare your periodic tax returns.,
#   'brady'],
#  [Royalty payments should be clearly marked as such and sent to the Project Gutenberg Literary Archive Foundation at the address specified in Section 4, Information about donations to the Project Gutenberg Literary Archive Foundation.,
#   'brady'],
#  [You provide a full refund of any money paid by a user who notifies you in writing within 30 days of receipt that s he does not agree to the terms of the full Project Gutenberg tm License.,
#   'brady'],
#  [You must require such a user to return or destroy all copies of the works possessed in a physical medium and discontinue all use of and all access to other copies of Project Gutenberg tm works.,
#   'brady'],
#  [You provide, in accordance with paragraph 1.F.3, a full refund of any money paid for a work or a replacement copy, if a defect in the electronic work is discovered and reported to you within 90 days of receipt of the work.,
#   'brady'],
#  [You comply with all other terms of this agreement for free distribution of Project Gutenberg tm works.1.E.9.,
#   'brady'],
#  [If you wish to charge a fee or distribute a Project Gutenberg tmelectronic work or group of works on different terms than are setforth in this agreement, you must obtain permission in writing fromboth the Project Gutenberg Literary Archive Foundation and MichaelHart, the owner of the Project Gutenberg tm trademark.,
#   'brady'],
#  [Contact theFoundation as set forth in Section 3 below.1.F.1.F.1., 'brady'],
#  [Project Gutenberg volunteers and employees expend considerableeffort to identify, do copyright research on, transcribe and proofreadpublic domain works in creating the Project Gutenberg tmcollection.,
#   'brady'],
#  [Despite these efforts, Project Gutenberg tm electronicworks, and the medium on which they may be stored, may contain Defects, such as, but not limited to, incomplete, inaccurate orcorrupt data, transcription errors, a copyright or other intellectualproperty infringement, a defective or damaged disk or other medium, acomputer virus, or computer codes that damage or cannot be read byyour equipment.1.F.2.,
#   'brady'],
#  [LIMITED WARRANTY, DISCLAIMER OF DAMAGES, 'brady'],
#  [Except for the Rightof Replacement or Refund described in paragraph 1.F.3, the ProjectGutenberg Literary Archive Foundation, the owner of the ProjectGutenberg tm trademark, and any other party distributing a ProjectGutenberg tm electronic work under this agreement, disclaim allliability to you for damages, costs and expenses, including legalfees.,
#   'brady'],
#  [YOU AGREE THAT YOU HAVE NO REMEDIES FOR NEGLIGENCE, STRICTLIABILITY, BREACH OF WARRANTY,
#   'brady'],
#  [OR BREACH OF CONTRACT EXCEPT THOSEPROVIDED IN PARAGRAPH, 'brady'],
#  [F3., 'brady'],
#  [YOU AGREE THAT THE FOUNDATION, THETRADEMARK OWNER, AND ANY DISTRIBUTOR,
#   'brady'],
#  [UNDER THIS AGREEMENT, 'brady'],
#  [WILL NOT BELIABLE TO YOU FOR ACTUAL, DIRECT, INDIRECT, CONSEQUENTIAL,,
#   'brady'],
#  [PUNITIVE ORINCIDENTAL DAMAGES, 'brady'],
#  [EVEN IF YOU GIVE NOTICE OF THE POSSIBILITY OF SUCHDAMAGE.1.F.3., 'brady'],
#  [LIMITED, 'brady'],
#  [RIGHT OF REPLACEMENT OR REFUND, 'brady'],
#  [If you discover adefect in this electronic work within 90 days of receiving it, you canreceive a refund of the money you paid for it by sending awritten explanation to the person you received the work from.,
#   'brady'],
#  [If youreceived the work on a physical medium, you must return the medium withyour written explanation.,
#   'brady'],
#  [The person or entity that provided you withthe defective work may elect to provide a replacement copy in lieu of arefund.,
#   'brady'],
#  [If you received the work electronically, the person or entityproviding it to you may choose to give you a second opportunity toreceive the work electronically in lieu of a refund.,
#   'brady'],
#  [If the second copyis also defective, you may demand a refund in writing without furtheropportunities to fix the problem.1.F.4.,
#   'brady'],
#  [Except for the limited right of replacement or refund set forthin paragraph 1.F.3, this work is provided to you AS IS , WITH NO OTHERWARRANTIES OF ANY KIND, EXPRESS OR IMPLIED, INCLUDING,
#   'brady'],
#  [BUT NOT LIMITED TOWARRANTIES OF MERCHANTIBILITY OR FITNESS FOR ANY PURPOSE.1.F.5.,
#   'brady'],
#  [Some states do not allow disclaimers of certain impliedwarranties or the exclusion or limitation of certain types of damages.,
#   'brady'],
#  [If any disclaimer or limitation set forth in this agreement violates thelaw of the state applicable to this agreement, the agreement shall beinterpreted to make the maximum disclaimer or limitation permitted bythe applicable state law.,
#   'brady'],
#  [The invalidity or unenforceability of anyprovision of this agreement shall not void the remaining provisions.1.F.6.,
#   'brady'],
#  [INDEMNITY, 'brady'],
#  [You agree to indemnify and hold the Foundation, thetrademark owner, any agent or employee of the Foundation, anyoneproviding copies of Project Gutenberg tm electronic works in accordancewith this agreement, and any volunteers associated with the production,promotion and distribution of Project Gutenberg tm electronic works,harmless from all liability, costs and expenses, including legal fees,that arise directly or indirectly from any of the following which you door cause to occur distribution of this or any Project Gutenberg tmwork, alteration, modification, or additions or deletions to anyProject Gutenberg tm work, and any Defect you cause.,
#   'brady'],
#  [Section 2., 'brady'],
#  [Information about the Mission of Project Gutenberg tmProject Gutenberg tm is synonymous with the free distribution ofelectronic works in formats readable by the widest variety of computersincluding obsolete, old, middle aged and new computers.,
#   'brady'],
#  [It existsbecause of the efforts of hundreds of volunteers and donations frompeople in all walks of life.,
#   'brady'],
#  [Volunteers and financial support to provide volunteers with theassistance they need, is critical to reaching Project Gutenberg tm sgoals and ensuring that the Project Gutenberg tm collection willremain freely available for generations to come.,
#   'brady'],
#  [In 2001, the ProjectGutenberg Literary Archive Foundation was created to provide a secureand permanent future for Project Gutenberg tm and future generations.,
#   'brady'],
#  [To learn more about the Project Gutenberg Literary Archive Foundationand how your efforts and donations can help, see Sections 3 and 4and the Foundation web page at http www.gutenberg.net fundraising pglaf.,
#   'brady'],
#  [Section 3., 'brady'],
#  [Information about the Project Gutenberg Literary ArchiveFoundationThe Project Gutenberg Literary Archive Foundation is a non profit501 educational corporation organized under the laws of thestate of Mississippi and granted tax exempt status by the InternalRevenue Service.,
#   'brady'],
#  [The Foundation s EIN or federal tax identificationnumber is 64 6221541.,
#   'brady'],
#  [Contributions to the Project GutenbergLiterary Archive Foundation are tax deductible to the full extentpermitted by U.S. federal laws and your state s laws.,
#   'brady'],
#  [The Foundation s principal office is located at 4557 Melan Dr. S.Fairbanks, AK, 99712., but its volunteers and employees are scatteredthroughout numerous locations.,
#   'brady'],
#  [Its business office is located at809 North 1500 West, Salt Lake City, UT 84116, 596 1887, emailbusiness pglaf.org.,
#   'brady'],
#  [Email contact links and up to date contactinformation can be found at the Foundation s web site and officialpage at http www.gutenberg.net about contactFor additional contact information Dr. Gregory B. Newby Chief Executive and Director gbnewby pglaf.orgSection 4.,
#   'brady'],
#  [Information about Donations to the Project GutenbergLiterary Archive FoundationProject Gutenberg tm depends upon and cannot survive without widespread public support and donations to carry out its mission ofincreasing the number of public domain and licensed works that can befreely distributed in machine readable form accessible by the widestarray of equipment including outdated equipment.,
#   'brady'],
#  [Many small donations are particularly important to maintaining tax exemptstatus with the IRS.The Foundation is committed to complying with the laws regulatingcharities and charitable donations in all 50 states of the UnitedStates.,
#   'brady'],
#  [Compliance requirements are not uniform and it takes aconsiderable effort, much paperwork and many fees to meet and keep upwith these requirements.,
#   'brady'],
#  [We do not solicit donations in locationswhere we have not received written confirmation of compliance.,
#   'brady'],
#  [ToSEND DONATIONS or determine the status of compliance for anyparticular state visit http,
#   'brady'],
#  [www.gutenberg.net fundraising donateWhile we cannot and do not solicit contributions from states where wehave not met the solicitation requirements, we know of no prohibitionagainst accepting unsolicited donations from donors in such states whoapproach us with offers to donate.,
#   'brady'],
#  [International donations are gratefully accepted, but we cannot makeany statements concerning tax treatment of donations received fromoutside the United States.,
#   'brady'],
#  [U.S. laws alone swamp our small staff., 'brady'],
#  [Please check the Project Gutenberg Web pages for current donationmethods and addresses.,
#   'brady'],
#  [Donations are accepted in a number of otherways including including checks, online payments and credit carddonations.,
#   'brady'],
#  [To donate, please visit http www.gutenberg.net fundraising donateSection 5.,
#   'brady'],
#  [General Information About Project Gutenberg tm electronicworks., 'brady'],
#  [Professor Michael S. Hart is the originator of the Project Gutenberg tmconcept of a library of electronic works that could be freely sharedwith anyone.,
#   'brady'],
#  [For thirty years, he produced and distributed ProjectGutenberg tm eBooks with only a loose network of volunteer support.,
#   'brady'],
#  [Project Gutenberg tm eBooks are often created from several printededitions, all of which are confirmed as Public Domain in the U.S.unless a copyright notice is included.,
#   'brady'],
#  [Thus, we do not necessarilykeep eBooks in compliance with any particular paper edition.,
#   'brady'],
#  [Most people start at our Web site which has the main PG search facility http www.gutenberg.netThis Web site includes information about Project Gutenberg tm,including how to make donations to the Project Gutenberg LiteraryArchive Foundation, how to help produce our new eBooks, and how tosubscribe to our email newsletter to hear about new eBooks.,
#   'brady']]

# %%
# Combine the sentences from the two novels into one data frame.
sentences = pd.DataFrame(text_sents)

# %%
from collections import Counter
# Utility function to create a list of the 10 most common words.
def bag_of_words(text):
    
    # Filter out punctuation and stop words.
    allwords = [token.lemma_
                for token in text
                if not token.is_punct
                and not token.is_stop]
    
    # Return the most common words.
    return [item[0] for item in Counter(allwords).most_common(10)]

# %%
# Creates a data frame with features for each word in our common word set.
# Each value is the count of the times the word appears in each sentence.
def bow_features(sentences, common_words):
    
    # Scaffold the data frame and initialize counts to zero.
    df = pd.DataFrame(columns=common_words)
    df['text_sentence'] = sentences[0]
    df['text_source'] = sentences[1]
    df.loc[:, common_words] = 0
    
    # Process each row, counting the occurrence of words in each sentence.
    for i, sentence in enumerate(df['text_sentence']):
        
        # Convert the sentence to lemmas, then filter out punctuation,
        # stop words, and uncommon words.
        words = [token.lemma_
                 for token in sentence
                 if (
                     not token.is_punct
                     and not token.is_stop
                     and token.lemma_ in common_words
                 )]
        
        # Populate the row with word counts.
        for word in words:
            df.loc[i, word] += 1
        
        # This counter is just to make sure the kernel didn't hang.
        if i % 500 == 0:
            print("Processing row {}".format(i))
            
    return df

# %%
# Set up the bags.
text_words = bag_of_words(text_doc)

# %%
# Create our data frame with features. This can take a while to run.
text_counts = bow_features(sentences, text_words)
# Out:
# Processing row 0
