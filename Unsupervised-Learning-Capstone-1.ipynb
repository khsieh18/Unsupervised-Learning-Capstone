# %% [markdown]
# For this project you'll dig into a large amount of text and apply most of what you've covered in this unit and in the course so far.
#
# First, pick a set of texts. This can be either a series of novels, chapters, or articles. Anything you'd like. It just has to have multiple entries of varying characteristics. At least 100 should be good. There should also be at least 10 different authors, but try to keep the texts related (either all on the same topic of from the same branch of literature - something to make classification a bit more difficult than obviously different subjects).
#
# This capstone can be an extension of your NLP challenge if you wish to use the same corpus. If you found problems with that data set that limited your analysis, however, it may be worth using what you learned to choose a new corpus. Reserve 25% of your corpus as a test set.
#
# The first technique is to create a series of clusters. Try several techniques and pick the one you think best represents your data. Make sure there is a narrative and reasoning around why you have chosen the given clusters. Are authors consistently grouped into the same cluster?
#
# Next, perform some unsupervised feature generation and selection using the techniques covered in this unit and elsewhere in the course. Using those features then build models to attempt to classify your texts by author. Try different permutations of unsupervised and supervised techniques to see which combinations have the best performance.
#
# Lastly return to your holdout group. Does your clustering on those members perform as you'd expect? Have your clusters remained stable or changed dramatically? What about your model? Is it's performance consistent?
#
# If there is a divergence in the relative stability of your model and your clusters, delve into why.
#
# Your end result should be a write up of how clustering and modeling compare for classifying your texts. What are the advantages of each? Why would you want to use one over the other? Approximately 3-5 pages is a good length for your write up, and remember to include visuals to help tell your story!

# %%
import pandas as pd

# %%
filename='And Thus He Came.txt'
file=open(filename,'rt')
text=file.read()
file.close
# Out:
# <function TextIOWrapper.close()>

# %%
text
# Out:
# 'ï»¿The Project Gutenberg eBook, And Thus He Came, by Cyrus Townsend Brady,\nIllustrated by Walter B. Everett\n\n\nThis eBook is for the use of anyone anywhere at no cost and with\nalmost no restrictions whatsoever.  You may copy it, give it away or\nre-use it under the terms of the Project Gutenberg License included\nwith this eBook or online at www.gutenberg.net\n\n\n\n\n\nTitle: And Thus He Came\n\nAuthor: Cyrus Townsend Brady\n\nRelease Date: January 5, 2005  [eBook #14606]\n\nLanguage: English\n\nCharacter set encoding: ISO-646-US (US-ASCII)\n\n\n***START OF THE PROJECT GUTENBERG EBOOK AND THUS HE CAME***\n\n\nE-text prepared by Robert Cicconetti, Melissa Er-Raqabi, and the Project\nGutenberg Online Distributed Proofreading Team (http://www.pgdp.net)\n\n\n\nNote: Project Gutenberg also has an HTML version of this\n      file which includes the original illustrations.\n      See 14606-h.htm or 14606-h.zip:\n      (http://www.gutenberg.net/dirs/1/4/6/0/14606/14606-h/14606-h.htm)\n      or\n      (http://www.gutenberg.net/dirs/1/4/6/0/14606/14606-h.zip)\n\n\n\n\n\nAND THUS HE CAME\n\nA Christmas Fantasy\n\nby\n\nCYRUS TOWNSEND BRADY\n\nPictures by Walter B. Everett\n\nG.P. Putnam\'s Sons\nNew York and London\nThe Knickerbocker Press\n\n1916\n\n\n\n\n\n\n\n[Illustration: "No, No," said the woman, "I can\'t go with you now."]\n\n\n\nTo the Beloved Memory\nof\nLittle Betty\n\n\n\n\nContents\n\n       I.--THE BABY\n      II.--THE CHILD\n     III.--THE FRIEND\n      IV.--THE WORKMAN\n       V.--THE COMFORTER\n      VI.--THE BURDEN BEARER\n     VII.--THE THORN CROWNED\n    VIII.--THE BROKEN-HEARTED\n      IX.--THE FORGIVER OF SINS\n       X.--THE GIVER OF LIFE\n      XI.--THE STILLER OF THE STORM\n\n\n\n\nIllustrations\n\n   "NO, NO," SAID THE WOMAN, "I CAN\'T GO WITH YOU NOW" (Frontispiece)\n\n   AFTER A TIME SHE FELL DOWN ON HER KNEES. SHE PRESSED THEM AGAINST\n   HER FACE\n\n   SHE LAID HER HAND UPON THE KNOB OF THE CHURCH DOOR\n\n   "IT IS HE," WHISPERED THE PRIEST; "HIS SORROW WAS GREATER THAN MINE"\n\n   ABSOLVO TE\n\n   THE CRY FOR BREAD\n\n\n\n\nI\n\nThe Baby\n\n"A LITTLE CHILD SHALL LEAD THEM"\n\n\n\n\nI\n\nThe Baby\n\n\nThe heavy perfume of rare blossoms, the wild strains of mad music, the\npatter of flying feet, the murmur of speech, the ring of laughter,\nfilled the great hall. Now and again a pair of dancers, peculiarly\ngraceful and particularly daring, held the center of the floor for a\nmoment while the room rang with applause.\n\nInto alcoves, screened and flower-decked, couples wandered. In the\ndancing-space hands were clasped, bosoms rose and fell, hearts throbbed,\npulses beat, and moving bodies kept time to rhythmic sound.\n\nSuddenly the music stopped, the conversation ceased, the laughter died\naway. Almost, as it were, poised in the air, the dancers stood amazed.\nOne looked to another in surprise. Something stole throughout the room\nwhich was neither music, nor lights, nor fragrance, but which was\nlife--a presence!\n\n"Do you see that child?" asked the wildest of the dancers of her escort.\n"There," she pointed. "He looks like a very little boy."\n\n"I see nothing," said the man, who still held her in the clasp of his\narm.\n\n"He is strangely dressed, although I see him indistinctly, vaguely,"\nwhispered the woman. "He wears a long white robe and there is a kind of\nlight about his face. See, he is looking at us."\n\n"I see nothing," repeated the man in low tones. "The heat, the light,\nthe music, have disturbed you; let me get you--"\n\n"I want nothing," interposed the woman, waving the man aside and drawing\naway from his arm. "Don\'t you see him, there?"\n\nShe made a step toward the center of the room. She stopped, put her\nhand to her head.\n\n"Why, he is gone," she exclaimed.\n\n"Good," said the man, while at that instant the room suddenly rang with\ncries: "Go on with the music, the dance is not half over." He extended\nhis arm to the woman again. "Our dance is not finished."\n\n"Yes, it is," sh ...

# %%
from nltk import sent_tokenize

# %%
sentences=sent_tokenize(text)

# %%
sentences
# Out:
# ['ï»¿The Project Gutenberg eBook, And Thus He Came, by Cyrus Townsend Brady,\nIllustrated by Walter B. Everett\n\n\nThis eBook is for the use of anyone anywhere at no cost and with\nalmost no restrictions whatsoever.',
#  'You may copy it, give it away or\nre-use it under the terms of the Project Gutenberg License included\nwith this eBook or online at www.gutenberg.net\n\n\n\n\n\nTitle: And Thus He Came\n\nAuthor: Cyrus Townsend Brady\n\nRelease Date: January 5, 2005  [eBook #14606]\n\nLanguage: English\n\nCharacter set encoding: ISO-646-US (US-ASCII)\n\n\n***START OF THE PROJECT GUTENBERG EBOOK AND THUS HE CAME***\n\n\nE-text prepared by Robert Cicconetti, Melissa Er-Raqabi, and the Project\nGutenberg Online Distributed Proofreading Team (http://www.pgdp.net)\n\n\n\nNote: Project Gutenberg also has an HTML version of this\n      file which includes the original illustrations.',
#  'See 14606-h.htm or 14606-h.zip:\n      (http://www.gutenberg.net/dirs/1/4/6/0/14606/14606-h/14606-h.htm)\n      or\n      (http://www.gutenberg.net/dirs/1/4/6/0/14606/14606-h.zip)\n\n\n\n\n\nAND THUS HE CAME\n\nA Christmas Fantasy\n\nby\n\nCYRUS TOWNSEND BRADY\n\nPictures by Walter B. Everett\n\nG.P.',
#  'Putnam\'s Sons\nNew York and London\nThe Knickerbocker Press\n\n1916\n\n\n\n\n\n\n\n[Illustration: "No, No," said the woman, "I can\'t go with you now."]',
#  'To the Beloved Memory\nof\nLittle Betty\n\n\n\n\nContents\n\n       I.--THE BABY\n      II.--THE CHILD\n     III.--THE FRIEND\n      IV.--THE WORKMAN\n       V.--THE COMFORTER\n      VI.--THE BURDEN BEARER\n     VII.--THE THORN CROWNED\n    VIII.--THE BROKEN-HEARTED\n      IX.--THE FORGIVER OF SINS\n       X.--THE GIVER OF LIFE\n      XI.--THE STILLER OF THE STORM\n\n\n\n\nIllustrations\n\n   "NO, NO," SAID THE WOMAN, "I CAN\'T GO WITH YOU NOW" (Frontispiece)\n\n   AFTER A TIME SHE FELL DOWN ON HER KNEES.',
#  'SHE PRESSED THEM AGAINST\n   HER FACE\n\n   SHE LAID HER HAND UPON THE KNOB OF THE CHURCH DOOR\n\n   "IT IS HE," WHISPERED THE PRIEST; "HIS SORROW WAS GREATER THAN MINE"\n\n   ABSOLVO TE\n\n   THE CRY FOR BREAD\n\n\n\n\nI\n\nThe Baby\n\n"A LITTLE CHILD SHALL LEAD THEM"\n\n\n\n\nI\n\nThe Baby\n\n\nThe heavy perfume of rare blossoms, the wild strains of mad music, the\npatter of flying feet, the murmur of speech, the ring of laughter,\nfilled the great hall.',
#  'Now and again a pair of dancers, peculiarly\ngraceful and particularly daring, held the center of the floor for a\nmoment while the room rang with applause.',
#  'Into alcoves, screened and flower-decked, couples wandered.',
#  'In the\ndancing-space hands were clasped, bosoms rose and fell, hearts throbbed,\npulses beat, and moving bodies kept time to rhythmic sound.',
#  'Suddenly the music stopped, the conversation ceased, the laughter died\naway.',
#  'Almost, as it were, poised in the air, the dancers stood amazed.',
#  'One looked to another in surprise.',
#  'Something stole throughout the room\nwhich was neither music, nor lights, nor fragrance, but which was\nlife--a presence!',
#  '"Do you see that child?"',
#  'asked the wildest of the dancers of her escort.',
#  '"There," she pointed.',
#  '"He looks like a very little boy."',
#  '"I see nothing," said the man, who still held her in the clasp of his\narm.',
#  '"He is strangely dressed, although I see him indistinctly, vaguely,"\nwhispered the woman.',
#  '"He wears a long white robe and there is a kind of\nlight about his face.',
#  'See, he is looking at us."',
#  '"I see nothing," repeated the man in low tones.',
#  '"The heat, the light,\nthe music, have disturbed you; let me get you--"\n\n"I want nothing," interposed the woman, waving the man aside and drawing\naway from his arm.',
#  '"Don\'t you see him, there?"',
#  'She made a step toward the center of the room.',
#  'She stopped, put her\nhand to her head.',
#  '"Why, he is gone," she exclaimed.',
#  '"Good," said the man, while at that instant the room suddenly rang with\ncries: "Go on with the music, the dance is not half over."',
#  'He extended\nhis arm to the woman again.',
#  '"Our dance is not finished."',
#  '"Yes, it is," she said as the flying feet once more twinkled across the\npolished floor, as everybody took a long breath and a new start\napparently unconscious of the pause.',
#  '"It is over for me.',
#  'What I saw!"',
#  '"What did you see?"',
#  '"I don\'t know, but I\'m going back home to my child.',
#  'Good-night."',
#  '*       *       *       *       *\n\nYes, the music had stopped suddenly.',
#  'The man in the farthest alcove\nturned to his companion.',
#  'They were hidden by a group of palms.',
#  '"I wonder why?"',
#  'queried the woman.',
#  'She was deathly pale.',
#  'Her eyes were\ndark with fear, yet alight with passionate determination.',
#  '"When it begins," said the man tenderly, "we will slip away.',
#  'My car is\noutside.',
#  'Everything is ready."',
#  '"That is my husband over there," said the woman.',
#  '"Yes," said the man, "he won\'t trouble you any more."',
#  '"That woman with him is leaving him," she said.',
#  '"I wonder why."',
#  'She\nturned suddenly with a great start.',
#  '"There is somebody here," she\nwhispered, staring into the back of the alcove.',
#  '"Nonsense," said the man, throwing a glance around the recess.',
#  '"There\'s\nnobody here but you and I.',
#  'We are alone together, as we shall be\nhereafter, when we have taken the step."',
#  '"But that child," whispered the woman, "with his strange vesture and\nhis wonderful face.',
#  'His eyes look at me so."',
#  '"There is no child there, my dear," urged the man; "you are overwrought,\nexcited, nervous.',
#  'The music starts.',
#  'Let us go."',
#  'He stretched out his hand to the woman, but as he came nearer she shrank\nback with her own hand on her heart.',
#  '"Oh," she said faintly, "he\'s gone."',
#  '"Of course he\'s gone," he answered soothingly.',
#  '"Now is our time to get\naway.',
#  'Let me--"\n\n"No, no," said the woman.',
#  '"I can\'t go with you now.',
#  'It wouldn\'t be\nright."',
#  '"But you knew that before," pleaded the man.',
#  '"Besides--"\n\n"Yes, but I can\'t do it.',
#  'He was there!',
#  'His eyes spoke--I--don\'t touch\nme," she said; "I\'m going back to my husband.',
#  'Don\'t follow."',
#  'II\n\nThe Child\n\n\n\n\n"SUFFER THE LITTLE CHILDREN TO COME UNTO ME"\n\n\n\n\nII\n\nThe Child\n\n\nThe employees had all gone home, carrying with them Christmas checks and\nhearty greetings from the great man whose beck and nod they followed.',
#  'He\nsat in his private office absolutely alone.',
#  'He had some serious matters\nto consider and did not want any interruptions.',
#  "His balance-sheet for\nthe year had been made up according to the custom of the firm before\nChristmas instead of on New Year's Day.",
#  'He examined it again.',
#  'It showed\ntremendous profit.',
#  'The mills were turning out quantities of material,\nthe demand for which was greater and the cost of production less than\never before.',
#  '"I tell you," said the man to himself, "it was a master-stroke to\ndisplace the men with children in the mills.',
#  'They have reduced the cost\nby four fifths.',
#  'War has made the prices go up.',
#  'This is not wealth, it is\nriches beyond calculation."',
#  'He picked up a letter, read it over.',
#  'It was a proposal from the\nsuperintendent to clear more land, to build more buildings, to install\nmore machines, to employ more children and increase the profits greatly.',
#  '"I\'ll do it," said the man.',
#  '"We can crush opposition absolutely.',
#  "I'll\ncontrol the markets of the world.",
#  'I\'ll build a fortune upon this\nfoundation so great that no one can comprehend it."',
#  'He stopped, leaned back in his chair, lifted his eyes up toward the\nceiling of the room and saw beyond it the kingdoms of this world and the\nmeans unlimited to make him lord and master.',
#  'He gave no thought to the\nfoundations, only to the structure erected by his fancy.',
#  'How long he\nindulged in dreams he scarcely realized, but presently he put his hands\non the arms of the chair and started to rise, saying,\n\n"I\'ll telegraph the superintendent to go ahead."',
#  'He had scarcely formulated the words when right in front of him, seated\non his desk, he saw a young lad regarding him intently.',
#  'He stopped,\npetrified, in the position he had assumed.',
#  '"How did you get in?',
#  'What are you doing here?"',
#  'he asked.',
#  'There was no\nanswer.',
#  '"Come," said the man, shrinking back.',
#  '"I can\'t imagine how you\ngot in here.',
#  'If my people had not all gone I should hold them to strict\naccount.',
#  'As it is, you--"\n\nThe room was suddenly filled with people.',
#  'They came crowding through the\nwalls from every side and pressed close to him.',
#  'Such people he had never\nseen: wan, worn, stunted, pinched, starved, joyless.',
#  'They were all\nchildren, meagerly clothed, badly nourished, ill developed.',
#  'They were\nquite silent.',
#  'They did not cry.',
#  'They did not protest.',
#  'They did not\nargue.',
#  'They did not plead.',
#  'They did not laugh.',
#  'They just looked at him.',
#  'They made no sound of any sort.',
#  'He had children of his own and he had\nknown many children.',
#  'He had never known so many gathered together\nwithout a smile or a laugh.',
#  'His eye wandered around the room.',
#  'They were very close to him and yet\nthey did not touch him.',
#  'He turned to the desk where the lad had sat, but\nhe was no longer there and yet he well remembered his face.',
#  'He knew\nexactly how he looked.',
#  'He turned to the nearest child and in some\nstrange way, although the poor, wretched face had not changed, his look\nsuggested the lad who had been his first visitor.',
#  'He turned to another\nand another.',
#  'They all looked back at him in the same way with the same\neyes.',
#  'He threw his head up again and saw the castle of success of which he had\ndreamed.',
#  'He looked down again.',
#  'This was the foundation.',
#  'Slowly his hand\nwent to the desk.',
#  'The little crowding figures drew back to give him\nfreedom of movement as he stretched his hand out for a telegraph-blank.',
#  'He drew it to him.',
#  'He seized a pen and wrote rapidly:\n\n"Build no more mills, take the children out of those already in\noperation, put men in their places.',
#  'We will be content with less profit\nin the future."',
#  'He read over the telegram.',
#  'The telephone was close at hand.',
#  'He called up\nthe telegraph-office, dictated it and directed it to be sent\nimmediately.',
#  'He had been so engrossed in this task that he had noticed\nnothing else.',
#  'Now he looked up.',
#  'The room was still filled with children,\nbut they were all laughing.',
#  'It was a soundless laugh, and yet he heard\nit.',
#  'And then the room was empty save for the child he had seen first and\nvaguely.',
#  'He had just time to catch a smile from his lips and then he,\ntoo, was gone as silently and as strangely as he had appeared.',
#  'Was it a dream?',
#  'No, there was the telegram in his hand!',
#  'Had he sent it?',
#  'Again he called up the office on the telephone.',
#  '"Did you get a message from me just a minute ago?"',
#  '"Yes, do you want to recall it?"',
#  'The man thought a second.',
#  '"No," he said quietly--was it to himself or to his vanished\nvisitors?--"let it go.',
#  'Merry Christmas."',
#  'III\n\nThe Friend\n\n\n\n\n"INASMUCH AS YE HAVE DONE IT UNTO ONE OF THE LEAST OF THESE, MY\nBRETHREN"\n\n\n\n\nIII\n\nThe Friend\n\n\n"Is the story of the Christ Child true, Mommy?"',
#  'quivered one little,\nthin voice.',
#  '"Yes, they told us it was over at the mission Sunday-school," said the\nlittlest child.',
#  '"I don\'t believe it," answered the mother.',
#  '"God ain\'t never done much\nfor me."',
#  '"It\'s Christmas eve, ain\'t it?"',
#  'asked the boy, climbing up on the thin\nknees of the threadbare woman and nestling his thin face against a\nthinner breast which the rags scarcely covered decently.',
#  '"Yes, it\'s Christmas eve."',
#  '"And that\'s the day He came, ain\'t it?"',
#  'urged the oldest girl.',
#  '"They say so."',
#  '"Don\'t you believe it, Mommy?"',
#  '"I used to believe it when I was a girl.',
#  'I believed it before your\nfather died, but now--"\n\n"Don\'t you believe it now?"',
#  'repeated the first child.',
#  '"How can I believe it?',
#  "You're old enough to understand.",
#  "That's the last\nscuttle of coal we got.",
#  'We ate the last bit of bread for supper\nto-night."',
#  '"They say," put in the little boy, "that if you hang up your stockings,\nSanta Claus\'ll fill \'em, \'cause of the Christ Child."',
#  '"Don\'t you believe it, Sonny," said the mother desperately.',
#  '"I\'m going to hang up mine and see," said the littlest girl.',
#  '"He\'s got too many other children to look after," said the woman, "to\ncare for the likes of us, I\'m afraid, and--"\n\n"But my Sunday-school teacher said He came to poor people special.',
#  'He\nwas awful poor Himself.',
#  'Why, He was born in a stable.',
#  'That\'s awful poor,\nain\'t it?"',
#  'asked the boy.',
#  '"When I was a girl," answered the mother, "I lived on a farm and we had\na stable there that was a palace to this hole we live in now.',
#  'No, you\'d\nbetter not hang up your stockings, none of you."',
#  '"And you don\'t believe in Him, Mommy?"',
#  '"No.',
#  'What would be the use if you hung \'em up and didn\'t find anything\nin \'em in the morning?"',
#  '"It\'d be awful, but I believe in Him," said the littlest girl.',
#  '"I don\'t\nthink God has forgot us, really.',
#  'I\'m going to try."',
#  '"I tell you \'tain\'t no use."',
#  '"Oh, yes, it is."',
#  '"I\'m sure it ain\'t.',
#  'But have it your own way," said the woman.',
#  '"If\nsomeone would fill your stockings with milk and bread and--"\n\n"I want a turkey," said the oldest girl.',
#  '"And cranberry sauce," added the boy.',
#  '"I want a doll-baby in mine," said the littlest girl.',
#  'The mother hid her face and groaned aloud.',
#  '"You ain\'t sick, are you, Mommy?"',
#  '"I guess so.',
#  "Come, you'd better say your prayers and go to bed.",
#  'We don\'t\nhave to keep the fire going so hard when you\'re all covered up."',
#  'It did not take long for the three little youngsters to divest\nthemselves of the rags of clothing they wore.',
#  'They slept in what passed\nfor their underclothes, so there was no donning of white gowns for the\nnight.',
#  '"Here are our stockings, Mommy," said the oldest, handing three ragged,\nalmost footless, black stockings to the woman.',
#  '"It\'s no use, I tell you.',
#  'I can\'t do it."',
#  '"It won\'t do any harm, Mommy," urged the girl.',
#  '"Do you believe in it, too?"',
#  'asked the mother, and the girl shook her\nhead.',
#  '"You won\'t be disappointed in the morning if there\'s nothing in\n\'em?"',
#  '"No, I suppose it will be because Santa Claus was too busy."',
#  'With nervous fingers the woman hung the three stockings near the window.',
#  'She was hungry, she was cold, she was broken, she was a mother.',
#  'She\ncould scarcely keep from crying.',
#  '"Maybe you\'ll be glad you did it," said the littlest girl drowsily.',
#  '"Ain\'t you comin\' to bed, too, Mommy?"',
#  'asked the oldest, beneath the\ncovers over the mattress on the floor.',
#  '"In a little while."',
#  '"And you won\'t forget to say your prayers?"',
#  '"I ain\'t said \'em for months, ever since your father was killed, and we\ngot so poor."',
#  '"But you\'ll say \'em to-night \'cause it\'s Christmas eve?"',
#  '"Yes, to-night," said the mother; "now you go to sleep."',
#  '"Are you waitin\' for him to come, Mommy?"',
#  'asked the littlest girl, who\nwas very sleepy.',
#  '"Yes," said the mother.',
#  'Presently, as she sat in the dark, having turned out the light, the deep\nbreathing of the children told her they were asleep.',
#  'She rose quietly,\nstepped to the window, and stood looking at the three shapeless,\ntattered stockings.',
#  'She was high up in the tenement and the moonlight\ncame softly over the house roofs of the city into the bare, cold,\ncheerless room.',
#  'She stared at the stockings and tears streamed down her\nwasted cheeks.',
#  'She had hung them low at the suggestion of the littlest\ngirl so the children could easily get at them in the morning.',
#  '[Illustration: She pressed them against her face.]',
#  'After a time she fell down on her knees.',
#  'She pressed them against her\nface.',
#  'She did not say anything.',
#  'She could scarcely think anything.',
#  'She\njust knelt there until something gently drew her head around.',
#  'She\ndropped the stockings.',
#  'She put her right hand on the window-ledge to\nsteady herself and looked backward.',
#  "No sound save the breathing of the children and her own stifled sobs had\nbroken the silence; the door was shut, but a man was there, a man of\nstrange vesture seen dimly in the moon's radiance, yet there was a kind\nof light about his face.",
#  'She could see his features.',
#  'They were those of\na man in middle years.',
#  'They were lined with care.',
#  'He had seen life on\nits seamy side.',
#  'The woman felt that he had known poverty and loneliness.',
#  'She stared up at him.',
#  '"I didn\'t believe," she whispered; "it cannot be.',
#  'I thought we were\nforgotten."',
#  'The man slowly raised his hand.',
#  'The moonlight struck fair upon it.',
#  'She\nsaw that it was calloused, the hand of a man who toiled.',
#  'It was extended\nover her head.',
#  'There was no bodily touch, but her head bent low down\nuntil she rested it upon her hands upon the floor.',
#  'When she looked up,\nthe room was empty.',
#  'There was no sound save the breathing of the\nchildren and the throb of her own heart which beat wildly in the fearful\nhollow of her ear.',
#  'She heard a sound of strange footsteps outside the door.',
#  'There was a\ncrackle as of paper, the soft sound of things laid upon the floor, a\ngentle rapping on the panels, a light laugh, a rustle of draperies,\nfootsteps moving away.',
#  'As in a dream she got to her feet, she knew not\nhow.',
#  'She opened the door.',
#  'The hall was dimly illuminated.',
#  'Her feet struck a little heap of\njoy-bringing parcels.',
#  'She leaned back against the door-jamb, her hand\nto her heart, trembling.',
#  'What could it mean?',
#  'A tiny voice broke the silence.',
#  'It was the littlest girl turning over in\nher sleep, murmuring incoherently and then clearly:\n\n"If you only believe, that\'s enough; if you only believe."',
#  'IV\n\nThe Workman\n\n"IS NOT THIS THE CARPENTER?"',
#  'IV\n\nThe Workman\n\n\nIn the mean squalid room back of the saloon half a score of men were\nassembled.',
#  'They were all young in years, in other things not youthful.',
#  'Some of them lounged against the wall.',
#  'Some sat at tables.',
#  'All were\ndrinking.',
#  'The air was foul with smoke and reeked with the odor of vile\nliquor.',
#  '"We\'ve got two jobs on hand to-night," said the leader of the gang.',
#  '"There\'s a crib to be cracked an\' a guy to be croaked.',
#  "Red, you an'\nGypsie an' the Gunney will crack the crib.",
#  "It's dead easy.",
#  "Only an old\nman an' his wife.",
#  "The servants are out except one an' he's fixed.",
#  "I'll\ngive you the layout presently.",
#  "The other job's harder.",
#  "Kid, I'll put you\nin charge, an' as it's got to be done early to-night I'll give you the\norders now.",
#  "He'll be at The Montmorency at ten o'clock.",
#  'Someone will\ncall him out to the street."',
#  '"Who?"',
#  '"Never mind who.',
#  'You\'ll be there in the car."',
#  '"Whose car?"',
#  '"Never mind whose.',
#  "Why're you askin' so many questions?",
#  "It'll take you\nan' the four to The Montmorency at ten o'clock.",
#  'When he comes out every\none of you let go, the whole bunch, understand.',
#  'If they don\'t find five\nbullets in him there\'ll be trouble to-morrow."',
#  '"What do we get out of it?"',
#  '"A hundred apiece fer you an\' a hundred an\' fifty fer me fer engineerin\'\nthe job.',
#  'Christmas money!',
#  'You get me?"',
#  '"Of course.',
#  'How\'ll we know who we\'ve got to shoot?"',
#  '"I\'ll be there myself on the sidewalk.',
#  'I\'ll point him out to you."',
#  '"The police?"',
#  '"They\'re fixed."',
#  '"Easy enough," said the Kid, the youngest of the gang.',
#  '"Well, you guys," said the leader pointing out four of the men, "will go\nwith the Kid.',
#  'The car\'ll be at the door in half an hour."',
#  '"Now, gimme my orders," said Red.',
#  'The gang leader scribbled something on a bit of paper.',
#  '"You go to that number with these two guys between midnight an\' two in\nthe mornin\'.',
#  "You'll find a back winder open.",
#  "Here's the combination of\nthe safe.",
#  'The silver\'ll be in that."',
#  '"Jewels?"',
#  '"In a wall cabinet upstairs.',
#  'It\'ll be unlocked."',
#  '"An\' if they make any noise?"',
#  '"Croak \'em, of course.',
#  "But don't make no noise doin' it.",
#  'Better use a\nblackjack.',
#  'We\'re not sure about the cop on that beat."',
#  '"I understand."',
#  '"Well, git your gats and make ready.',
#  "Before we go, the drinks'll be on\nme.",
#  'Fill up, men," he added, first pouring himself a liberal glassful,\n"an\' here\'s to bringin\' it off easy."',
#  'With deep relish the toast was drunk by all save Red and the Kid.',
#  'Red\nset his glass down on the table.',
#  'The Kid dropped his to the floor.',
#  '"There\'s somebody else in the room," whispered Red.',
#  '"Yes, yonder by the door," said the Kid.',
#  '"You c\'n jest see him."',
#  '"Don\'t be a fool," said the gang leader.',
#  '"There\'s nobody here but us."',
#  '"He\'s wearin\' strange clothes," said Red.',
#  '"He looks like a carpenter by his kit o\' tools," said the Kid.',
#  '"Here, pull yourselves together, men," said the gang leader; "you\'re\ndippy, there\'s nobody here.',
#  'Where\'s your nerve?"',
#  'But Red made no move to obey.',
#  'He thrust his glass from him and rose and\nleaned over the table staring.',
#  'The other men shrank back glancing at the\ntwo figures, for the Kid had also dashed the proffered glass aside.',
#  '"I see him," he said, "he\'s lookin\' at me, he\'s lookin\' through me."',
#  'In his excitement he took a step forward and the table went over with a\ncrash.',
#  'The two men passed their hands over their eyes in bewilderment.',
#  '"Why, there ain\'t nobody here," said the Kid.',
#  '"But I seen him I tell you," persisted Red.',
#  '"And so did I."',
#  '"Well, he\'s gone, whoever he was, accordin\' to your own showin\'," said\nthe gang leader contemptuously.',
#  '"Now brace up.',
#  'Take your liquor.',
#  'Get a\nmove on youse."',
#  '"Not me," exclaimed Red suddenly.',
#  '"Nor me," said the Kid.',
#  '"What d\'ye mean?"',
#  '"I won\'t do it."',
#  '"Neither will I."',
#  'Both men moved to the door.',
#  'The gang leader sprang to intercept them,\nhis arms upraised, his hands clenched.',
#  '"Lemme pass," said Red.',
#  '"Are you goin\' to give us away?"',
#  '"No," answered Red.',
#  '"But you don\'t rob no house, an\' you don\'t kill no\nman to-night."',
#  '"You all know what that means," cried the leader.',
#  '"Here you men grab\n\'em."',
#  'But the rest of the gang hung back.',
#  '"Mebbe they did see somethin\'," said one.',
#  '"You cowardly dogs," cried the leader.',
#  '"We won\'t mention no names to nobody," said the Kid, "but you can\'t\npull them jobs off.',
#  'We\'ll jest warn \'em."',
#  '"You swore you\'d be true to the gang, that you\'d obey orders an\' follow\ndirections."',
#  '"We won\'t give ye away but I\'m goin\' to quit the gang an\' go to work,"\nsaid Red.',
#  '"Me too," said the Kid.',
#  '"Work!',
#  'Hell!"',
#  'exclaimed the gang leader, but they shoved him out of the\nway and went out of the door.',
#  'V\n\nComforter\n\n\n\n\n"NEITHER DO I CONDEMN THEE"\n\n\n\n\nV\n\nThe Comforter\n\n\nShe was a daughter of shame.',
#  'Even inexperience could see that as she\nwandered up and down the streets of the town, desperate, impelled to go\non by a force too strong for her to resist.',
#  'She trod the pavement, yet\nloathed the necessity and hated herself for her compliance.',
#  'She had only\nto look forward to the jail or the hospital; yet there was always the\nriver.',
#  'Had it come to that?',
#  'Was there nothing else?',
#  'She lifted her eyes from the stone walk as hard as the heart of the\nworld, and found herself opposite a brightly lighted building.',
#  'She\nleaned against the door.',
#  'From within came the sound of music, the\nstrains of a hymn, words of prayer.',
#  'The light streamed about her face\nfrom the stained window.',
#  'This was a Church of God.',
#  'Stained window,\nstained woman, confronting each other in the night!',
#  'There was no God for her.',
#  'There might have been once, but she had\ncommitted the unpardonable sin against society and society was God.',
#  'There was no place for her anywhere, save the jail or the hospital or\nthe river.',
#  'That last was the best.',
#  'The street was deserted.',
#  'She had\nthought it not a good place in which to ply her trade!',
#  'She made a step\nforward and stopped.',
#  'In her pathway stood a figure seen dimly in the darkness.',
#  'It stood in\nthe shadow beyond the broad light from the painted window.',
#  'There was\nsomething strangely familiar about it.',
#  'She glanced up at that window.',
#  'Had the figure there stepped down and embodied itself vaguely on the\nwalk before her?',
#  '[Illustration: She laid her hand upon the knob of the church door.]',
#  'What was this strange figure?',
#  'Who was he?',
#  'As she stared, the outline\ndrew nearer.',
#  'A man vested in long white draperies confronted her.',
#  'He was\nbareheaded and appeared insensible to the cold in which she shivered.',
#  'She put out her hand and something folded it back upon her breast.',
#  'She\nopened her lips and something sealed them.',
#  'As she watched, the figure slowly moved.',
#  'It bent forward and went slowly\ndown on its knees on the sidewalk.',
#  'The white hand began to trace\nstrange, mysterious, unknown, incomprehensible characters upon the\npavement.',
#  'She watched with bated breath, some memory of another sinful\nwoman of whom she had heard in childhood coming back to her prostrate\nmind.',
#  'Yes, and there behind the figure stood others, hateful and hating,\nvery violent, passionate men.',
#  'She stared from the handwriting in the\ndust to these others and they faded away.',
#  'She was alone with the\nkneeling figure and, as she looked, it too vanished in the chill air.',
#  'She bent over the pavement.',
#  'There was nothing there, yet she had\nreceived a message.',
#  'After a last glance she turned away, new courage,\nnew life, new hope in her heart.',
#  'She mounted the steps, she laid her hand upon the knob of the church\ndoor, she turned it and went bravely within.',
#  'VI\n\nThe Burden Bearer\n\n"HE, BEARING HIS CROSS, WENT FORTH"\n\n\n\n\nVI\n\nThe Burden Bearer\n\n\nThe sound of the running feet of the man smashing through the burned\nstubble ceased abruptly.',
#  'He stopped at the threshold of the door.',
#  'No\nfriendly bark of dog welcomed him.',
#  'From the barn there came no gentle\nlowing of cattle, no homely clucking of chickens.',
#  'Like the house the\nbyre too had been ruined, gutted with flame.',
#  'The soldier whose march had brought him back to his own village that\nnight stood in the entrance of what had been his home and stared at the\nsmoking walls, the charred roof gaping to the sky, the empty casements.',
#  'The enemy had been there.',
#  "He whispered his young wife's name, he called\nsoftly to the baby, as if they might be sleeping somewhere within the\ndevastated house.",
#  'He listened for a reply but none came.',
#  'Perhaps he\nwould have been thankful even for a groan or a cry of agony, anything\nthat meant life.',
#  'But all was silence within, without.',
#  'Yonder on the winding road at the foot of the hill he could hear the\ntrampling of men, the groaning of wheels, the clank of iron cavalrymen,\nthe jingling of bits and swords, sharp words of command.',
#  'The army was\nadvancing.',
#  'He could delay no longer.',
#  'He must get back to his place in\nthe ranks.',
#  'Summoning his courage he crossed the threshold and stepped\ninto the vacant emptiness of the house.',
#  'Everything was gone but the four\nstone walls.',
#  'There were unrecognizable heaps of ashes here and there.',
#  'He\nbent over them fearfully in the twilight wondering whether the\nshapeless, formless masses were--\n\nSomething caught his eye.',
#  'The one thing intact apparently.',
#  'He stooped\nover it.',
#  "It was the baby's shoe--white, it had been originally.",
#  'He\nremembered it.',
#  'Now it was stained with blood.',
#  "That was all that was\nleft--a little baby's shoe, blood spotted.",
#  'He pressed it to his heart\nand groaned aloud.',
#  'A spasm of mortal anguish shook his frame.',
#  'He lifted\nhis clenched hand toward the sky overshadowing the roofless walls.',
#  'Now he suddenly became aware that he was not alone.',
#  'There was someone\nelse in the room.',
#  'He saw vaguely, indistinctly, a figure strangely clad,\nstaggering on with bended back as if under some crushing load.',
#  'He stared\nin the twilight striving to concentrate his faculties.',
#  'The figure passed\nby.',
#  'On its back was a shadowy something--beams of wood roughly crossed,\nhe decided.',
#  'It raised its head and looked at him.',
#  'The face was somehow\nlighter than the rest.',
#  "The man's arm fell.",
#  'The room was empty after all.',
#  'He stared at the\nlittle shoe.',
#  'Was it somewhere well with the child, with its mother?',
#  'Unbuttoning his tunic he thrust the little shoe within, over his heart.',
#  'He straightened up.',
#  'Away off on the road a bugle call rang out above the\ntumult.',
#  'He turned away, seized his rifle, shouldered it, stepped rapidly\ntoward his regiment and his duty.',
#  'VII\n\nThe Thorn Crowned\n\n"THE SOLDIERS PLATTED A CROWN OF THORNS AND PUT IT ON HIS HEAD"\n\n\n\n\nVII\n\nThe Thorn Crowned\n\n\nIt was ghastly cold in the ruined church.',
#  'It had been warm enough there\nduring the day, but the fire that had gutted it had died like the young\nacolyte, like the aged sacristan, the venerable mother, the sweet young\nnovice, the women who had sought shelter there in vain.',
#  'Neither the\ndignity of age nor the sweetness of maidenhood nor the innocence of\nyouth nor the sanctity of profession had availed.',
#  'The old priest was glad they were dead.',
#  'Life after what they had\nsuffered had been unthinkable.',
#  'He thanked God for that oblivion.',
#  'He\nwished that he, too, might die in that violated shrine where he had\npeacefully ministered for so long a time.',
#  'They had taken the flock, the\nshepherd must follow.',
#  'He should have led.',
#  'He had fought, oh, he had played the man for the honor of the poor lambs\ncommitted to him.',
#  'Had he done right?',
#  'Should he not have stood dumb\nbefore the shearers?',
#  'They had shot him and stabbed him and beaten him\ninto insensibility.',
#  'The last thing he had heard was the shriek of one\nwoman, the piteous appeal of another.',
#  'They thought he was dead, but he\nwas living.',
#  'Why had he not died?',
#  'How could God be so cruel?',
#  'This was war.',
#  'This ruined sanctuary, these\nbroken men and women who had sought only to serve Him!',
#  'Was there a God\nindeed?',
#  'Faith, hope, what were they?',
#  'Assurance, trust?',
#  'Words, words!',
#  'Ah,\nhow he suffered.',
#  '[Illustration: "It is He," whispered the priest.',
#  '"His sorrow was\ngreater than mine."]',
#  'It was bitter cold and yet he burned with fever.',
#  'The tremors of pain so\nexquisite that they might almost be counted pleasure shot through his\nruined, torn, broken figure, yet he recked little of these.',
#  'It was the\nshame, the shame.',
#  'He had been zealous for the Lord of Hosts.',
#  'There was\nno God.',
#  'Men were not made in any image save that of hell.',
#  'He could not\nmove hand or foot, but he could see.',
#  'He could speak.',
#  'He could curse God\nand die.',
#  'As his lips framed that anathema he saw vaguely the figure of a\nstranger; a slender, wasted body, dark stains upon it in the moonlight.',
#  'It wore some kind of curious headgear.',
#  'The man stared.',
#  'The light was\nreflected from the sharp points of long thorns.',
#  'A cloth was fastened\nabout the loins.',
#  'The figure stood very straight in the desecrated Holy\nof Holies.',
#  'A light seemed to come from its face.',
#  'Its eyes looked at the\nman with great pity.',
#  'Slowly the figure raised its arms.',
#  'Slowly the arms\nextended themselves; there were blood-stains in the palms of the hands.',
#  '"It is He," whispered the priest.',
#  '"His sorrow was greater than mine.',
#  'Lord, I believe."',
#  'He knew nothing more save that a great peace had suddenly stolen around\nhim.',
#  'VIII\n\nThe Broken Hearted\n\n\n\n\n"ONE OF THE SOLDIERS WITH A SPEAR PIERCED HIS SIDE"\n\n\n\n\nVIII\n\nThe Broken Hearted\n\n\n"I\'ll get that man if I die for it," said the soldier.',
#  '"He\'s found the\none position in the lines from which he can fire into our trenches."',
#  '"It\'s easier said than done," remarked his comrade, "and the minute you\ncross that spot you come within his range.',
#  'He\'ll put a bullet through\nyou before you can level a rifle or press a trigger."',
#  '"I\'ll not go that way," said the man.',
#  '"What is your plan?"',
#  '"You know that salient yonder on the right?',
#  'I\'m going out of the trench\nthere."',
#  '"When?"',
#  '"Now.',
#  "I'll wrap myself in white.",
#  'That little run of coppice will cover\nme until I get within a few feet of him, then I\'ll have to chance it."',
#  '"Wish I could help you, old man.',
#  "I'd like to get that man.",
#  'He\'s shot six\nof the best fellows in the company and--"\n\n"You can help me by making a diversion to attract his attention.',
#  'Keep\nhim looking at that alley."',
#  'A few moments later the soldier shrouded in white crept out of the\ntrench and noiselessly rolled down the slope to the bushes.',
#  'The snow was\ndeep on the ground.',
#  'There was no touch of color about the soldier.',
#  'He\neven thrust his rifle under the linen in which he had wrapped himself.',
#  'Outside the shelter of the trenches the wind blew with terrific force.',
#  'It was terribly cold.',
#  'He had discarded his overcoat for freedom of\nmotion.',
#  'Only his indomitable resolution kept him alive.',
#  'He locked his\njaws together to keep his teeth from chattering.',
#  'The ice-covered snow\nunder his bare hands almost blistered the flesh as he crept along.',
#  'He intended to use the bayonet.',
#  'If he shot the man he was stalking alarm\nwould be given and he would be riddled with bullets before he got back.',
#  'He was willing to give a life for a life if it were necessary, but he\nwas reluctant to do so if it could be avoided.',
#  'Cold steel would be\nbetter.',
#  'Cold steel!',
#  'He smiled grimly.',
#  'It would need some hot blood to\ntake the chill off the bayonet at the end of his rifle.',
#  'Slowly, almost holding his breath lest he be noticed, he edged his way\nalong.',
#  'He had plenty of time for thought.',
#  'This was not so easy a job as\nhe had fancied, not the physical part, but the mental strain.',
#  'He could\nshoot a man who was shooting at him, he could batter a man over the head\nwho was trying to do the same to him, but this stalking a man in cold\nblood was different somehow.',
#  'Cold blood!',
#  'He laughed soundlessly at his\nrecurrent fancy.',
#  'He went a little more slowly.',
#  'Finally he stopped to\nconsider.',
#  'From the nook ahead of him in which the enemy had ensconced himself came\na sudden rapid rattle of rifle-shots.',
#  'His friend back in the trench was\ndoing his part.',
#  'The man was awake--on the alert.',
#  'It would be something\nof a fair fight, he thought with some little satisfaction.',
#  'He surveyed\nthe intervening space beyond the coppice.',
#  'The men in the trenches on\nboth sides would be awake, too.',
#  'It would take him a few seconds to cross\nthat space and get at the man he was stalking.',
#  'Could they shoot him\nbefore that?',
#  'There was some shelter where the enemy was.',
#  "If the stalker\ncould get to that spot he would be protected for a moment from fire from\nthe enemy's trench.",
#  'It would take him a second or two to cross that space.',
#  'In a second or\ntwo what might happen?',
#  'Well, he would have to risk that.',
#  'At the very\nend of the coppice he gathered himself together and rose slowly to a\ncrouching position.',
#  "Another rain of shots came from the nook; the man's\nrifle would be empty, he must give him no chance to reload.",
#  'Now it would\nbe a fair fight with the bayonet.',
#  'He threw aside the white draperies that impeded his legs and in half a\ndozen bounds the two men were face to face.',
#  'No shot had been fired.',
#  "Yes, the magazine of the man's rifle was empty.",
#  "He heard the crunch of his enemy's feet on the snow.",
#  'He rose to his\nfeet, his bayoneted rifle extended.',
#  'The two barrels struck with terrific\nforce.',
#  'The men swayed, drew back for another thrust, and they were\nsuddenly aware of a mist-like figure between them, a figure draped in\nwhite, lightly, diaphanously.',
#  'They stood arrested, guns drawn back, and stared.',
#  'The figure slowly\nextended its arm, carrying drapery with it.',
#  "A man's breast was bared.",
#  'There, over the heart, was a great gaping wound, fresh, as if a broad,\nheavy blade had pierced it.',
#  'There was a clatter on the ice as a gun dropped and another clatter as a\nsimilar weapon struck the stone opposite.',
#  'The two men bent forward,\ntheir hands outstretched.',
#  'They took a step as if to touch the figure and\nthere was nothing there!',
#  'The hands met.',
#  'They clasped warmly in the cold\nagainst each other.',
#  '"My God, what was that?"',
#  'said the stalker.',
#  '"I don\'t know," answered the other.',
#  '"A pierced side!"',
#  '"Was it--"\n\n"No.',
#  'It couldn\'t be."',
#  '"Well, we worship the same God and--"\n\nAh, they were seen.',
#  'There were quick words of command from the\ntrenches, a staccato of rifle-shots, and two bodies lay side by side,\nhands still clasped, while the snow reddened and reddened beneath them.',
#  'And it was Christmas eve.',
#  'IX\n\nThe Forgiver of Sins\n\n\n\n\n"I SAY UNTO THEE UNTIL SEVENTY TIMES SEVEN"\n\n\n\n\nIX\n\nThe Forgiver of Sins\n\n\n"A Priest, for Christ\'s sake, a priest," moaned the man.',
#  'A white-faced sister of charity upon whom had developed the appalling\ntask of caring for the long rows of wounded at the dressing station\nbefore they were entrained and sent south to the hospital, hovered over\nthe stretcher.',
#  '"My poor man," she whispered, "there is no priest here."',
#  '"I can\'t die without confession--absolution," was the answer.',
#  '"A priest,\nget me a priest."',
#  'Next to and almost touching the cot on which the speaker writhed in his\ndeath agony lay another man apparently in a profound stupor.',
#  'He wore\nthe uniform of a private soldier and his eyes were bandaged.',
#  'His face\nhad been torn to pieces by shrapnel, fragments of which had blinded him.',
#  'At that instant he came out of that stupor.',
#  'Perhaps the familiar words\nrecalled him to himself.',
#  'He moved his hand slightly.',
#  'The sister saw his\nlips tremble.',
#  'She bent low.',
#  '"Who seeks confession, absolution?"',
#  'he whispered.',
#  '"I am a priest."',
#  '"You are wounded, dying, father."',
#  '"How can I die better than shriving a fellow sinner?"',
#  'That was true.',
#  'The heroic woman turned to the man who still kept up his\nmonotonous appeal.',
#  '"The man next to you," she said, "dying like you, is a priest."',
#  '"Father," cried the first man with sudden strength.',
#  '"I must confess\nbefore I die."',
#  '"Lift me up," said the priest.',
#  'The woman slipped her arm about his shoulders and raised him.',
#  '"The sister?"',
#  'began the other.',
#  '"I shall be blind and deaf," said the woman.',
#  '"Speak on," whispered the priest.',
#  '"I have been a great sinner--there isn\'t time to confess all."',
#  '"What is heaviest upon your soul, my son?"',
#  '"A woman\'s fate."',
#  '"Ah."',
#  '"There were two who loved her--a dozen years ago--she preferred me--I\ntook her away."',
#  '"Did you marry her?"',
#  '"No.',
#  'And then we quarreled--I deserted her.',
#  'When I came to seek her she\nwas gone--young, innocent, penniless, alone in Paris--I have sought her\nand never found her."',
#  '"What is your name?"',
#  'asked the priest suddenly with a fierce note in\nhis quivering voice.',
#  '"Father, can I be forgiven?"',
#  'answered the man giving his name.',
#  'The dying soldier stared anxiously up at his bandaged comrade, at the\nnun who had hid her face behind the shoulder of the priest.',
#  'He noticed\nthat her body was shaking.',
#  '"And the woman\'s name?"',
#  'The priest suddenly sat upright.',
#  "He shook off the sister's restraining\nhand.",
#  'He tore the bandage from his own face.',
#  "He bent over the dying man\nas he murmured the woman's name.",
#  '"Wretch," he cried, "look at me."',
#  'His face was gashed and cut and torn but something remained by which the\nother recognized him.',
#  '"You!"',
#  'he cried shrinking away.',
#  '"I loved her, too," said the priest.',
#  '"I would have married her.',
#  'When\nshe went away with you Holy Church received me."',
#  '"Mercy," cried the soldier uplifting his hand.',
#  '"What mercy did you show her?"',
#  'The priest could not see but he could feel.',
#  "His hand seized the other's\nthroat.",
#  '"My father," interposed the nun.',
#  '"He has confessed.',
#  'God will forgive,\neven as I."',
#  '"Who are you?"',
#  'asked the blind priest, fearfully.',
#  '"The woman!"',
#  "cried the dying man shaking off the other's hand and\nlifting himself up.",
#  'The sight came back to the priest on the instant.',
#  'The fierce agony that\nfilled his blinded eyes seemed to give place to the gentle touch of a\nhand upon them.',
#  'He seemed to hear a mighty word--_Ephphatha_--that meant\n"be opened."',
#  'Light flooded his soul.',
#  'Looking up he was aware of two\nfigures.',
#  'One of the twain, an old man, gray bearded, was appealing to\nthe other, clad in white raiment and youthful.',
#  'And the priest suddenly\nrecalled an old and well-known story of a fellow servant who would not\nhave mercy.',
#  '"Father, forgive--" whispered the man before him.',
#  'As the voice of the dying sinner died away in the silence all was dark\nagain.',
#  'The priest saw no more, but the horrible pain in his eyes did not\nreturn.',
#  'Over his torn features came a look of calm.',
#  'He lifted his arm.',
#  'His wavering hand cut the air in the sign of the cross.',
#  '"_Absolvo te_," he murmured as he pitched forward dead upon the breast\nof the dying.',
#  'And the woman tenderly covered them over.',
#  '[Illustration: _Absolvo te._]\n\n\n\n\nX\n\nThe Giver of Life\n\n"HE THAT EATETH OF THIS BREAD SHALL LIVE FOREVER"\n\n\n\n\nX\n\nThe Giver of Life\n\n\nOf the five specters in the boat three were without life.',
#  'Those whose\nfaint breathing indicated that they had not yet reached the point of\ndeath were too weak and indifferent to rid the boat of the bodies of the\nothers.',
#  'Ever since the homeward-bound whaler had struck a derelict in a\ngale of wind north of the Falklands and foundered, this little boat,\nsurviving the shipwreck as by a miracle, had drifted on.',
#  'For three weeks in vain they had scanned the horizon for a sail.',
#  'Their\nscanty supply of bread and water had been consumed in ten days.',
#  'Thereafter they had nothing.',
#  "The baby had died first, next a man whose\narm had been broken by a falling spar in the disaster, and then the\nship's cabin boy.",
#  'The survivors were a man and a woman.',
#  'They were both\nfar gone.',
#  'The woman was plainly dying.',
#  'The man kept himself up by sheer\nexercise of will.',
#  'Their drifting had been northward toward warmer seas.',
#  'It was winter in\ntheir home land and, though they knew it not, Christmas day.',
#  'There the\ntropic sun blazed overhead from an absolutely cloudless sky.',
#  'There was\nno vestige of breeze to stir the canvas of the solitary sail or ripple\nthe glassy surface of the smoothed out ocean.',
#  'The boat lay still.',
#  'Not\neven the iron man at the helm could have lifted an oar.',
#  'It had been dead\ncalm for days.',
#  'Speech there was none except in the gravest necessity.',
#  'To\ntalk connectedly was impossible.',
#  "After scanning the horizon for the thousandth time the man's burning\neyes sought those of the woman at his feet.",
#  'He was astonished to find\nthem open.',
#  'Her mouth was working, her parched lips strove to form words.',
#  'He dropped the tiller which his hand had grasped mechanically, and which\nwas useless since there was no way on the boat, and bent his head lower.',
#  'Some sudden recrudescence of strength which the dying sometimes receive\ncame to the woman.',
#  '"Death," she whispered.',
#  '"Glad."',
#  'She turned her head slightly and saw the\nform of the child.',
#  '"The Baby--and--I--together."',
#  'The man nodded.',
#  "Tenderly he laid his hot wasted hand on the woman's\nfevered brow.",
#  '"A priest," she said, looking up at him uncomprehendingly.',
#  'She was evidently going fast yet she knew what she wanted although she\nwas not conscious that she craved the impossible.',
#  'It would appear that\nshe had been a good churchwoman.',
#  'The man could only stare.',
#  'He was no\npriest, only a rough sailor.',
#  '"A priest," said the woman more clearly.',
#  '"I want--a priest--the\nsacrament."',
#  'By some nervous convulsive effort she lifted her arms up\ntoward him beseeching, appealing.',
#  'There was another kind of agony in her\nvoice that had not been present when she had moaned for water in the\ndays before.',
#  '"The sacrament," she insisted, "I die."',
#  'The man looked away.',
#  'Hard by the boat where there had been but a waste\nof sea rose a green island.',
#  'A stretch of pleasant meadow met his eyes.',
#  'It was so close to him that if he had leaned over the gunwale of the\nboat he could have laid his hand on the lush grass.',
#  'Dumbly he wondered\nwhere it had been before, how he had come upon it so suddenly, why he\nhad not seen it hours ago.',
#  'In front of him were hundreds of people, men, women, and children, plain\npeople in strange simple garb, the like of which he had never seen.',
#  'In\nfront of these people and with their backs toward him stood a little\ngroup of men, in the center a figure in white garments.',
#  'A lad offered\nsomething in a basket.',
#  'The man watched, amazed, awe-stricken, yet with a strange peace in his\nsoul.',
#  'He made no movement to gain the shore.',
#  'He only looked and looked.',
#  'The white-robed figure bent over the basket.',
#  'He lifted from it a crude\nrough loaf of bread.',
#  'He raised his eyes to heaven, his lips moved.',
#  'He\nbroke the bread and gave it.',
#  'As the sailor watched the island disappeared as suddenly as it had come.',
#  'The scene changed.',
#  'Now he looked into a low room, dimly lighted with\nstrange lamps.',
#  'Through an open window he saw the stars.',
#  'The few men that\nhad stood about the man in the grassy meadow were alone with him in that\nupper chamber reclining about a table.',
#  'The man lifted from the board a\ncup of silver.',
#  'He blessed it and gave it.',
#  'The fragrance of wine came to\nthe watcher.',
#  'He rubbed his eyes and looked again and before him spread the smooth\nunbroken surface of the monotonous sea.',
#  "The woman's voice smote his ear\nagain, higher, shriller, with more painful entreaty.",
#  '"A priest--for the love of God--the sacrament," she whispered.',
#  'The man tore open the last canvas bread-bag.',
#  'It was tough material but\nit yielded to his insistence.',
#  'In the corner there was a single tiny\ncrumb they had overlooked.',
#  'He lifted it gently with his great hand.',
#  'He\nheld it up in the air a moment striving to think.',
#  'He was an English\nsailor and in his boyhood had been a chorister in a great Cathedral.',
#  'The\nmighty words came back to him.',
#  'He bent over the woman.',
#  '[Illustration: The cry for bread.]',
#  '"Bread," he whispered.',
#  '"The body--"\n\nHe shattered the water breaker with his fist.',
#  'There was a suggestion of\nmoisture on the inside of the staves of the cask.',
#  "He drew his finger\nacross them and touched it to the woman's lips.",
#  '"Water," he said hoarsely.',
#  '"The blood--"\n\nThe terror, the yearning, disappeared from the woman\'s eyes.',
#  'She looked\nat the man sanely, gratefully.',
#  '"God bless--" she faltered and then her lips stiffened.',
# ...
#  'Nearly all the individual works in the\ncollection are in the public domain in the United States.',
#  'If an\nindividual work is in the public domain in the United States and you are\nlocated in the United States, we do not claim a right to prevent you from\ncopying, distributing, performing, displaying or creating derivative\nworks based on the work as long as all references to Project Gutenberg\nare removed.',
#  'Of course, we hope that you will support the Project\nGutenberg-tm mission of promoting free access to electronic works by\nfreely sharing Project Gutenberg-tm works in compliance with the terms of\nthis agreement for keeping the Project Gutenberg-tm name associated with\nthe work.',
#  'You can easily comply with the terms of this agreement by\nkeeping this work in the same format with its attached full Project\nGutenberg-tm License when you share it without charge with others.',
#  '1.D.',
#  'The copyright laws of the place where you are located also govern\nwhat you can do with this work.',
#  'Copyright laws in most countries are in\na constant state of change.',
#  'If you are outside the United States, check\nthe laws of your country in addition to the terms of this agreement\nbefore downloading, copying, displaying, performing, distributing or\ncreating derivative works based on this work or any other Project\nGutenberg-tm work.',
#  'The Foundation makes no representations concerning\nthe copyright status of any work in any country outside the United\nStates.',
#  '1.E.',
#  'Unless you have removed all references to Project Gutenberg:\n\n1.E.1.',
#  'The following sentence, with active links to, or other immediate\naccess to, the full Project Gutenberg-tm License must appear prominently\nwhenever any copy of a Project Gutenberg-tm work (any work on which the\nphrase "Project Gutenberg" appears, or with which the phrase "Project\nGutenberg" is associated) is accessed, displayed, performed, viewed,\ncopied or distributed:\n\nThis eBook is for the use of anyone anywhere at no cost and with\nalmost no restrictions whatsoever.',
#  'You may copy it, give it away or\nre-use it under the terms of the Project Gutenberg License included\nwith this eBook or online at www.gutenberg.net\n\n1.E.2.',
#  'If an individual Project Gutenberg-tm electronic work is derived\nfrom the public domain (does not contain a notice indicating that it is\nposted with permission of the copyright holder), the work can be copied\nand distributed to anyone in the United States without paying any fees\nor charges.',
#  'If you are redistributing or providing access to a work\nwith the phrase "Project Gutenberg" associated with or appearing on the\nwork, you must comply either with the requirements of paragraphs 1.E.1\nthrough 1.E.7 or obtain permission for the use of the work and the\nProject Gutenberg-tm trademark as set forth in paragraphs 1.E.8 or\n1.E.9.',
#  '1.E.3.',
#  'If an individual Project Gutenberg-tm electronic work is posted\nwith the permission of the copyright holder, your use and distribution\nmust comply with both paragraphs 1.E.1 through 1.E.7 and any additional\nterms imposed by the copyright holder.',
#  'Additional terms will be linked\nto the Project Gutenberg-tm License for all works posted with the\npermission of the copyright holder found at the beginning of this work.',
#  '1.E.4.',
#  'Do not unlink or detach or remove the full Project Gutenberg-tm\nLicense terms from this work, or any files containing a part of this\nwork or any other work associated with Project Gutenberg-tm.',
#  '1.E.5.',
#  'Do not copy, display, perform, distribute or redistribute this\nelectronic work, or any part of this electronic work, without\nprominently displaying the sentence set forth in paragraph 1.E.1 with\nactive links or immediate access to the full terms of the Project\nGutenberg-tm License.',
#  '1.E.6.',
#  'You may convert to and distribute this work in any binary,\ncompressed, marked up, nonproprietary or proprietary form, including any\nword processing or hypertext form.',
#  'However, if you provide access to or\ndistribute copies of a Project Gutenberg-tm work in a format other than\n"Plain Vanilla ASCII" or other format used in the official version\nposted on the official Project Gutenberg-tm web site (www.gutenberg.net),\nyou must, at no additional cost, fee or expense to the user, provide a\ncopy, a means of exporting a copy, or a means of obtaining a copy upon\nrequest, of the work in its original "Plain Vanilla ASCII" or other\nform.',
#  'Any alternate format must include the full Project Gutenberg-tm\nLicense as specified in paragraph 1.E.1.',
#  '1.E.7.',
#  'Do not charge a fee for access to, viewing, displaying,\nperforming, copying or distributing any Project Gutenberg-tm works\nunless you comply with paragraph 1.E.8 or 1.E.9.',
#  '1.E.8.',
#  'You may charge a reasonable fee for copies of or providing\naccess to or distributing Project Gutenberg-tm electronic works provided\nthat\n\n- You pay a royalty fee of 20% of the gross profits you derive from\n     the use of Project Gutenberg-tm works calculated using the method\n     you already use to calculate your applicable taxes.',
#  'The fee is\n     owed to the owner of the Project Gutenberg-tm trademark, but he\n     has agreed to donate royalties under this paragraph to the\n     Project Gutenberg Literary Archive Foundation.',
#  'Royalty payments\n     must be paid within 60 days following each date on which you\n     prepare (or are legally required to prepare) your periodic tax\n     returns.',
#  'Royalty payments should be clearly marked as such and\n     sent to the Project Gutenberg Literary Archive Foundation at the\n     address specified in Section 4, "Information about donations to\n     the Project Gutenberg Literary Archive Foundation."',
#  '- You provide a full refund of any money paid by a user who notifies\n     you in writing (or by e-mail) within 30 days of receipt that s/he\n     does not agree to the terms of the full Project Gutenberg-tm\n     License.',
#  'You must require such a user to return or\n     destroy all copies of the works possessed in a physical medium\n     and discontinue all use of and all access to other copies of\n     Project Gutenberg-tm works.',
#  '- You provide, in accordance with paragraph 1.F.3, a full refund of any\n     money paid for a work or a replacement copy, if a defect in the\n     electronic work is discovered and reported to you within 90 days\n     of receipt of the work.',
#  '- You comply with all other terms of this agreement for free\n     distribution of Project Gutenberg-tm works.',
#  '1.E.9.',
#  'If you wish to charge a fee or distribute a Project Gutenberg-tm\nelectronic work or group of works on different terms than are set\nforth in this agreement, you must obtain permission in writing from\nboth the Project Gutenberg Literary Archive Foundation and Michael\nHart, the owner of the Project Gutenberg-tm trademark.',
#  'Contact the\nFoundation as set forth in Section 3 below.',
#  '1.F.',
#  '1.F.1.',
#  'Project Gutenberg volunteers and employees expend considerable\neffort to identify, do copyright research on, transcribe and proofread\npublic domain works in creating the Project Gutenberg-tm\ncollection.',
#  'Despite these efforts, Project Gutenberg-tm electronic\nworks, and the medium on which they may be stored, may contain\n"Defects," such as, but not limited to, incomplete, inaccurate or\ncorrupt data, transcription errors, a copyright or other intellectual\nproperty infringement, a defective or damaged disk or other medium, a\ncomputer virus, or computer codes that damage or cannot be read by\nyour equipment.',
#  '1.F.2.',
#  'LIMITED WARRANTY, DISCLAIMER OF DAMAGES - Except for the "Right\nof Replacement or Refund" described in paragraph 1.F.3, the Project\nGutenberg Literary Archive Foundation, the owner of the Project\nGutenberg-tm trademark, and any other party distributing a Project\nGutenberg-tm electronic work under this agreement, disclaim all\nliability to you for damages, costs and expenses, including legal\nfees.',
#  'YOU AGREE THAT YOU HAVE NO REMEDIES FOR NEGLIGENCE, STRICT\nLIABILITY, BREACH OF WARRANTY OR BREACH OF CONTRACT EXCEPT THOSE\nPROVIDED IN PARAGRAPH F3.',
#  'YOU AGREE THAT THE FOUNDATION, THE\nTRADEMARK OWNER, AND ANY DISTRIBUTOR UNDER THIS AGREEMENT WILL NOT BE\nLIABLE TO YOU FOR ACTUAL, DIRECT, INDIRECT, CONSEQUENTIAL, PUNITIVE OR\nINCIDENTAL DAMAGES EVEN IF YOU GIVE NOTICE OF THE POSSIBILITY OF SUCH\nDAMAGE.',
#  '1.F.3.',
#  'LIMITED RIGHT OF REPLACEMENT OR REFUND - If you discover a\ndefect in this electronic work within 90 days of receiving it, you can\nreceive a refund of the money (if any) you paid for it by sending a\nwritten explanation to the person you received the work from.',
#  'If you\nreceived the work on a physical medium, you must return the medium with\nyour written explanation.',
#  'The person or entity that provided you with\nthe defective work may elect to provide a replacement copy in lieu of a\nrefund.',
#  'If you received the work electronically, the person or entity\nproviding it to you may choose to give you a second opportunity to\nreceive the work electronically in lieu of a refund.',
#  'If the second copy\nis also defective, you may demand a refund in writing without further\nopportunities to fix the problem.',
#  '1.F.4.',
#  "Except for the limited right of replacement or refund set forth\nin paragraph 1.F.3, this work is provided to you 'AS-IS', WITH NO OTHER\nWARRANTIES OF ANY KIND, EXPRESS OR IMPLIED, INCLUDING BUT NOT LIMITED TO\nWARRANTIES OF MERCHANTIBILITY OR FITNESS FOR ANY PURPOSE.",
#  '1.F.5.',
#  'Some states do not allow disclaimers of certain implied\nwarranties or the exclusion or limitation of certain types of damages.',
#  'If any disclaimer or limitation set forth in this agreement violates the\nlaw of the state applicable to this agreement, the agreement shall be\ninterpreted to make the maximum disclaimer or limitation permitted by\nthe applicable state law.',
#  'The invalidity or unenforceability of any\nprovision of this agreement shall not void the remaining provisions.',
#  '1.F.6.',
#  'INDEMNITY - You agree to indemnify and hold the Foundation, the\ntrademark owner, any agent or employee of the Foundation, anyone\nproviding copies of Project Gutenberg-tm electronic works in accordance\nwith this agreement, and any volunteers associated with the production,\npromotion and distribution of Project Gutenberg-tm electronic works,\nharmless from all liability, costs and expenses, including legal fees,\nthat arise directly or indirectly from any of the following which you do\nor cause to occur: (a) distribution of this or any Project Gutenberg-tm\nwork, (b) alteration, modification, or additions or deletions to any\nProject Gutenberg-tm work, and (c) any Defect you cause.',
#  'Section  2.',
#  'Information about the Mission of Project Gutenberg-tm\n\nProject Gutenberg-tm is synonymous with the free distribution of\nelectronic works in formats readable by the widest variety of computers\nincluding obsolete, old, middle-aged and new computers.',
#  'It exists\nbecause of the efforts of hundreds of volunteers and donations from\npeople in all walks of life.',
#  "Volunteers and financial support to provide volunteers with the\nassistance they need, is critical to reaching Project Gutenberg-tm's\ngoals and ensuring that the Project Gutenberg-tm collection will\nremain freely available for generations to come.",
#  'In 2001, the Project\nGutenberg Literary Archive Foundation was created to provide a secure\nand permanent future for Project Gutenberg-tm and future generations.',
#  'To learn more about the Project Gutenberg Literary Archive Foundation\nand how your efforts and donations can help, see Sections 3 and 4\nand the Foundation web page at http://www.gutenberg.net/fundraising/pglaf.',
#  'Section 3.',
#  'Information about the Project Gutenberg Literary Archive\nFoundation\n\nThe Project Gutenberg Literary Archive Foundation is a non profit\n501(c)(3) educational corporation organized under the laws of the\nstate of Mississippi and granted tax exempt status by the Internal\nRevenue Service.',
#  "The Foundation's EIN or federal tax identification\nnumber is 64-6221541.",
#  "Contributions to the Project Gutenberg\nLiterary Archive Foundation are tax deductible to the full extent\npermitted by U.S. federal laws and your state's laws.",
#  "The Foundation's principal office is located at 4557 Melan Dr. S.\nFairbanks, AK, 99712., but its volunteers and employees are scattered\nthroughout numerous locations.",
#  'Its business office is located at\n809 North 1500 West, Salt Lake City, UT 84116, (801) 596-1887, email\nbusiness@pglaf.org.',
#  "Email contact links and up to date contact\ninformation can be found at the Foundation's web site and official\npage at http://www.gutenberg.net/about/contact\n\nFor additional contact information:\n     Dr. Gregory B. Newby\n     Chief Executive and Director\n     gbnewby@pglaf.org\n\nSection 4.",
#  'Information about Donations to the Project Gutenberg\nLiterary Archive Foundation\n\nProject Gutenberg-tm depends upon and cannot survive without wide\nspread public support and donations to carry out its mission of\nincreasing the number of public domain and licensed works that can be\nfreely distributed in machine readable form accessible by the widest\narray of equipment including outdated equipment.',
#  'Many small donations\n($1 to $5,000) are particularly important to maintaining tax exempt\nstatus with the IRS.',
#  'The Foundation is committed to complying with the laws regulating\ncharities and charitable donations in all 50 states of the United\nStates.',
#  'Compliance requirements are not uniform and it takes a\nconsiderable effort, much paperwork and many fees to meet and keep up\nwith these requirements.',
#  'We do not solicit donations in locations\nwhere we have not received written confirmation of compliance.',
#  'To\nSEND DONATIONS or determine the status of compliance for any\nparticular state visit http://www.gutenberg.net/fundraising/donate\n\nWhile we cannot and do not solicit contributions from states where we\nhave not met the solicitation requirements, we know of no prohibition\nagainst accepting unsolicited donations from donors in such states who\napproach us with offers to donate.',
#  'International donations are gratefully accepted, but we cannot make\nany statements concerning tax treatment of donations received from\noutside the United States.',
#  'U.S. laws alone swamp our small staff.',
#  'Please check the Project Gutenberg Web pages for current donation\nmethods and addresses.',
#  'Donations are accepted in a number of other\nways including including checks, online payments and credit card\ndonations.',
#  'To donate, please visit:\nhttp://www.gutenberg.net/fundraising/donate\n\n\nSection 5.',
#  'General Information About Project Gutenberg-tm electronic\nworks.',
#  'Professor Michael S. Hart is the originator of the Project Gutenberg-tm\nconcept of a library of electronic works that could be freely shared\nwith anyone.',
#  'For thirty years, he produced and distributed Project\nGutenberg-tm eBooks with only a loose network of volunteer support.',
#  'Project Gutenberg-tm eBooks are often created from several printed\neditions, all of which are confirmed as Public Domain in the U.S.\nunless a copyright notice is included.',
#  'Thus, we do not necessarily\nkeep eBooks in compliance with any particular paper edition.',
#  'Most people start at our Web site which has the main PG search facility:\n\n     http://www.gutenberg.net\n\nThis Web site includes information about Project Gutenberg-tm,\nincluding how to make donations to the Project Gutenberg Literary\nArchive Foundation, how to help produce our new eBooks, and how to\nsubscribe to our email newsletter to hear about new eBooks.']

# %%
from nltk.tokenize import word_tokenize

# %%
tokens=word_tokenize(text)

# %%
tokens
# Out:
# ['ï',
#  '»',
#  '¿The',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  ',',
#  'And',
#  'Thus',
#  'He',
#  'Came',
#  ',',
#  'by',
#  'Cyrus',
#  'Townsend',
#  'Brady',
#  ',',
#  'Illustrated',
#  'by',
#  'Walter',
#  'B.',
#  'Everett',
#  'This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  '.',
#  'You',
#  'may',
#  'copy',
#  'it',
#  ',',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.net',
#  'Title',
#  ':',
#  'And',
#  'Thus',
#  'He',
#  'Came',
#  'Author',
#  ':',
#  'Cyrus',
#  'Townsend',
#  'Brady',
#  'Release',
#  'Date',
#  ':',
#  'January',
#  '5',
#  ',',
#  '2005',
#  '[',
#  'eBook',
#  '#',
#  '14606',
#  ']',
#  'Language',
#  ':',
#  'English',
#  'Character',
#  'set',
#  'encoding',
#  ':',
#  'ISO-646-US',
#  '(',
#  'US-ASCII',
#  ')',
#  '***START',
#  'OF',
#  'THE',
#  'PROJECT',
#  'GUTENBERG',
#  'EBOOK',
#  'AND',
#  'THUS',
#  'HE',
#  'CAME***',
#  'E-text',
#  'prepared',
#  'by',
#  'Robert',
#  'Cicconetti',
#  ',',
#  'Melissa',
#  'Er-Raqabi',
#  ',',
#  'and',
#  'the',
#  'Project',
#  'Gutenberg',
#  'Online',
#  'Distributed',
#  'Proofreading',
#  'Team',
#  '(',
#  'http',
#  ':',
#  '//www.pgdp.net',
#  ')',
#  'Note',
#  ':',
#  'Project',
#  'Gutenberg',
#  'also',
#  'has',
#  'an',
#  'HTML',
#  'version',
#  'of',
#  'this',
#  'file',
#  'which',
#  'includes',
#  'the',
#  'original',
#  'illustrations',
#  '.',
#  'See',
#  '14606-h.htm',
#  'or',
#  '14606-h.zip',
#  ':',
#  '(',
#  'http',
#  ':',
#  '//www.gutenberg.net/dirs/1/4/6/0/14606/14606-h/14606-h.htm',
#  ')',
#  'or',
#  '(',
#  'http',
#  ':',
#  '//www.gutenberg.net/dirs/1/4/6/0/14606/14606-h.zip',
#  ')',
#  'AND',
#  'THUS',
#  'HE',
#  'CAME',
#  'A',
#  'Christmas',
#  'Fantasy',
#  'by',
#  'CYRUS',
#  'TOWNSEND',
#  'BRADY',
#  'Pictures',
#  'by',
#  'Walter',
#  'B.',
#  'Everett',
#  'G.P',
#  '.',
#  'Putnam',
#  "'s",
#  'Sons',
#  'New',
#  'York',
#  'and',
#  'London',
#  'The',
#  'Knickerbocker',
#  'Press',
#  '1916',
#  '[',
#  'Illustration',
#  ':',
#  '``',
#  'No',
#  ',',
#  'No',
#  ',',
#  "''",
#  'said',
#  'the',
#  'woman',
#  ',',
#  '``',
#  'I',
#  'ca',
#  "n't",
#  'go',
#  'with',
#  'you',
#  'now',
#  '.',
#  "''",
#  ']',
#  'To',
#  'the',
#  'Beloved',
#  'Memory',
#  'of',
#  'Little',
#  'Betty',
#  'Contents',
#  'I.',
#  '--',
#  'THE',
#  'BABY',
#  'II.',
#  '--',
#  'THE',
#  'CHILD',
#  'III.',
#  '--',
#  'THE',
#  'FRIEND',
#  'IV.',
#  '--',
#  'THE',
#  'WORKMAN',
#  'V.',
#  '--',
#  'THE',
#  'COMFORTER',
#  'VI.',
#  '--',
#  'THE',
#  'BURDEN',
#  'BEARER',
#  'VII.',
#  '--',
#  'THE',
#  'THORN',
#  'CROWNED',
#  'VIII.',
#  '--',
#  'THE',
#  'BROKEN-HEARTED',
#  'IX.',
#  '--',
#  'THE',
#  'FORGIVER',
#  'OF',
#  'SINS',
#  'X.',
#  '--',
#  'THE',
#  'GIVER',
#  'OF',
#  'LIFE',
#  'XI.',
#  '--',
#  'THE',
#  'STILLER',
#  'OF',
#  'THE',
#  'STORM',
#  'Illustrations',
#  '``',
#  'NO',
#  ',',
#  'NO',
#  ',',
#  "''",
#  'SAID',
#  'THE',
#  'WOMAN',
#  ',',
#  '``',
#  'I',
#  'CA',
#  "N'T",
#  'GO',
#  'WITH',
#  'YOU',
#  'NOW',
#  "''",
#  '(',
#  'Frontispiece',
#  ')',
#  'AFTER',
#  'A',
#  'TIME',
#  'SHE',
#  'FELL',
#  'DOWN',
#  'ON',
#  'HER',
#  'KNEES',
#  '.',
#  'SHE',
#  'PRESSED',
#  'THEM',
#  'AGAINST',
#  'HER',
#  'FACE',
#  'SHE',
#  'LAID',
#  'HER',
#  'HAND',
#  'UPON',
#  'THE',
#  'KNOB',
#  'OF',
#  'THE',
#  'CHURCH',
#  'DOOR',
#  '``',
#  'IT',
#  'IS',
#  'HE',
#  ',',
#  "''",
#  'WHISPERED',
#  'THE',
#  'PRIEST',
#  ';',
#  '``',
#  'HIS',
#  'SORROW',
#  'WAS',
#  'GREATER',
#  'THAN',
#  'MINE',
#  "''",
#  'ABSOLVO',
#  'TE',
#  'THE',
#  'CRY',
#  'FOR',
#  'BREAD',
#  'I',
#  'The',
#  'Baby',
#  "''",
#  'A',
#  'LITTLE',
#  'CHILD',
#  'SHALL',
#  'LEAD',
#  'THEM',
#  "''",
#  'I',
#  'The',
#  'Baby',
#  'The',
#  'heavy',
#  'perfume',
#  'of',
#  'rare',
#  'blossoms',
#  ',',
#  'the',
#  'wild',
#  'strains',
#  'of',
#  'mad',
#  'music',
#  ',',
#  'the',
#  'patter',
#  'of',
#  'flying',
#  'feet',
#  ',',
#  'the',
#  'murmur',
#  'of',
#  'speech',
#  ',',
#  'the',
#  'ring',
#  'of',
#  'laughter',
#  ',',
#  'filled',
#  'the',
#  'great',
#  'hall',
#  '.',
#  'Now',
#  'and',
#  'again',
#  'a',
#  'pair',
#  'of',
#  'dancers',
#  ',',
#  'peculiarly',
#  'graceful',
#  'and',
#  'particularly',
#  'daring',
#  ',',
#  'held',
#  'the',
#  'center',
#  'of',
#  'the',
#  'floor',
#  'for',
#  'a',
#  'moment',
#  'while',
#  'the',
#  'room',
#  'rang',
#  'with',
#  'applause',
#  '.',
#  'Into',
#  'alcoves',
#  ',',
#  'screened',
#  'and',
#  'flower-decked',
#  ',',
#  'couples',
#  'wandered',
#  '.',
#  'In',
#  'the',
#  'dancing-space',
#  'hands',
#  'were',
#  'clasped',
#  ',',
#  'bosoms',
#  'rose',
#  'and',
#  'fell',
#  ',',
#  'hearts',
#  'throbbed',
#  ',',
#  'pulses',
#  'beat',
#  ',',
#  'and',
#  'moving',
#  'bodies',
#  'kept',
#  'time',
#  'to',
#  'rhythmic',
#  'sound',
#  '.',
#  'Suddenly',
#  'the',
#  'music',
#  'stopped',
#  ',',
#  'the',
#  'conversation',
#  'ceased',
#  ',',
#  'the',
#  'laughter',
#  'died',
#  'away',
#  '.',
#  'Almost',
#  ',',
#  'as',
#  'it',
#  'were',
#  ',',
#  'poised',
#  'in',
#  'the',
#  'air',
#  ',',
#  'the',
#  'dancers',
#  'stood',
#  'amazed',
#  '.',
#  'One',
#  'looked',
#  'to',
#  'another',
#  'in',
#  'surprise',
#  '.',
#  'Something',
#  'stole',
#  'throughout',
#  'the',
#  'room',
#  'which',
#  'was',
#  'neither',
#  'music',
#  ',',
#  'nor',
#  'lights',
#  ',',
#  'nor',
#  'fragrance',
#  ',',
#  'but',
#  'which',
#  'was',
#  'life',
#  '--',
#  'a',
#  'presence',
#  '!',
#  '``',
#  'Do',
#  'you',
#  'see',
#  'that',
#  'child',
#  '?',
#  "''",
#  'asked',
#  'the',
#  'wildest',
#  'of',
#  'the',
#  'dancers',
#  'of',
#  'her',
#  'escort',
#  '.',
#  '``',
#  'There',
#  ',',
#  "''",
#  'she',
#  'pointed',
#  '.',
#  '``',
#  'He',
#  'looks',
#  'like',
#  'a',
#  'very',
#  'little',
#  'boy',
#  '.',
#  "''",
#  '``',
#  'I',
#  'see',
#  'nothing',
#  ',',
#  "''",
#  'said',
#  'the',
#  'man',
#  ',',
#  'who',
#  'still',
#  'held',
#  'her',
#  'in',
#  'the',
#  'clasp',
#  'of',
#  'his',
#  'arm',
#  '.',
#  '``',
#  'He',
#  'is',
#  'strangely',
#  'dressed',
#  ',',
#  'although',
#  'I',
#  'see',
#  'him',
#  'indistinctly',
#  ',',
#  'vaguely',
#  ',',
#  "''",
#  'whispered',
#  'the',
#  'woman',
#  '.',
#  '``',
#  'He',
#  'wears',
#  'a',
#  'long',
#  'white',
#  'robe',
#  'and',
#  'there',
#  'is',
#  'a',
#  'kind',
#  'of',
#  'light',
#  'about',
#  'his',
#  'face',
#  '.',
#  'See',
#  ',',
#  'he',
#  'is',
#  'looking',
#  'at',
#  'us',
#  '.',
#  "''",
#  '``',
#  'I',
#  'see',
#  'nothing',
#  ',',
#  "''",
#  'repeated',
#  'the',
#  'man',
#  'in',
#  'low',
#  'tones',
#  '.',
#  '``',
#  'The',
#  'heat',
#  ',',
#  'the',
#  'light',
#  ',',
#  'the',
#  'music',
#  ',',
#  'have',
#  'disturbed',
#  'you',
#  ';',
#  'let',
#  'me',
#  'get',
#  'you',
#  '--',
#  "''",
#  "''",
#  'I',
#  'want',
#  'nothing',
#  ',',
#  "''",
#  'interposed',
#  'the',
#  'woman',
#  ',',
#  'waving',
#  'the',
#  'man',
#  'aside',
#  'and',
#  'drawing',
#  'away',
#  'from',
#  'his',
#  'arm',
#  '.',
#  '``',
#  'Do',
#  "n't",
#  'you',
#  'see',
#  'him',
#  ',',
#  'there',
#  '?',
#  "''",
#  'She',
#  'made',
#  'a',
#  'step',
#  'toward',
#  'the',
#  'center',
#  'of',
#  'the',
#  'room',
#  '.',
#  'She',
#  'stopped',
#  ',',
#  'put',
#  'her',
#  'hand',
#  'to',
#  'her',
#  'head',
#  '.',
#  '``',
#  'Why',
#  ',',
#  'he',
#  'is',
#  'gone',
#  ',',
#  "''",
#  'she',
#  'exclaimed',
#  '.',
#  '``',
#  'Good',
#  ',',
#  "''",
#  'said',
#  'the',
#  'man',
#  ',',
#  'while',
#  'at',
#  'that',
#  'instant',
#  'the',
#  'room',
#  'suddenly',
#  'rang',
#  'with',
#  'cries',
#  ':',
#  '``',
#  'Go',
#  'on',
#  'with',
#  'the',
#  'music',
#  ',',
#  'the',
#  'dance',
#  'is',
#  'not',
#  'half',
#  'over',
#  '.',
#  "''",
#  'He',
#  'extended',
#  'his',
#  'arm',
#  'to',
#  'the',
#  'woman',
#  'again',
#  '.',
#  '``',
#  'Our',
#  'dance',
#  'is',
#  'not',
#  'finished',
#  '.',
#  "''",
#  '``',
#  'Yes',
#  ',',
#  'it',
#  'is',
#  ',',
#  "''",
#  'she',
#  'said',
#  'as',
#  'the',
#  'flying',
#  'feet',
#  'once',
#  'more',
#  'twinkled',
#  'across',
#  'the',
#  'polished',
#  'floor',
#  ',',
#  'as',
#  'everybody',
#  'took',
#  'a',
#  'long',
#  'breath',
#  'and',
#  'a',
#  'new',
#  'start',
#  'apparently',
#  'unconscious',
#  'of',
#  'the',
#  'pause',
#  '.',
#  '``',
#  'It',
#  'is',
#  'over',
#  'for',
#  'me',
#  '.',
#  'What',
#  'I',
#  'saw',
#  '!',
#  "''",
#  '``',
#  'What',
#  'did',
#  'you',
#  'see',
#  '?',
#  "''",
#  '``',
#  'I',
#  'do',
#  "n't",
#  'know',
#  ',',
#  'but',
#  'I',
#  "'m",
#  'going',
#  'back',
#  'home',
#  'to',
#  'my',
#  'child',
#  '.',
#  'Good-night',
#  '.',
#  "''",
#  '*',
#  '*',
#  '*',
#  '*',
#  '*',
#  'Yes',
#  ',',
#  'the',
#  'music',
#  'had',
#  'stopped',
#  'suddenly',
#  '.',
#  'The',
#  'man',
#  'in',
#  'the',
#  'farthest',
#  'alcove',
#  'turned',
#  'to',
#  'his',
#  'companion',
#  '.',
#  'They',
#  'were',
#  'hidden',
#  'by',
#  'a',
#  'group',
#  'of',
#  'palms',
#  '.',
#  '``',
#  'I',
#  'wonder',
#  'why',
#  '?',
#  "''",
#  'queried',
#  'the',
#  'woman',
#  '.',
#  'She',
#  'was',
#  'deathly',
#  'pale',
#  '.',
#  'Her',
#  'eyes',
#  'were',
#  'dark',
#  'with',
#  'fear',
#  ',',
#  'yet',
#  'alight',
#  'with',
#  'passionate',
#  'determination',
#  '.',
#  '``',
#  'When',
#  'it',
#  'begins',
#  ',',
#  "''",
#  'said',
#  'the',
#  'man',
#  'tenderly',
#  ',',
#  '``',
#  'we',
#  'will',
#  'slip',
#  'away',
#  '.',
#  'My',
#  'car',
#  'is',
#  'outside',
#  '.',
#  'Everything',
#  'is',
#  'ready',
#  '.',
#  "''",
#  '``',
#  'That',
#  'is',
#  'my',
#  'husband',
#  'over',
#  'there',
#  ',',
#  "''",
#  'said',
#  'the',
#  'woman',
#  '.',
#  '``',
#  'Yes',
#  ',',
#  "''",
#  'said',
#  'the',
#  'man',
#  ',',
#  '``',
#  'he',
#  'wo',
#  "n't",
#  'trouble',
#  'you',
#  'any',
#  'more',
#  '.',
#  "''",
#  '``',
#  'That',
#  'woman',
#  'with',
#  'him',
#  'is',
#  'leaving',
#  'him',
#  ',',
#  "''",
#  'she',
#  'said',
#  '.',
#  '``',
#  'I',
#  'wonder',
#  'why',
#  '.',
#  "''",
#  'She',
#  'turned',
#  'suddenly',
#  'with',
#  'a',
#  ...]

# %%
words=[word for word in tokens if word.isalpha()]

# %%
words
# Out:
# ['ï',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'And',
#  'Thus',
#  'He',
#  'Came',
#  'by',
#  'Cyrus',
#  'Townsend',
#  'Brady',
#  'Illustrated',
#  'by',
#  'Walter',
#  'Everett',
#  'This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  'You',
#  'may',
#  'copy',
#  'it',
#  'give',
#  'it',
#  'away',
#  'or',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at',
#  'Title',
#  'And',
#  'Thus',
#  'He',
#  'Came',
#  'Author',
#  'Cyrus',
#  'Townsend',
#  'Brady',
#  'Release',
#  'Date',
#  'January',
#  'eBook',
#  'Language',
#  'English',
#  'Character',
#  'set',
#  'encoding',
#  'OF',
#  'THE',
#  'PROJECT',
#  'GUTENBERG',
#  'EBOOK',
#  'AND',
#  'THUS',
#  'HE',
#  'prepared',
#  'by',
#  'Robert',
#  'Cicconetti',
#  'Melissa',
#  'and',
#  'the',
#  'Project',
#  'Gutenberg',
#  'Online',
#  'Distributed',
#  'Proofreading',
#  'Team',
#  'http',
#  'Note',
#  'Project',
#  'Gutenberg',
#  'also',
#  'has',
#  'an',
#  'HTML',
#  'version',
#  'of',
#  'this',
#  'file',
#  'which',
#  'includes',
#  'the',
#  'original',
#  'illustrations',
#  'See',
#  'or',
#  'http',
#  'or',
#  'http',
#  'AND',
#  'THUS',
#  'HE',
#  'CAME',
#  'A',
#  'Christmas',
#  'Fantasy',
#  'by',
#  'CYRUS',
#  'TOWNSEND',
#  'BRADY',
#  'Pictures',
#  'by',
#  'Walter',
#  'Everett',
#  'Putnam',
#  'Sons',
#  'New',
#  'York',
#  'and',
#  'London',
#  'The',
#  'Knickerbocker',
#  'Press',
#  'Illustration',
#  'No',
#  'No',
#  'said',
#  'the',
#  'woman',
#  'I',
#  'ca',
#  'go',
#  'with',
#  'you',
#  'now',
#  'To',
#  'the',
#  'Beloved',
#  'Memory',
#  'of',
#  'Little',
#  'Betty',
#  'Contents',
#  'THE',
#  'BABY',
#  'THE',
#  'CHILD',
#  'THE',
#  'FRIEND',
#  'THE',
#  'WORKMAN',
#  'THE',
#  'COMFORTER',
#  'THE',
#  'BURDEN',
#  'BEARER',
#  'THE',
#  'THORN',
#  'CROWNED',
#  'THE',
#  'THE',
#  'FORGIVER',
#  'OF',
#  'SINS',
#  'THE',
#  'GIVER',
#  'OF',
#  'LIFE',
#  'THE',
#  'STILLER',
#  'OF',
#  'THE',
#  'STORM',
#  'Illustrations',
#  'NO',
#  'NO',
#  'SAID',
#  'THE',
#  'WOMAN',
#  'I',
#  'CA',
#  'GO',
#  'WITH',
#  'YOU',
#  'NOW',
#  'Frontispiece',
#  'AFTER',
#  'A',
#  'TIME',
#  'SHE',
#  'FELL',
#  'DOWN',
#  'ON',
#  'HER',
#  'KNEES',
#  'SHE',
#  'PRESSED',
#  'THEM',
#  'AGAINST',
#  'HER',
#  'FACE',
#  'SHE',
#  'LAID',
#  'HER',
#  'HAND',
#  'UPON',
#  'THE',
#  'KNOB',
#  'OF',
#  'THE',
#  'CHURCH',
#  'DOOR',
#  'IT',
#  'IS',
#  'HE',
#  'WHISPERED',
#  'THE',
#  'PRIEST',
#  'HIS',
#  'SORROW',
#  'WAS',
#  'GREATER',
#  'THAN',
#  'MINE',
#  'ABSOLVO',
#  'TE',
#  'THE',
#  'CRY',
#  'FOR',
#  'BREAD',
#  'I',
#  'The',
#  'Baby',
#  'A',
#  'LITTLE',
#  'CHILD',
#  'SHALL',
#  'LEAD',
#  'THEM',
#  'I',
#  'The',
#  'Baby',
#  'The',
#  'heavy',
#  'perfume',
#  'of',
#  'rare',
#  'blossoms',
#  'the',
#  'wild',
#  'strains',
#  'of',
#  'mad',
#  'music',
#  'the',
#  'patter',
#  'of',
#  'flying',
#  'feet',
#  'the',
#  'murmur',
#  'of',
#  'speech',
#  'the',
#  'ring',
#  'of',
#  'laughter',
#  'filled',
#  'the',
#  'great',
#  'hall',
#  'Now',
#  'and',
#  'again',
#  'a',
#  'pair',
#  'of',
#  'dancers',
#  'peculiarly',
#  'graceful',
#  'and',
#  'particularly',
#  'daring',
#  'held',
#  'the',
#  'center',
#  'of',
#  'the',
#  'floor',
#  'for',
#  'a',
#  'moment',
#  'while',
#  'the',
#  'room',
#  'rang',
#  'with',
#  'applause',
#  'Into',
#  'alcoves',
#  'screened',
#  'and',
#  'couples',
#  'wandered',
#  'In',
#  'the',
#  'hands',
#  'were',
#  'clasped',
#  'bosoms',
#  'rose',
#  'and',
#  'fell',
#  'hearts',
#  'throbbed',
#  'pulses',
#  'beat',
#  'and',
#  'moving',
#  'bodies',
#  'kept',
#  'time',
#  'to',
#  'rhythmic',
#  'sound',
#  'Suddenly',
#  'the',
#  'music',
#  'stopped',
#  'the',
#  'conversation',
#  'ceased',
#  'the',
#  'laughter',
#  'died',
#  'away',
#  'Almost',
#  'as',
#  'it',
#  'were',
#  'poised',
#  'in',
#  'the',
#  'air',
#  'the',
#  'dancers',
#  'stood',
#  'amazed',
#  'One',
#  'looked',
#  'to',
#  'another',
#  'in',
#  'surprise',
#  'Something',
#  'stole',
#  'throughout',
#  'the',
#  'room',
#  'which',
#  'was',
#  'neither',
#  'music',
#  'nor',
#  'lights',
#  'nor',
#  'fragrance',
#  'but',
#  'which',
#  'was',
#  'life',
#  'a',
#  'presence',
#  'Do',
#  'you',
#  'see',
#  'that',
#  'child',
#  'asked',
#  'the',
#  'wildest',
#  'of',
#  'the',
#  'dancers',
#  'of',
#  'her',
#  'escort',
#  'There',
#  'she',
#  'pointed',
#  'He',
#  'looks',
#  'like',
#  'a',
#  'very',
#  'little',
#  'boy',
#  'I',
#  'see',
#  'nothing',
#  'said',
#  'the',
#  'man',
#  'who',
#  'still',
#  'held',
#  'her',
#  'in',
#  'the',
#  'clasp',
#  'of',
#  'his',
#  'arm',
#  'He',
#  'is',
#  'strangely',
#  'dressed',
#  'although',
#  'I',
#  'see',
#  'him',
#  'indistinctly',
#  'vaguely',
#  'whispered',
#  'the',
#  'woman',
#  'He',
#  'wears',
#  'a',
#  'long',
#  'white',
#  'robe',
#  'and',
#  'there',
#  'is',
#  'a',
#  'kind',
#  'of',
#  'light',
#  'about',
#  'his',
#  'face',
#  'See',
#  'he',
#  'is',
#  'looking',
#  'at',
#  'us',
#  'I',
#  'see',
#  'nothing',
#  'repeated',
#  'the',
#  'man',
#  'in',
#  'low',
#  'tones',
#  'The',
#  'heat',
#  'the',
#  'light',
#  'the',
#  'music',
#  'have',
#  'disturbed',
#  'you',
#  'let',
#  'me',
#  'get',
#  'you',
#  'I',
#  'want',
#  'nothing',
#  'interposed',
#  'the',
#  'woman',
#  'waving',
#  'the',
#  'man',
#  'aside',
#  'and',
#  'drawing',
#  'away',
#  'from',
#  'his',
#  'arm',
#  'Do',
#  'you',
#  'see',
#  'him',
#  'there',
#  'She',
#  'made',
#  'a',
#  'step',
#  'toward',
#  'the',
#  'center',
#  'of',
#  'the',
#  'room',
#  'She',
#  'stopped',
#  'put',
#  'her',
#  'hand',
#  'to',
#  'her',
#  'head',
#  'Why',
#  'he',
#  'is',
#  'gone',
#  'she',
#  'exclaimed',
#  'Good',
#  'said',
#  'the',
#  'man',
#  'while',
#  'at',
#  'that',
#  'instant',
#  'the',
#  'room',
#  'suddenly',
#  'rang',
#  'with',
#  'cries',
#  'Go',
#  'on',
#  'with',
#  'the',
#  'music',
#  'the',
#  'dance',
#  'is',
#  'not',
#  'half',
#  'over',
#  'He',
#  'extended',
#  'his',
#  'arm',
#  'to',
#  'the',
#  'woman',
#  'again',
#  'Our',
#  'dance',
#  'is',
#  'not',
#  'finished',
#  'Yes',
#  'it',
#  'is',
#  'she',
#  'said',
#  'as',
#  'the',
#  'flying',
#  'feet',
#  'once',
#  'more',
#  'twinkled',
#  'across',
#  'the',
#  'polished',
#  'floor',
#  'as',
#  'everybody',
#  'took',
#  'a',
#  'long',
#  'breath',
#  'and',
#  'a',
#  'new',
#  'start',
#  'apparently',
#  'unconscious',
#  'of',
#  'the',
#  'pause',
#  'It',
#  'is',
#  'over',
#  'for',
#  'me',
#  'What',
#  'I',
#  'saw',
#  'What',
#  'did',
#  'you',
#  'see',
#  'I',
#  'do',
#  'know',
#  'but',
#  'I',
#  'going',
#  'back',
#  'home',
#  'to',
#  'my',
#  'child',
#  'Yes',
#  'the',
#  'music',
#  'had',
#  'stopped',
#  'suddenly',
#  'The',
#  'man',
#  'in',
#  'the',
#  'farthest',
#  'alcove',
#  'turned',
#  'to',
#  'his',
#  'companion',
#  'They',
#  'were',
#  'hidden',
#  'by',
#  'a',
#  'group',
#  'of',
#  'palms',
#  'I',
#  'wonder',
#  'why',
#  'queried',
#  'the',
#  'woman',
#  'She',
#  'was',
#  'deathly',
#  'pale',
#  'Her',
#  'eyes',
#  'were',
#  'dark',
#  'with',
#  'fear',
#  'yet',
#  'alight',
#  'with',
#  'passionate',
#  'determination',
#  'When',
#  'it',
#  'begins',
#  'said',
#  'the',
#  'man',
#  'tenderly',
#  'we',
#  'will',
#  'slip',
#  'away',
#  'My',
#  'car',
#  'is',
#  'outside',
#  'Everything',
#  'is',
#  'ready',
#  'That',
#  'is',
#  'my',
#  'husband',
#  'over',
#  'there',
#  'said',
#  'the',
#  'woman',
#  'Yes',
#  'said',
#  'the',
#  'man',
#  'he',
#  'wo',
#  'trouble',
#  'you',
#  'any',
#  'more',
#  'That',
#  'woman',
#  'with',
#  'him',
#  'is',
#  'leaving',
#  'him',
#  'she',
#  'said',
#  'I',
#  'wonder',
#  'why',
#  'She',
#  'turned',
#  'suddenly',
#  'with',
#  'a',
#  'great',
#  'start',
#  'There',
#  'is',
#  'somebody',
#  'here',
#  'she',
#  'whispered',
#  'staring',
#  'into',
#  'the',
#  'back',
#  'of',
#  'the',
#  'alcove',
#  'Nonsense',
#  'said',
#  'the',
#  'man',
#  'throwing',
#  'a',
#  'glance',
#  'around',
#  'the',
#  'recess',
#  'nobody',
#  'here',
#  'but',
#  'you',
#  'and',
#  'I',
#  'We',
#  'are',
#  'alone',
#  'together',
#  'as',
#  'we',
#  'shall',
#  'be',
#  'hereafter',
#  'when',
#  'we',
#  'have',
#  'taken',
#  'the',
#  'step',
#  'But',
#  'that',
#  'child',
#  'whispered',
#  'the',
#  'woman',
#  'with',
#  'his',
#  'strange',
#  'vesture',
#  'and',
#  'his',
#  'wonderful',
#  'face',
#  'His',
#  'eyes',
#  'look',
#  'at',
#  'me',
#  'so',
#  'There',
#  'is',
#  'no',
#  'child',
#  'there',
#  'my',
#  'dear',
#  'urged',
#  'the',
#  'man',
#  'you',
#  'are',
#  'overwrought',
#  'excited',
#  'nervous',
#  'The',
#  'music',
#  'starts',
#  'Let',
#  'us',
#  'go',
#  'He',
#  'stretched',
#  'out',
#  'his',
#  'hand',
#  'to',
#  'the',
#  'woman',
#  'but',
#  'as',
#  'he',
#  'came',
#  'nearer',
#  'she',
#  'shrank',
#  'back',
#  'with',
#  'her',
#  'own',
#  'hand',
#  'on',
#  'her',
#  'heart',
#  'Oh',
#  'she',
#  'said',
#  'faintly',
#  'he',
#  'gone',
#  'Of',
#  'course',
#  'he',
#  'gone',
#  'he',
#  'answered',
#  'soothingly',
#  'Now',
#  'is',
#  'our',
#  'time',
#  'to',
#  'get',
#  'away',
#  'Let',
#  'me',
#  'No',
#  'no',
#  'said',
#  'the',
#  'woman',
#  'I',
#  'ca',
#  'go',
#  'with',
#  'you',
#  'now',
#  'It',
#  'would',
#  'be',
#  'right',
#  'But',
#  'you',
#  'knew',
#  'that',
#  'before',
#  'pleaded',
#  'the',
#  'man',
#  'Besides',
#  'Yes',
#  'but',
#  'I',
#  'ca',
#  'do',
#  'it',
#  'He',
#  'was',
#  'there',
#  'His',
#  'eyes',
#  'spoke',
#  'I',
#  'do',
#  'touch',
#  'me',
#  'she',
#  'said',
#  'I',
#  'going',
#  'back',
#  'to',
#  'my',
#  'husband',
#  'Do',
#  'follow',
#  'II',
#  'The',
#  'Child',
#  'SUFFER',
#  'THE',
#  'LITTLE',
#  'CHILDREN',
#  'TO',
#  'COME',
#  'UNTO',
#  'ME',
#  'II',
#  'The',
#  'Child',
#  'The',
#  'employees',
#  'had',
#  'all',
#  'gone',
#  'home',
#  'carrying',
#  'with',
#  'them',
#  'Christmas',
#  'checks',
#  'and',
#  'hearty',
#  'greetings',
#  'from',
#  'the',
#  'great',
#  'man',
#  'whose',
#  'beck',
#  'and',
#  'nod',
#  'they',
#  'followed',
#  'He',
#  'sat',
#  'in',
#  'his',
#  'private',
#  'office',
#  'absolutely',
#  'alone',
#  'He',
#  'had',
#  'some',
#  'serious',
#  'matters',
#  'to',
#  'consider',
#  'and',
#  'did',
#  'not',
#  'want',
#  'any',
#  'interruptions',
#  'His',
#  'for',
#  'the',
#  'year',
#  'had',
#  'been',
#  'made',
#  'up',
#  'according',
#  'to',
#  'the',
#  'custom',
#  'of',
#  'the',
#  'firm',
#  'before',
#  'Christmas',
#  'instead',
#  'of',
#  'on',
#  'New',
#  'Year',
#  'Day',
#  'He',
#  'examined',
#  'it',
#  'again',
#  'It',
#  'showed',
#  'tremendous',
#  'profit',
#  'The',
#  'mills',
#  ...]

# %%
from nltk.corpus import stopwords

# %%
stop_words=stopwords.words('english')

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
words=[w for w in words if not w in stop_words]

# %%
words
# Out:
# ['ï',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'And',
#  'Thus',
#  'He',
#  'Came',
#  'Cyrus',
#  'Townsend',
#  'Brady',
#  'Illustrated',
#  'Walter',
#  'Everett',
#  'This',
#  'eBook',
#  'use',
#  'anyone',
#  'anywhere',
#  'cost',
#  'almost',
#  'restrictions',
#  'whatsoever',
#  'You',
#  'may',
#  'copy',
#  'give',
#  'away',
#  'terms',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'eBook',
#  'online',
#  'Title',
#  'And',
#  'Thus',
#  'He',
#  'Came',
#  'Author',
#  'Cyrus',
#  'Townsend',
#  'Brady',
#  'Release',
#  'Date',
#  'January',
#  'eBook',
#  'Language',
#  'English',
#  'Character',
#  'set',
#  'encoding',
#  'OF',
#  'THE',
#  'PROJECT',
#  'GUTENBERG',
#  'EBOOK',
#  'AND',
#  'THUS',
#  'HE',
#  'prepared',
#  'Robert',
#  'Cicconetti',
#  'Melissa',
#  'Project',
#  'Gutenberg',
#  'Online',
#  'Distributed',
#  'Proofreading',
#  'Team',
#  'http',
#  'Note',
#  'Project',
#  'Gutenberg',
#  'also',
#  'HTML',
#  'version',
#  'file',
#  'includes',
#  'original',
#  'illustrations',
#  'See',
#  'http',
#  'http',
#  'AND',
#  'THUS',
#  'HE',
#  'CAME',
#  'A',
#  'Christmas',
#  'Fantasy',
#  'CYRUS',
#  'TOWNSEND',
#  'BRADY',
#  'Pictures',
#  'Walter',
#  'Everett',
#  'Putnam',
#  'Sons',
#  'New',
#  'York',
#  'London',
#  'The',
#  'Knickerbocker',
#  'Press',
#  'Illustration',
#  'No',
#  'No',
#  'said',
#  'woman',
#  'I',
#  'ca',
#  'go',
#  'To',
#  'Beloved',
#  'Memory',
#  'Little',
#  'Betty',
#  'Contents',
#  'THE',
#  'BABY',
#  'THE',
#  'CHILD',
#  'THE',
#  'FRIEND',
#  'THE',
#  'WORKMAN',
#  'THE',
#  'COMFORTER',
#  'THE',
#  'BURDEN',
#  'BEARER',
#  'THE',
#  'THORN',
#  'CROWNED',
#  'THE',
#  'THE',
#  'FORGIVER',
#  'OF',
#  'SINS',
#  'THE',
#  'GIVER',
#  'OF',
#  'LIFE',
#  'THE',
#  'STILLER',
#  'OF',
#  'THE',
#  'STORM',
#  'Illustrations',
#  'NO',
#  'NO',
#  'SAID',
#  'THE',
#  'WOMAN',
#  'I',
#  'CA',
#  'GO',
#  'WITH',
#  'YOU',
#  'NOW',
#  'Frontispiece',
#  'AFTER',
#  'A',
#  'TIME',
#  'SHE',
#  'FELL',
#  'DOWN',
#  'ON',
#  'HER',
#  'KNEES',
#  'SHE',
#  'PRESSED',
#  'THEM',
#  'AGAINST',
#  'HER',
#  'FACE',
#  'SHE',
#  'LAID',
#  'HER',
#  'HAND',
#  'UPON',
#  'THE',
#  'KNOB',
#  'OF',
#  'THE',
#  'CHURCH',
#  'DOOR',
#  'IT',
#  'IS',
#  'HE',
#  'WHISPERED',
#  'THE',
#  'PRIEST',
#  'HIS',
#  'SORROW',
#  'WAS',
#  'GREATER',
#  'THAN',
#  'MINE',
#  'ABSOLVO',
#  'TE',
#  'THE',
#  'CRY',
#  'FOR',
#  'BREAD',
#  'I',
#  'The',
#  'Baby',
#  'A',
#  'LITTLE',
#  'CHILD',
#  'SHALL',
#  'LEAD',
#  'THEM',
#  'I',
#  'The',
#  'Baby',
#  'The',
#  'heavy',
#  'perfume',
#  'rare',
#  'blossoms',
#  'wild',
#  'strains',
#  'mad',
#  'music',
#  'patter',
#  'flying',
#  'feet',
#  'murmur',
#  'speech',
#  'ring',
#  'laughter',
#  'filled',
#  'great',
#  'hall',
#  'Now',
#  'pair',
#  'dancers',
#  'peculiarly',
#  'graceful',
#  'particularly',
#  'daring',
#  'held',
#  'center',
#  'floor',
#  'moment',
#  'room',
#  'rang',
#  'applause',
#  'Into',
#  'alcoves',
#  'screened',
#  'couples',
#  'wandered',
#  'In',
#  'hands',
#  'clasped',
#  'bosoms',
#  'rose',
#  'fell',
#  'hearts',
#  'throbbed',
#  'pulses',
#  'beat',
#  'moving',
#  'bodies',
#  'kept',
#  'time',
#  'rhythmic',
#  'sound',
#  'Suddenly',
#  'music',
#  'stopped',
#  'conversation',
#  'ceased',
#  'laughter',
#  'died',
#  'away',
#  'Almost',
#  'poised',
#  'air',
#  'dancers',
#  'stood',
#  'amazed',
#  'One',
#  'looked',
#  'another',
#  'surprise',
#  'Something',
#  'stole',
#  'throughout',
#  'room',
#  'neither',
#  'music',
#  'lights',
#  'fragrance',
#  'life',
#  'presence',
#  'Do',
#  'see',
#  'child',
#  'asked',
#  'wildest',
#  'dancers',
#  'escort',
#  'There',
#  'pointed',
#  'He',
#  'looks',
#  'like',
#  'little',
#  'boy',
#  'I',
#  'see',
#  'nothing',
#  'said',
#  'man',
#  'still',
#  'held',
#  'clasp',
#  'arm',
#  'He',
#  'strangely',
#  'dressed',
#  'although',
#  'I',
#  'see',
#  'indistinctly',
#  'vaguely',
#  'whispered',
#  'woman',
#  'He',
#  'wears',
#  'long',
#  'white',
#  'robe',
#  'kind',
#  'light',
#  'face',
#  'See',
#  'looking',
#  'us',
#  'I',
#  'see',
#  'nothing',
#  'repeated',
#  'man',
#  'low',
#  'tones',
#  'The',
#  'heat',
#  'light',
#  'music',
#  'disturbed',
#  'let',
#  'get',
#  'I',
#  'want',
#  'nothing',
#  'interposed',
#  'woman',
#  'waving',
#  'man',
#  'aside',
#  'drawing',
#  'away',
#  'arm',
#  'Do',
#  'see',
#  'She',
#  'made',
#  'step',
#  'toward',
#  'center',
#  'room',
#  'She',
#  'stopped',
#  'put',
#  'hand',
#  'head',
#  'Why',
#  'gone',
#  'exclaimed',
#  'Good',
#  'said',
#  'man',
#  'instant',
#  'room',
#  'suddenly',
#  'rang',
#  'cries',
#  'Go',
#  'music',
#  'dance',
#  'half',
#  'He',
#  'extended',
#  'arm',
#  'woman',
#  'Our',
#  'dance',
#  'finished',
#  'Yes',
#  'said',
#  'flying',
#  'feet',
#  'twinkled',
#  'across',
#  'polished',
#  'floor',
#  'everybody',
#  'took',
#  'long',
#  'breath',
#  'new',
#  'start',
#  'apparently',
#  'unconscious',
#  'pause',
#  'It',
#  'What',
#  'I',
#  'saw',
#  'What',
#  'see',
#  'I',
#  'know',
#  'I',
#  'going',
#  'back',
#  'home',
#  'child',
#  'Yes',
#  'music',
#  'stopped',
#  'suddenly',
#  'The',
#  'man',
#  'farthest',
#  'alcove',
#  'turned',
#  'companion',
#  'They',
#  'hidden',
#  'group',
#  'palms',
#  'I',
#  'wonder',
#  'queried',
#  'woman',
#  'She',
#  'deathly',
#  'pale',
#  'Her',
#  'eyes',
#  'dark',
#  'fear',
#  'yet',
#  'alight',
#  'passionate',
#  'determination',
#  'When',
#  'begins',
#  'said',
#  'man',
#  'tenderly',
#  'slip',
#  'away',
#  'My',
#  'car',
#  'outside',
#  'Everything',
#  'ready',
#  'That',
#  'husband',
#  'said',
#  'woman',
#  'Yes',
#  'said',
#  'man',
#  'wo',
#  'trouble',
#  'That',
#  'woman',
#  'leaving',
#  'said',
#  'I',
#  'wonder',
#  'She',
#  'turned',
#  'suddenly',
#  'great',
#  'start',
#  'There',
#  'somebody',
#  'whispered',
#  'staring',
#  'back',
#  'alcove',
#  'Nonsense',
#  'said',
#  'man',
#  'throwing',
#  'glance',
#  'around',
#  'recess',
#  'nobody',
#  'I',
#  'We',
#  'alone',
#  'together',
#  'shall',
#  'hereafter',
#  'taken',
#  'step',
#  'But',
#  'child',
#  'whispered',
#  'woman',
#  'strange',
#  'vesture',
#  'wonderful',
#  'face',
#  'His',
#  'eyes',
#  'look',
#  'There',
#  'child',
#  'dear',
#  'urged',
#  'man',
#  'overwrought',
#  'excited',
#  'nervous',
#  'The',
#  'music',
#  'starts',
#  'Let',
#  'us',
#  'go',
#  'He',
#  'stretched',
#  'hand',
#  'woman',
#  'came',
#  'nearer',
#  'shrank',
#  'back',
#  'hand',
#  'heart',
#  'Oh',
#  'said',
#  'faintly',
#  'gone',
#  'Of',
#  'course',
#  'gone',
#  'answered',
#  'soothingly',
#  'Now',
#  'time',
#  'get',
#  'away',
#  'Let',
#  'No',
#  'said',
#  'woman',
#  'I',
#  'ca',
#  'go',
#  'It',
#  'would',
#  'right',
#  'But',
#  'knew',
#  'pleaded',
#  'man',
#  'Besides',
#  'Yes',
#  'I',
#  'ca',
#  'He',
#  'His',
#  'eyes',
#  'spoke',
#  'I',
#  'touch',
#  'said',
#  'I',
#  'going',
#  'back',
#  'husband',
#  'Do',
#  'follow',
#  'II',
#  'The',
#  'Child',
#  'SUFFER',
#  'THE',
#  'LITTLE',
#  'CHILDREN',
#  'TO',
#  'COME',
#  'UNTO',
#  'ME',
#  'II',
#  'The',
#  'Child',
#  'The',
#  'employees',
#  'gone',
#  'home',
#  'carrying',
#  'Christmas',
#  'checks',
#  'hearty',
#  'greetings',
#  'great',
#  'man',
#  'whose',
#  'beck',
#  'nod',
#  'followed',
#  'He',
#  'sat',
#  'private',
#  'office',
#  'absolutely',
#  'alone',
#  'He',
#  'serious',
#  'matters',
#  'consider',
#  'want',
#  'interruptions',
#  'His',
#  'year',
#  'made',
#  'according',
#  'custom',
#  'firm',
#  'Christmas',
#  'instead',
#  'New',
#  'Year',
#  'Day',
#  'He',
#  'examined',
#  'It',
#  'showed',
#  'tremendous',
#  'profit',
#  'The',
#  'mills',
#  'turning',
#  'quantities',
#  'material',
#  'demand',
#  'greater',
#  'cost',
#  'production',
#  'less',
#  'ever',
#  'I',
#  'tell',
#  'said',
#  'man',
#  'displace',
#  'men',
#  'children',
#  'mills',
#  'They',
#  'reduced',
#  'cost',
#  'four',
#  'fifths',
#  'War',
#  'made',
#  'prices',
#  'go',
#  'This',
#  'wealth',
#  'riches',
#  'beyond',
#  'calculation',
#  'He',
#  'picked',
#  'letter',
#  'read',
#  'It',
#  'proposal',
#  'superintendent',
#  'clear',
#  'land',
#  'build',
#  'buildings',
#  'install',
#  'machines',
#  'employ',
#  'children',
#  'increase',
#  'profits',
#  'greatly',
#  'I',
#  'said',
#  'man',
#  'We',
#  'crush',
#  'opposition',
#  'absolutely',
#  'control',
#  'markets',
#  'world',
#  'I',
#  'build',
#  'fortune',
#  'upon',
#  'foundation',
#  'great',
#  'one',
#  'comprehend',
#  'He',
#  'stopped',
#  'leaned',
#  'back',
#  'chair',
#  'lifted',
#  'eyes',
#  'toward',
#  'ceiling',
#  'room',
#  'saw',
#  'beyond',
#  'kingdoms',
#  'world',
#  'means',
#  'unlimited',
#  'make',
#  'lord',
#  'master',
#  'He',
#  'gave',
#  'thought',
#  'foundations',
#  'structure',
#  'erected',
#  'fancy',
#  'How',
#  'long',
#  'indulged',
#  'dreams',
#  'scarcely',
#  'realized',
#  'presently',
#  'put',
#  'hands',
#  'arms',
#  'chair',
#  'started',
#  'rise',
#  'saying',
#  'I',
#  'telegraph',
#  'superintendent',
#  'go',
#  'ahead',
#  'He',
#  'scarcely',
#  'formulated',
#  'words',
#  'right',
#  'front',
#  'seated',
#  'desk',
#  'saw',
#  'young',
#  'lad',
#  'regarding',
#  'intently',
#  'He',
#  'stopped',
#  'petrified',
#  'position',
#  'assumed',
#  'How',
#  'get',
#  'What',
#  'asked',
#  'There',
#  'answer',
#  'Come',
#  'said',
#  'man',
#  'shrinking',
#  'back',
#  'I',
#  'ca',
#  'imagine',
#  'got',
#  'If',
#  'people',
#  'gone',
#  'I',
#  'hold',
#  'strict',
#  'account',
#  'As',
#  'The',
#  'room',
#  'suddenly',
#  'filled',
#  'people',
#  'They',
#  'came',
#  'crowding',
#  'walls',
#  'every',
#  'side',
#  'pressed',
#  'close',
#  'Such',
#  'people',
#  'never',
#  'seen',
#  'wan',
#  'worn',
#  'stunted',
#  'pinched',
#  'starved',
#  'joyless',
#  'They',
#  'children',
#  'meagerly',
#  'clothed',
#  'badly',
#  'nourished',
#  'ill',
#  'developed',
#  'They',
#  'quite',
#  'silent',
#  'They',
#  'cry',
#  'They',
#  'protest',
#  'They',
#  'argue',
#  'They',
#  'plead',
#  'They',
#  'laugh',
#  'They',
#  'looked',
#  'They',
#  'made',
#  'sound',
#  'sort',
#  'He',
#  'children',
#  'known',
#  'many',
#  'children',
#  'He',
#  'never',
#  'known',
#  'many',
#  'gathered',
#  'together',
#  'without',
#  'smile',
#  'laugh',
#  'His',
#  'eye',
#  'wandered',
#  'around',
#  'room',
#  'They',
#  'close',
#  'yet',
#  'touch',
#  'He',
#  'turned',
#  'desk',
#  'lad',
#  'sat',
#  'longer',
#  'yet',
#  'well',
#  'remembered',
#  'face',
#  'He',
#  'knew',
#  'exactly',
#  'looked',
#  'He',
#  'turned',
#  'nearest',
#  'child',
#  'strange',
#  'way',
#  'although',
#  'poor',
#  'wretched',
#  'face',
#  'changed',
#  'look',
#  'suggested',
#  'lad',
#  'first',
#  'visitor',
#  'He',
#  'turned',
#  'another',
#  'another',
#  'They',
#  'looked',
#  'back',
#  'way',
#  'eyes',
#  'He',
#  'threw',
#  'head',
#  'saw',
#  'castle',
#  'success',
#  'dreamed',
#  'He',
#  'looked',
#  'This',
#  'foundation',
#  'Slowly',
#  'hand',
#  'went',
#  'desk',
#  'The',
#  'little',
#  'crowding',
#  'figures',
#  'drew',
#  'back',
#  'give',
#  'freedom',
#  'movement',
#  'stretched',
#  'hand',
#  'He',
#  'drew',
#  'He',
#  'seized',
#  'pen',
#  'wrote',
#  'rapidly',
#  'Build',
#  'mills',
#  'take',
#  'children',
#  'already',
#  'operation',
#  'put',
#  'men',
#  'places',
#  'We',
#  'content',
#  'less',
#  'profit',
#  'future',
#  'He',
#  'read',
#  'telegram',
#  'The',
#  'telephone',
#  'close',
#  'hand',
#  'He',
#  'called',
#  'dictated',
#  'directed',
#  'sent',
#  'immediately',
#  'He',
#  'engrossed',
#  'task',
#  'noticed',
#  'nothing',
#  'else',
#  'Now',
#  'looked',
#  'The',
#  'room',
#  'still',
#  'filled',
#  'children',
#  'laughing',
#  'It',
#  'soundless',
#  'laugh',
#  'yet',
#  ...]

# %%
from nltk.stem.porter import PorterStemmer

# %%
porter = PorterStemmer()

# %%
stemmed=[porter.stem(word) for word in words]

# %%
stemmed
# Out:
# ['ï',
#  'project',
#  'gutenberg',
#  'ebook',
#  'and',
#  'thu',
#  'He',
#  'came',
#  'cyru',
#  'townsend',
#  'bradi',
#  'illustr',
#  'walter',
#  'everett',
#  'thi',
#  'ebook',
#  'use',
#  'anyon',
#  'anywher',
#  'cost',
#  'almost',
#  'restrict',
#  'whatsoev',
#  'you',
#  'may',
#  'copi',
#  'give',
#  'away',
#  'term',
#  'project',
#  'gutenberg',
#  'licens',
#  'includ',
#  'ebook',
#  'onlin',
#  'titl',
#  'and',
#  'thu',
#  'He',
#  'came',
#  'author',
#  'cyru',
#  'townsend',
#  'bradi',
#  'releas',
#  'date',
#  'januari',
#  'ebook',
#  'languag',
#  'english',
#  'charact',
#  'set',
#  'encod',
#  'OF',
#  'the',
#  'project',
#  'gutenberg',
#  'ebook',
#  'and',
#  'thu',
#  'HE',
#  'prepar',
#  'robert',
#  'cicconetti',
#  'melissa',
#  'project',
#  'gutenberg',
#  'onlin',
#  'distribut',
#  'proofread',
#  'team',
#  'http',
#  'note',
#  'project',
#  'gutenberg',
#  'also',
#  'html',
#  'version',
#  'file',
#  'includ',
#  'origin',
#  'illustr',
#  'see',
#  'http',
#  'http',
#  'and',
#  'thu',
#  'HE',
#  'came',
#  'A',
#  'christma',
#  'fantasi',
#  'cyru',
#  'townsend',
#  'bradi',
#  'pictur',
#  'walter',
#  'everett',
#  'putnam',
#  'son',
#  'new',
#  'york',
#  'london',
#  'the',
#  'knickerbock',
#  'press',
#  'illustr',
#  'No',
#  'No',
#  'said',
#  'woman',
#  'I',
#  'ca',
#  'go',
#  'To',
#  'belov',
#  'memori',
#  'littl',
#  'betti',
#  'content',
#  'the',
#  'babi',
#  'the',
#  'child',
#  'the',
#  'friend',
#  'the',
#  'workman',
#  'the',
#  'comfort',
#  'the',
#  'burden',
#  'bearer',
#  'the',
#  'thorn',
#  'crown',
#  'the',
#  'the',
#  'forgiv',
#  'OF',
#  'sin',
#  'the',
#  'giver',
#  'OF',
#  'life',
#  'the',
#  'stiller',
#  'OF',
#  'the',
#  'storm',
#  'illustr',
#  'NO',
#  'NO',
#  'said',
#  'the',
#  'woman',
#  'I',
#  'CA',
#  'GO',
#  'with',
#  'you',
#  'now',
#  'frontispiec',
#  'after',
#  'A',
#  'time',
#  'she',
#  'fell',
#  'down',
#  'ON',
#  'her',
#  'knee',
#  'she',
#  'press',
#  'them',
#  'against',
#  'her',
#  'face',
#  'she',
#  'laid',
#  'her',
#  'hand',
#  'upon',
#  'the',
#  'knob',
#  'OF',
#  'the',
#  'church',
#  'door',
#  'IT',
#  'IS',
#  'HE',
#  'whisper',
#  'the',
#  'priest',
#  'hi',
#  'sorrow',
#  'wa',
#  'greater',
#  'than',
#  'mine',
#  'absolvo',
#  'TE',
#  'the',
#  'cri',
#  'for',
#  'bread',
#  'I',
#  'the',
#  'babi',
#  'A',
#  'littl',
#  'child',
#  'shall',
#  'lead',
#  'them',
#  'I',
#  'the',
#  'babi',
#  'the',
#  'heavi',
#  'perfum',
#  'rare',
#  'blossom',
#  'wild',
#  'strain',
#  'mad',
#  'music',
#  'patter',
#  'fli',
#  'feet',
#  'murmur',
#  'speech',
#  'ring',
#  'laughter',
#  'fill',
#  'great',
#  'hall',
#  'now',
#  'pair',
#  'dancer',
#  'peculiarli',
#  'grace',
#  'particularli',
#  'dare',
#  'held',
#  'center',
#  'floor',
#  'moment',
#  'room',
#  'rang',
#  'applaus',
#  'into',
#  'alcov',
#  'screen',
#  'coupl',
#  'wander',
#  'In',
#  'hand',
#  'clasp',
#  'bosom',
#  'rose',
#  'fell',
#  'heart',
#  'throb',
#  'puls',
#  'beat',
#  'move',
#  'bodi',
#  'kept',
#  'time',
#  'rhythmic',
#  'sound',
#  'suddenli',
#  'music',
#  'stop',
#  'convers',
#  'ceas',
#  'laughter',
#  'die',
#  'away',
#  'almost',
#  'pois',
#  'air',
#  'dancer',
#  'stood',
#  'amaz',
#  'one',
#  'look',
#  'anoth',
#  'surpris',
#  'someth',
#  'stole',
#  'throughout',
#  'room',
#  'neither',
#  'music',
#  'light',
#  'fragranc',
#  'life',
#  'presenc',
#  'Do',
#  'see',
#  'child',
#  'ask',
#  'wildest',
#  'dancer',
#  'escort',
#  'there',
#  'point',
#  'He',
#  'look',
#  'like',
#  'littl',
#  'boy',
#  'I',
#  'see',
#  'noth',
#  'said',
#  'man',
#  'still',
#  'held',
#  'clasp',
#  'arm',
#  'He',
#  'strang',
#  'dress',
#  'although',
#  'I',
#  'see',
#  'indistinctli',
#  'vagu',
#  'whisper',
#  'woman',
#  'He',
#  'wear',
#  'long',
#  'white',
#  'robe',
#  'kind',
#  'light',
#  'face',
#  'see',
#  'look',
#  'us',
#  'I',
#  'see',
#  'noth',
#  'repeat',
#  'man',
#  'low',
#  'tone',
#  'the',
#  'heat',
#  'light',
#  'music',
#  'disturb',
#  'let',
#  'get',
#  'I',
#  'want',
#  'noth',
#  'interpos',
#  'woman',
#  'wave',
#  'man',
#  'asid',
#  'draw',
#  'away',
#  'arm',
#  'Do',
#  'see',
#  'she',
#  'made',
#  'step',
#  'toward',
#  'center',
#  'room',
#  'she',
#  'stop',
#  'put',
#  'hand',
#  'head',
#  'whi',
#  'gone',
#  'exclaim',
#  'good',
#  'said',
#  'man',
#  'instant',
#  'room',
#  'suddenli',
#  'rang',
#  'cri',
#  'Go',
#  'music',
#  'danc',
#  'half',
#  'He',
#  'extend',
#  'arm',
#  'woman',
#  'our',
#  'danc',
#  'finish',
#  'ye',
#  'said',
#  'fli',
#  'feet',
#  'twinkl',
#  'across',
#  'polish',
#  'floor',
#  'everybodi',
#  'took',
#  'long',
#  'breath',
#  'new',
#  'start',
#  'appar',
#  'unconsci',
#  'paus',
#  'It',
#  'what',
#  'I',
#  'saw',
#  'what',
#  'see',
#  'I',
#  'know',
#  'I',
#  'go',
#  'back',
#  'home',
#  'child',
#  'ye',
#  'music',
#  'stop',
#  'suddenli',
#  'the',
#  'man',
#  'farthest',
#  'alcov',
#  'turn',
#  'companion',
#  'they',
#  'hidden',
#  'group',
#  'palm',
#  'I',
#  'wonder',
#  'queri',
#  'woman',
#  'she',
#  'deathli',
#  'pale',
#  'her',
#  'eye',
#  'dark',
#  'fear',
#  'yet',
#  'alight',
#  'passion',
#  'determin',
#  'when',
#  'begin',
#  'said',
#  'man',
#  'tenderli',
#  'slip',
#  'away',
#  'My',
#  'car',
#  'outsid',
#  'everyth',
#  'readi',
#  'that',
#  'husband',
#  'said',
#  'woman',
#  'ye',
#  'said',
#  'man',
#  'wo',
#  'troubl',
#  'that',
#  'woman',
#  'leav',
#  'said',
#  'I',
#  'wonder',
#  'she',
#  'turn',
#  'suddenli',
#  'great',
#  'start',
#  'there',
#  'somebodi',
#  'whisper',
#  'stare',
#  'back',
#  'alcov',
#  'nonsens',
#  'said',
#  'man',
#  'throw',
#  'glanc',
#  'around',
#  'recess',
#  'nobodi',
#  'I',
#  'We',
#  'alon',
#  'togeth',
#  'shall',
#  'hereaft',
#  'taken',
#  'step',
#  'but',
#  'child',
#  'whisper',
#  'woman',
#  'strang',
#  'vestur',
#  'wonder',
#  'face',
#  'hi',
#  'eye',
#  'look',
#  'there',
#  'child',
#  'dear',
#  'urg',
#  'man',
#  'overwrought',
#  'excit',
#  'nervou',
#  'the',
#  'music',
#  'start',
#  'let',
#  'us',
#  'go',
#  'He',
#  'stretch',
#  'hand',
#  'woman',
#  'came',
#  'nearer',
#  'shrank',
#  'back',
#  'hand',
#  'heart',
#  'Oh',
#  'said',
#  'faintli',
#  'gone',
#  'Of',
#  'cours',
#  'gone',
#  'answer',
#  'soothingli',
#  'now',
#  'time',
#  'get',
#  'away',
#  'let',
#  'No',
#  'said',
#  'woman',
#  'I',
#  'ca',
#  'go',
#  'It',
#  'would',
#  'right',
#  'but',
#  'knew',
#  'plead',
#  'man',
#  'besid',
#  'ye',
#  'I',
#  'ca',
#  'He',
#  'hi',
#  'eye',
#  'spoke',
#  'I',
#  'touch',
#  'said',
#  'I',
#  'go',
#  'back',
#  'husband',
#  'Do',
#  'follow',
#  'II',
#  'the',
#  'child',
#  'suffer',
#  'the',
#  'littl',
#  'children',
#  'TO',
#  'come',
#  'unto',
#  'ME',
#  'II',
#  'the',
#  'child',
#  'the',
#  'employe',
#  'gone',
#  'home',
#  'carri',
#  'christma',
#  'check',
#  'hearti',
#  'greet',
#  'great',
#  'man',
#  'whose',
#  'beck',
#  'nod',
#  'follow',
#  'He',
#  'sat',
#  'privat',
#  'offic',
#  'absolut',
#  'alon',
#  'He',
#  'seriou',
#  'matter',
#  'consid',
#  'want',
#  'interrupt',
#  'hi',
#  'year',
#  'made',
#  'accord',
#  'custom',
#  'firm',
#  'christma',
#  'instead',
#  'new',
#  'year',
#  'day',
#  'He',
#  'examin',
#  'It',
#  'show',
#  'tremend',
#  'profit',
#  'the',
#  'mill',
#  'turn',
#  'quantiti',
#  'materi',
#  'demand',
#  'greater',
#  'cost',
#  'product',
#  'less',
#  'ever',
#  'I',
#  'tell',
#  'said',
#  'man',
#  'displac',
#  'men',
#  'children',
#  'mill',
#  'they',
#  'reduc',
#  'cost',
#  'four',
#  'fifth',
#  'war',
#  'made',
#  'price',
#  'go',
#  'thi',
#  'wealth',
#  'rich',
#  'beyond',
#  'calcul',
#  'He',
#  'pick',
#  'letter',
#  'read',
#  'It',
#  'propos',
#  'superintend',
#  'clear',
#  'land',
#  'build',
#  'build',
#  'instal',
#  'machin',
#  'employ',
#  'children',
#  'increas',
#  'profit',
#  'greatli',
#  'I',
#  'said',
#  'man',
#  'We',
#  'crush',
#  'opposit',
#  'absolut',
#  'control',
#  'market',
#  'world',
#  'I',
#  'build',
#  'fortun',
#  'upon',
#  'foundat',
#  'great',
#  'one',
#  'comprehend',
#  'He',
#  'stop',
#  'lean',
#  'back',
#  'chair',
#  'lift',
#  'eye',
#  'toward',
#  'ceil',
#  'room',
#  'saw',
#  'beyond',
#  'kingdom',
#  'world',
#  'mean',
#  'unlimit',
#  'make',
#  'lord',
#  'master',
#  'He',
#  'gave',
#  'thought',
#  'foundat',
#  'structur',
#  'erect',
#  'fanci',
#  'how',
#  'long',
#  'indulg',
#  'dream',
#  'scarc',
#  'realiz',
#  'present',
#  'put',
#  'hand',
#  'arm',
#  'chair',
#  'start',
#  'rise',
#  'say',
#  'I',
#  'telegraph',
#  'superintend',
#  'go',
#  'ahead',
#  'He',
#  'scarc',
#  'formul',
#  'word',
#  'right',
#  'front',
#  'seat',
#  'desk',
#  'saw',
#  'young',
#  'lad',
#  'regard',
#  'intent',
#  'He',
#  'stop',
#  'petrifi',
#  'posit',
#  'assum',
#  'how',
#  'get',
#  'what',
#  'ask',
#  'there',
#  'answer',
#  'come',
#  'said',
#  'man',
#  'shrink',
#  'back',
#  'I',
#  'ca',
#  'imagin',
#  'got',
#  'If',
#  'peopl',
#  'gone',
#  'I',
#  'hold',
#  'strict',
#  'account',
#  'As',
#  'the',
#  'room',
#  'suddenli',
#  'fill',
#  'peopl',
#  'they',
#  'came',
#  'crowd',
#  'wall',
#  'everi',
#  'side',
#  'press',
#  'close',
#  'such',
#  'peopl',
#  'never',
#  'seen',
#  'wan',
#  'worn',
#  'stunt',
#  'pinch',
#  'starv',
#  'joyless',
#  'they',
#  'children',
#  'meagerli',
#  'cloth',
#  'badli',
#  'nourish',
#  'ill',
#  'develop',
#  'they',
#  'quit',
#  'silent',
#  'they',
#  'cri',
#  'they',
#  'protest',
#  'they',
#  'argu',
#  'they',
#  'plead',
#  'they',
#  'laugh',
#  'they',
#  'look',
#  'they',
#  'made',
#  'sound',
#  'sort',
#  'He',
#  'children',
#  'known',
#  'mani',
#  'children',
#  'He',
#  'never',
#  'known',
#  'mani',
#  'gather',
#  'togeth',
#  'without',
#  'smile',
#  'laugh',
#  'hi',
#  'eye',
#  'wander',
#  'around',
#  'room',
#  'they',
#  'close',
#  'yet',
#  'touch',
#  'He',
#  'turn',
#  'desk',
#  'lad',
#  'sat',
#  'longer',
#  'yet',
#  'well',
#  'rememb',
#  'face',
#  'He',
#  'knew',
#  'exactli',
#  'look',
#  'He',
#  'turn',
#  'nearest',
#  'child',
#  'strang',
#  'way',
#  'although',
#  'poor',
#  'wretch',
#  'face',
#  'chang',
#  'look',
#  'suggest',
#  'lad',
#  'first',
#  'visitor',
#  'He',
#  'turn',
#  'anoth',
#  'anoth',
#  'they',
#  'look',
#  'back',
#  'way',
#  'eye',
#  'He',
#  'threw',
#  'head',
#  'saw',
#  'castl',
#  'success',
#  'dream',
#  'He',
#  'look',
#  'thi',
#  'foundat',
#  'slowli',
#  'hand',
#  'went',
#  'desk',
#  'the',
#  'littl',
#  'crowd',
#  'figur',
#  'drew',
#  'back',
#  'give',
#  'freedom',
#  'movement',
#  'stretch',
#  'hand',
#  'He',
#  'drew',
#  'He',
#  'seiz',
#  'pen',
#  'wrote',
#  'rapidli',
#  'build',
#  'mill',
#  'take',
#  'children',
#  'alreadi',
#  'oper',
#  'put',
#  'men',
#  'place',
#  'We',
#  'content',
#  'less',
#  'profit',
#  'futur',
#  'He',
#  'read',
#  'telegram',
#  'the',
#  'telephon',
#  'close',
#  'hand',
#  'He',
#  'call',
#  'dictat',
#  'direct',
#  'sent',
#  'immedi',
#  'He',
#  'engross',
#  'task',
#  'notic',
#  'noth',
#  'els',
#  'now',
#  'look',
#  'the',
#  'room',
#  'still',
#  'fill',
#  'children',
#  'laugh',
#  'It',
#  'soundless',
#  'laugh',
#  'yet',
#  ...]
